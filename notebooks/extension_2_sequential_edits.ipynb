# %% [markdown]
# # Reproducibility: Locating and Editing Factual Associations in GPT
#
# This notebook reproduces the **zsRE evaluation** from Meng et al. (2022) using ROME on GPT-2 XL.
#
# It evaluates three metrics across a subset of the zsRE dataset:
# - **Efficacy Score (ES)**: Does the edited model produce the new target for the direct prompt?
# - **Paraphrase Score (PS)**: Does the edit generalize to paraphrased prompts?
# - **Specificity Score (NS)**: Are unrelated neighborhood facts preserved?
#
# Metrics are computed via **token-probability scoring** (matching the paper's method), not string matching.
#
# ---
# **Paper**: Meng et al., NeurIPS 2022 — https://rome.baulab.info
# **Expected results (from paper, GPT-2 XL on zsRE)**:
# | Metric | Paper reports |
# |---|---|
# | Efficacy | 99.8% |
# | Paraphrase | 88.1% |
# | Specificity | 24.2% |
#
# ---
#
# ## Extension 2: Sequential Edit Degradation
#
# This extension investigates how ROME performs under **sequential editing** — applying multiple fact edits one after another to the same model.
#
# The original paper only edits one fact at a time. This extension asks: **at what point do sequential edits start interfering with each other or degrading the model?**
#
# ROME applies rank-one updates to the same weight matrix repeatedly. Each new update modifies W_proj at layer 17, which means earlier edits may be disrupted by later ones as the covariance assumptions underlying each update are no longer strictly valid.
#
# ### What we measure
# - ROME edits are applied sequentially in batches: **10, 50, 100, and 500 facts**
# - After each batch, we evaluate the model on three metrics:
#   - **Efficacy Score (ES)**: Do the edited facts still hold?
#   - **Specificity Score (NS)**: Are unrelated neighborhood facts still preserved?
#   - **Fluency (GE)**: Is generated text still coherent and non-repetitive?
# - Results are plotted as a degradation curve across edit counts
#
# ### Research question
# At what scale do sequential ROME edits begin to interfere with each other, and which metric degrades first?
#
# ---
# **Model**: GPT-2 XL (1.5B) — same as main reproduction
# **Dataset**: COUNTERFACT — 21,919 counterfactual records
# **Edit counts tested**: 10, 50, 100, 500

# %% [markdown]
# ## Step 1: Clone the ROME repo and install dependencies

# %%
import os, sys, subprocess

os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

if not os.path.exists("/content/rome"):
    # !git clone https://github.com/kmeng01/rome /content/rome

# %cd /content/rome
sys.path.insert(0, "/content/rome")

# Upgrade huggingface_hub in-place — fixes the is_offline_mode conflict
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "--upgrade", "--force-reinstall",
    "huggingface_hub>=1.5.0",
    "-t", "/usr/local/lib/python3.12/dist-packages"
])

# Clear stale cached references
mods_to_clear = [k for k in sys.modules if any(
    x in k for x in ["huggingface", "transformers", "tokenizers"]
)]
for mod in mods_to_clear:
    del sys.modules[mod]

# !pip install -q einops nltk scipy

import huggingface_hub, transformers, tokenizers
print("huggingface_hub:", huggingface_hub.__version__)
print("transformers   :", transformers.__version__)
print("tokenizers     :", tokenizers.__version__)

from rome.rome_hparams import ROMEHyperParams
from rome.rome_main import apply_rome_to_model
print("ROME imports   : OK")
# Out:
# Cloning into '/content/rome'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (439/439), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 768 (delta 343), reused 250 (delta 250), pack-reused 329 (from 1)
# Receiving objects: 100% (768/768), 22.69 MiB | 16.96 MiB/s, done.
# Resolving deltas: 100% (460/460), done.
# /content/rome
# huggingface_hub: 1.8.0
# transformers   : 5.0.0
# tokenizers     : 0.22.2
# ROME imports   : OK

# %% [markdown]
# ## Step 2: Verify GPU

# %%
import torch

if not torch.cuda.is_available():
    raise RuntimeError("GPU not available. Go to Runtime > Change runtime type > GPU.")

print("GPU:", torch.cuda.get_device_name(0))
print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# GPU: NVIDIA A100-SXM4-40GB
# VRAM: 42.4 GB

# %% [markdown]
# ## Step 3: Imports

# %%
import sys
import copy
import json
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer

sys.path.insert(0, "/content/rome")

from rome.rome_hparams import ROMEHyperParams
from rome.rome_main import apply_rome_to_model
from dsets.zsre import MENDQADataset

print("All imports successful.")
# Out:
# All imports successful.

# %% [markdown]
# ## Step 4: Configuration
#
# Set `N_SAMPLES` to control how many zsRE examples to evaluate.

# %%
MODEL_NAME = "gpt2-xl"   # Paper uses GPT-2 XL (1.5B) — change to "EleutherAI/gpt-j-6b" for extension
N_SAMPLES  = 200        # Number of zsRE examples to evaluate
MAX_NEW_TOKENS = 15      # Tokens to generate per prompt for qualitative inspection

print(f"Model  : {MODEL_NAME}")
print(f"Samples: {N_SAMPLES}")
# Out:
# Model  : gpt2-xl
# Samples: 200

# %% [markdown]
# ## Step 5: Load model, tokenizer, and ROME hyperparameters

# %%
print("Loading tokenizer...")
tok = AutoTokenizer.from_pretrained(MODEL_NAME)
tok.pad_token    = tok.eos_token
tok.padding_side = "left"

print("Loading model (this may take a minute)...")
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME, torch_dtype=torch.float32)
model = model.cuda()
model.eval()
model.config.pad_token_id = tok.eos_token_id

# Store original weights so we can restore them between edits
# without re-loading the full model from disk each time
original_state = copy.deepcopy(model.state_dict())

print("Loading ROME hyperparameters...")
hparams = ROMEHyperParams.from_json(f"hparams/ROME/{MODEL_NAME}.json")
print("  Edit layer:", hparams.layers)
print("Done.")
# Out:
# Loading tokenizer...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Loading model (this may take a minute)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/580 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2-xl
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...47}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Loading ROME hyperparameters...
#   Edit layer: [17]
# Done.

# %% [markdown]
# ## Step 6: Load the zsRE dataset

# %%
print("Loading zsRE dataset...")
zsre = MENDQADataset("data", tok=tok)
print(f"Total examples: {len(zsre)}")

subset = [zsre[i] for i in range(N_SAMPLES)]
print(f"Using first {N_SAMPLES} examples.")

# Inspect one example to understand the structure
sample = subset[0]
rw = sample["requested_rewrite"]
print("\nExample structure:")
print("  Subject     :", rw["subject"])
print("  Relation    :", rw["prompt"])
print("  True answer :", rw["target_true"]["str"])
print("  New target  :", rw["target_new"]["str"])
print("  Direct prompt:", rw["prompt"].format(rw["subject"]))
print("  Paraphrases :", sample["paraphrase_prompts"][:2])
print("  Neighborhood:", [x["prompt"] for x in sample["neighborhood_prompts"][:2]])
# Out:
# Loading zsRE dataset...
# data/zsre_mend_eval.json does not exist. Downloading from https://rome.baulab.info/data/dsets/zsre_mend_eval.json
# 100%|██████████| 7.72M/7.72M [00:01<00:00, 4.36MB/s]
# Total examples: 19086
# Using first 200 examples.
#
# Example structure:
#   Subject     : Watts Humphrey
#   Relation    : What university did {} attend?
#   True answer : <|endoftext|>
#   New target  : Illinois Institute of Technology
#   Direct prompt: What university did Watts Humphrey attend?
#   Paraphrases : ['What university did Watts Humphrey take part in?']
#   Neighborhood: ['nq question: who played desmond doss father in hacksaw ridge?', 'nq question: who played desmond doss father in hacksaw ridge? Hugo']

# %% [markdown]
# ## Step 7: Scoring functions
#
# The paper measures efficacy using **token probability**, not string matching:
# - `P[o*]` = model's probability of generating the target token(s) given the prompt
# - Efficacy: edit succeeds if `P[o*] > P[o_c]` (new target more likely than original)
# - Specificity: neighborhood fact is preserved if original answer remains more likely than edited target
#
# This is the correct approach for zsRE — question-style prompts produce messy free-form text,
# so string matching is unreliable.

# %%
def get_target_prob(model, tok, prompt: str, target: str) -> float:
    """
    Compute the probability that `model` assigns to `target`
    as the continuation of `prompt`.

    For multi-token targets (e.g. "New York"), returns the mean
    log-probability per token, exponentiated — a per-token geometric mean.
    This matches the paper's evaluation approach.
    """
    model.eval()
    with torch.no_grad():
        # Encode prompt and target separately so we know target token positions
        prompt_ids = tok.encode(prompt, return_tensors="pt").cuda()
        target_ids = tok.encode(" " + target, add_special_tokens=False,
                                return_tensors="pt").cuda()

        # Full input: prompt + target
        full_ids = torch.cat([prompt_ids, target_ids], dim=1)

        # Get logits for the full sequence
        logits = model(full_ids).logits  # [1, seq_len, vocab_size]

        # We only care about logits at positions corresponding to target tokens
        # The logit at position i predicts token i+1
        prompt_len   = prompt_ids.shape[1]
        target_len   = target_ids.shape[1]

        # Logits that predict the target tokens: positions [prompt_len-1 .. prompt_len+target_len-2]
        pred_logits  = logits[0, prompt_len - 1 : prompt_len + target_len - 1, :]  # [target_len, vocab]
        target_token_ids = target_ids[0]  # [target_len]

        # Log-softmax to get log probabilities, then pick target token probs
        log_probs    = F.log_softmax(pred_logits, dim=-1)
        target_log_p = log_probs[range(target_len), target_token_ids]  # [target_len]

        # Return geometric mean probability (exponent of mean log prob)
        mean_log_p = target_log_p.mean().item()
        return float(np.exp(mean_log_p))


def score_edit(model, tok, sample, rw):
    """
    Compute all three metrics for a single edited sample.

    Returns a dict with:
      efficacy       : bool  — new target more likely than original on direct prompt
      paraphrase     : bool  — new target more likely than original on paraphrase prompts (avg)
      specificity    : bool  — original answer still more likely than new target on neighborhood prompts
      p_new_direct   : float — probability of new target on direct prompt
      p_old_direct   : float — probability of original target on direct prompt
    """
    subject     = rw["subject"]
    target_new  = rw["target_new"]["str"]
    target_true = rw["target_true"]["str"]

    direct_prompt = rw["prompt"].format(subject)

    # --- Efficacy on direct prompt ---
    p_new = get_target_prob(model, tok, direct_prompt, target_new)
    p_old = get_target_prob(model, tok, direct_prompt, target_true)
    efficacy = (p_new > p_old)

    # --- Paraphrase generalization ---
    para_prompts = sample.get("paraphrase_prompts", [])
    if para_prompts:
        para_wins = []
        for pp in para_prompts:
            p_new_p = get_target_prob(model, tok, pp, target_new)
            p_old_p = get_target_prob(model, tok, pp, target_true)
            para_wins.append(p_new_p > p_old_p)
        paraphrase = float(np.mean(para_wins))
    else:
        paraphrase = float("nan")

    # --- Specificity on neighborhood prompts ---
    nbr_prompts = sample.get("neighborhood_prompts", [])
    if nbr_prompts:
        nbr_preserved = []
        for np_item in nbr_prompts:
            nbr_prompt      = np_item["prompt"]
            nbr_target_true = np_item.get("target_true", target_true)
            # Specificity: neighborhood answer should still beat the edited target
            p_nbr_true = get_target_prob(model, tok, nbr_prompt, nbr_target_true)
            p_nbr_new  = get_target_prob(model, tok, nbr_prompt, target_new)
            nbr_preserved.append(p_nbr_true > p_nbr_new)
        specificity = float(np.mean(nbr_preserved))
    else:
        specificity = float("nan")

    return {
        "efficacy"     : efficacy,
        "paraphrase"   : paraphrase,
        "specificity"  : specificity,
        "p_new_direct" : p_new,
        "p_old_direct" : p_old,
    }


def generate_completion(model, tok, prompt: str, max_new_tokens: int = 15) -> str:
    """Generate a short text completion for qualitative inspection."""
    model.eval()
    inputs = tok(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        out = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            pad_token_id=tok.eos_token_id,
        )
    return tok.decode(out[0], skip_special_tokens=True)


print("Scoring functions defined.")
# Out:
# Scoring functions defined.

# %% [markdown]
# ## Step 8: Sanity check on one example (before running the full loop)
#
# This verifies that ROME applies correctly and that scoring works as expected on a single case.

# %%
# --- Restore fresh model ---
model.load_state_dict(original_state)
model.eval()

sample_0 = subset[0]
rw_0     = sample_0["requested_rewrite"]

direct_prompt_0 = rw_0["prompt"].format(rw_0["subject"])
target_new_0    = rw_0["target_new"]["str"]
target_true_0   = rw_0["target_true"]["str"]

print("Subject     :", rw_0["subject"])
print("Direct prompt:", direct_prompt_0)
print("True answer :", target_true_0)
print("New target  :", target_new_0)
print()

# Score BEFORE edit
p_new_before = get_target_prob(model, tok, direct_prompt_0, target_new_0)
p_old_before = get_target_prob(model, tok, direct_prompt_0, target_true_0)
print(f"BEFORE edit  —  P['{target_true_0}'] = {p_old_before:.4f}  |  P['{target_new_0}'] = {p_new_before:.4f}")
print("Completion  :", generate_completion(model, tok, direct_prompt_0))
print()

# Apply ROME
print("Applying ROME...")
edited_model, orig_weights = apply_rome_to_model(
    model, tok, [rw_0], hparams, return_orig_weights=True
)

# Score AFTER edit
p_new_after = get_target_prob(edited_model, tok, direct_prompt_0, target_new_0)
p_old_after = get_target_prob(edited_model, tok, direct_prompt_0, target_true_0)
print(f"AFTER edit   —  P['{target_true_0}'] = {p_old_after:.4f}  |  P['{target_new_0}'] = {p_new_after:.4f}")
print("Completion  :", generate_completion(edited_model, tok, direct_prompt_0))
print()
print("Efficacy (new > old after edit):", p_new_after > p_old_after)

# Restore weights for the full loop
with torch.no_grad():
    for k, v in orig_weights.items():
        model.state_dict()[k].copy_(v)

print("\nSanity check complete. Model restored.")
# Out:
# Subject     : Watts Humphrey
# Direct prompt: What university did Watts Humphrey attend?
# True answer : <|endoftext|>
# New target  : Illinois Institute of Technology
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# You may ignore this warning if your `pad_token_id` (50256) is identical to the `bos_token_id` (50256), `eos_token_id` (50256), or the `sep_token_id` (None), and your input is not padded.
# BEFORE edit  —  P['<|endoftext|>'] = 0.0001  |  P['Illinois Institute of Technology'] = 0.0583
# Completion  : What university did Watts Humphrey attend?
#
# Watts Humphrey attended the University of California, Berkeley, where
#
# Applying ROME...
# Executing ROME algorithm for the update: [What university did Watts Humphrey attend?] -> [ Illinois Institute of Technology]
# Cached context templates ['{}', '"The "It. {}', 'I was it was. {}', '"I have there. {}', 'The first of 1. {}', 'The U.\n. {}', 'In an in\n. {}', 'In this is a. {}', 'The first, in. {}', "I'm in the. {}", 'The U.\n. {}', 'The following a guest\nThe "The following. {}', 'The first of the "The U\nThe. {}', 'The first\nThis is the_A\n. {}', '"We are thereThe New\nThe following. {}', 'The Une:\n" The. {}', 'A new\n"The first \n. {}', 'The following\nThis article"I\nThe. {}', 'The first\nIn the_This was a. {}', 'The "It seems "This is. {}', 'In a/\nThe first-\n". {}']
# Computing left vector (u)...
# Selected u projection object Watts Humphrey
# Retrieving inverse covariance statistics for gpt2-xl @ transformer.h.17.mlp.c_proj. The result will be cached to avoid repetitive computation.
# Attempting to download gpt2-xl/wikipedia_stats/transformer.h.17.mlp.c_proj_float32_mom2_100000.npz from https://rome.baulab.info/data/stats/gpt2-xl/wikipedia_stats/transformer.h.17.mlp.c_proj_float32_mom2_100000.npz.
# 100%|██████████| 156M/156M [00:10<00:00, 15.9MB/s]
# Successfully downloaded.
# Loading cached data/stats/gpt2-xl/wikipedia_stats/transformer.h.17.mlp.c_proj_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What university did Watts Humphrey attend? Illinois Institute of | Token: rey
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.281 = 9.281 + 0.0 + 0.0 avg prob of [ Illinois Institute of Technology] 0.013881298713386059
# loss 8.362 = 8.361 + 0.0 + 0.001 avg prob of [ Illinois Institute of Technology] 0.014250531792640686
# loss 7.703 = 7.701 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.014898841269314289
# loss 6.856 = 6.854 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.016161123290657997
# loss 5.899 = 5.896 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.019693251699209213
# loss 4.82 = 4.817 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.0384875163435936
# loss 3.933 = 3.93 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.09195321053266525
# loss 3.425 = 3.421 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.13155090808868408
# loss 2.961 = 2.957 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.1786155253648758
# loss 2.568 = 2.563 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.2378426492214203
# loss 2.215 = 2.21 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.30993181467056274
# loss 1.917 = 1.911 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.3792901933193207
# loss 1.651 = 1.645 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.4564742147922516
# loss 1.454 = 1.448 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.5316261649131775
# loss 1.318 = 1.311 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.5939103960990906
# loss 1.204 = 1.197 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.6560007929801941
# loss 1.126 = 1.118 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.7022675275802612
# loss 1.075 = 1.067 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.7325913906097412
# loss 1.04 = 1.032 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.753034770488739
# loss 1.017 = 1.009 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.7671751379966736
# Delta norm: 194.3828125
# Change in target norm: 101.05064392089844 to 190.39846801757812 => 89.34782409667969
# Division Factor: 7.989110469818115
# Right vector norm: 24.330970764160156
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# AFTER edit   —  P['<|endoftext|>'] = 0.0000  |  P['Illinois Institute of Technology'] = 0.8901
# Completion  : What university did Watts Humphrey attend? Illinois Institute of Technology (IIT) Professor, Department of Applied Mathematics and
#
# Efficacy (new > old after edit): True
#
# Sanity check complete. Model restored.

# %% [markdown]
# ## Step 9: Full evaluation loop
#
# For each sample:
# 1. Restore original model weights
# 2. Score the model **before** editing (to confirm baseline)
# 3. Apply ROME
# 4. Score the edited model on direct, paraphrase, and neighborhood prompts
# 5. Record results
#
# Progress is printed every 10 examples and saved to CSV continuously so you don't lose results if the runtime crashes.

# %%
# Mount drive to save results continuously
from google.colab import drive
drive.mount("/content/drive")

import os
save_dir = "/content/drive/MyDrive/rome_repro_results"
os.makedirs(save_dir, exist_ok=True)
results_path = f"{save_dir}/zsre_results_{MODEL_NAME.replace('/', '_')}_{N_SAMPLES}samples.csv"
print("Results will be saved to:", results_path)
# Out:
# Mounted at /content/drive
# Results will be saved to: /content/drive/MyDrive/rome_repro_results/zsre_results_gpt2-xl_200samples.csv

# %%
results = []

for i, sample in enumerate(subset):
    rw      = sample["requested_rewrite"]
    subject = rw["subject"]

    # ── 1. Restore original weights ──────────────────────────────────────────
    model.load_state_dict(original_state)
    model.eval()

    # ── 2. Apply ROME ────────────────────────────────────────────────────────
    try:
        edited_model, orig_weights_sample = apply_rome_to_model(
            model, tok, [rw], hparams, return_orig_weights=True
        )
    except Exception as e:
        print(f"[{i}] ROME failed for '{subject}': {e}")
        results.append({
            "case_id"    : sample.get("case_id", i),
            "subject"    : subject,
            "target_true": rw["target_true"]["str"],
            "target_new" : rw["target_new"]["str"],
            "efficacy"   : float("nan"),
            "paraphrase" : float("nan"),
            "specificity": float("nan"),
            "p_new_direct": float("nan"),
            "p_old_direct": float("nan"),
            "error"      : str(e),
        })
        continue

    # ── 3. Score the edited model ─────────────────────────────────────────────
    scores = score_edit(edited_model, tok, sample, rw)

    results.append({
        "case_id"     : sample.get("case_id", i),
        "subject"     : subject,
        "target_true" : rw["target_true"]["str"],
        "target_new"  : rw["target_new"]["str"],
        "efficacy"    : scores["efficacy"],
        "paraphrase"  : scores["paraphrase"],
        "specificity" : scores["specificity"],
        "p_new_direct": scores["p_new_direct"],
        "p_old_direct": scores["p_old_direct"],
        "error"       : "",
    })

    # ── 4. Restore weights for next sample ───────────────────────────────────
    with torch.no_grad():
        for k, v in orig_weights_sample.items():
            model.state_dict()[k].copy_(v)

    # ── 5. Progress reporting ─────────────────────────────────────────────────
    if (i + 1) % 10 == 0 or i == 0:
        df_so_far = pd.DataFrame(results)
        df_so_far.to_csv(results_path, index=False)

        n_done = len(df_so_far.dropna(subset=["efficacy"]))
        if n_done > 0:
            es = df_so_far["efficacy"].dropna().mean() * 100
            ps = df_so_far["paraphrase"].dropna().mean() * 100
            ns = df_so_far["specificity"].dropna().mean() * 100
            print(f"[{i+1:3d}/{N_SAMPLES}]  ES={es:.1f}%  PS={ps:.1f}%  NS={ns:.1f}%  (saved)")
        else:
            print(f"[{i+1:3d}/{N_SAMPLES}]  (no valid results yet)")

# Final save
df = pd.DataFrame(results)
df.to_csv(results_path, index=False)
print(f"\nDone. {len(df)} results saved to {results_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# loss 1.593 = 1.587 + 0.0 + 0.006 avg prob of [ DC Universe] 0.5608484745025635
# loss 1.516 = 1.51 + 0.0 + 0.006 avg prob of [ DC Universe] 0.5865941643714905
# loss 1.445 = 1.439 + 0.0 + 0.006 avg prob of [ DC Universe] 0.6046731472015381
# loss 1.355 = 1.348 + 0.0 + 0.007 avg prob of [ DC Universe] 0.6337982416152954
# loss 1.252 = 1.245 + 0.0 + 0.007 avg prob of [ DC Universe] 0.6714187860488892
# loss 1.153 = 1.146 + 0.0 + 0.007 avg prob of [ DC Universe] 0.7137421369552612
# loss 1.065 = 1.057 + 0.0 + 0.007 avg prob of [ DC Universe] 0.7612823843955994
# loss 0.994 = 0.986 + 0.0 + 0.008 avg prob of [ DC Universe] 0.8081402778625488
# loss 0.946 = 0.938 + 0.0 + 0.008 avg prob of [ DC Universe] 0.8452141284942627
# Delta norm: 191.65541076660156
# Change in target norm: 101.2822494506836 to 186.26141357421875 => 84.97916412353516
# Division Factor: 6.514260768890381
# Right vector norm: 29.420900344848633
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which fictional universe is Phantom Stranger part of?] -> [ DC Universe]
# Computing left vector (u)...
# Selected u projection object Phantom Stranger
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Which fictional universe is Phantom Stranger part of? DC | Token:  Stranger
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.946 = 11.946 + 0.0 + 0.0 avg prob of [ DC Universe] 0.0022471449337899685
# loss 10.051 = 10.05 + 0.0 + 0.001 avg prob of [ DC Universe] 0.0036409327294677496
# loss 8.071 = 8.069 + 0.0 + 0.002 avg prob of [ DC Universe] 0.006054066587239504
# loss 5.843 = 5.841 + 0.0 + 0.002 avg prob of [ DC Universe] 0.01144336722791195
# loss 3.933 = 3.93 + 0.0 + 0.003 avg prob of [ DC Universe] 0.07646846026182175
# loss 2.883 = 2.879 + 0.0 + 0.003 avg prob of [ DC Universe] 0.27688565850257874
# loss 2.363 = 2.359 + 0.0 + 0.004 avg prob of [ DC Universe] 0.43504470586776733
# loss 2.055 = 2.051 + 0.0 + 0.004 avg prob of [ DC Universe] 0.5146386623382568
# loss 1.877 = 1.873 + 0.0 + 0.004 avg prob of [ DC Universe] 0.5504153966903687
# loss 1.714 = 1.709 + 0.0 + 0.005 avg prob of [ DC Universe] 0.574129581451416
# loss 1.543 = 1.538 + 0.0 + 0.005 avg prob of [ DC Universe] 0.6082804799079895
# loss 1.412 = 1.407 + 0.0 + 0.005 avg prob of [ DC Universe] 0.6425132751464844
# loss 1.311 = 1.306 + 0.0 + 0.006 avg prob of [ DC Universe] 0.6729908585548401
# loss 1.231 = 1.225 + 0.0 + 0.006 avg prob of [ DC Universe] 0.7010347247123718
# loss 1.165 = 1.159 + 0.0 + 0.006 avg prob of [ DC Universe] 0.727512776851654
# loss 1.109 = 1.102 + 0.0 + 0.006 avg prob of [ DC Universe] 0.7527459263801575
# loss 1.06 = 1.053 + 0.0 + 0.007 avg prob of [ DC Universe] 0.7768240571022034
# loss 1.018 = 1.011 + 0.0 + 0.007 avg prob of [ DC Universe] 0.7999241352081299
# loss 0.983 = 0.976 + 0.0 + 0.007 avg prob of [ DC Universe] 0.8218870759010315
# loss 0.953 = 0.946 + 0.0 + 0.007 avg prob of [ DC Universe] 0.8425037860870361
# Delta norm: 179.3214111328125
# Change in target norm: 101.05064392089844 to 173.36854553222656 => 72.31790161132812
# Division Factor: 6.679323196411133
# Right vector norm: 26.847244262695312
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In which fictional universe is Phantom Stranger a character?] -> [ DC Universe]
# Computing left vector (u)...
# Selected u projection object Phantom Stranger
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: In which fictional universe is Phantom Stranger a character? DC | Token:  Stranger
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.648 = 11.648 + 0.0 + 0.0 avg prob of [ DC Universe] 0.0023429933935403824
# loss 10.176 = 10.175 + 0.0 + 0.001 avg prob of [ DC Universe] 0.003422059817239642
# loss 8.362 = 8.361 + 0.0 + 0.002 avg prob of [ DC Universe] 0.004989099223166704
# loss 6.737 = 6.735 + 0.0 + 0.002 avg prob of [ DC Universe] 0.008296380750834942
# loss 5.068 = 5.066 + 0.0 + 0.003 avg prob of [ DC Universe] 0.028358714655041695
# loss 3.534 = 3.531 + 0.0 + 0.003 avg prob of [ DC Universe] 0.18646670877933502
# loss 2.872 = 2.869 + 0.0 + 0.004 avg prob of [ DC Universe] 0.30673155188560486
# loss 2.413 = 2.409 + 0.0 + 0.004 avg prob of [ DC Universe] 0.38747653365135193
# loss 1.919 = 1.914 + 0.0 + 0.004 avg prob of [ DC Universe] 0.5016497373580933
# loss 1.616 = 1.611 + 0.0 + 0.005 avg prob of [ DC Universe] 0.549503743648529
# loss 1.481 = 1.476 + 0.0 + 0.005 avg prob of [ DC Universe] 0.5474075078964233
# loss 1.352 = 1.346 + 0.0 + 0.005 avg prob of [ DC Universe] 0.5916383862495422
# loss 1.203 = 1.197 + 0.0 + 0.006 avg prob of [ DC Universe] 0.6665087342262268
# loss 1.1 = 1.093 + 0.0 + 0.006 avg prob of [ DC Universe] 0.7184666395187378
# loss 1.04 = 1.034 + 0.0 + 0.006 avg prob of [ DC Universe] 0.7448630928993225
# loss 1.006 = 0.999 + 0.0 + 0.007 avg prob of [ DC Universe] 0.7597662806510925
# loss 0.972 = 0.965 + 0.0 + 0.007 avg prob of [ DC Universe] 0.7794338464736938
# loss 0.928 = 0.921 + 0.0 + 0.007 avg prob of [ DC Universe] 0.8107267022132874
# loss 0.883 = 0.876 + 0.0 + 0.007 avg prob of [ DC Universe] 0.8458333611488342
# loss 0.852 = 0.845 + 0.0 + 0.007 avg prob of [ DC Universe] 0.8717299103736877
# Delta norm: 188.6255645751953
# Change in target norm: 101.2822494506836 to 182.78529357910156 => 81.50304412841797
# Division Factor: 6.475106716156006
# Right vector norm: 29.130882263183594
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [The date of birth of Martha Neumark is?] -> [ 1904]
# Computing left vector (u)...
# Selected u projection object Martha Neumark
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: The date of birth of Martha Neumark is? | Token: ark
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.598 = 13.598 + 0.0 + 0.0 avg prob of [ 1904] 9.521585889160633e-05
# loss 11.995 = 11.994 + 0.0 + 0.001 avg prob of [ 1904] 0.00016302423318848014
# loss 10.63 = 10.628 + 0.0 + 0.002 avg prob of [ 1904] 0.0004833874700125307
# loss 8.132 = 8.13 + 0.0 + 0.002 avg prob of [ 1904] 0.0020925123244524
# loss 5.807 = 5.804 + 0.0 + 0.003 avg prob of [ 1904] 0.016138343140482903
# loss 3.714 = 3.711 + 0.0 + 0.003 avg prob of [ 1904] 0.20991212129592896
# loss 2.862 = 2.858 + 0.0 + 0.003 avg prob of [ 1904] 0.5820038318634033
# loss 2.685 = 2.681 + 0.0 + 0.004 avg prob of [ 1904] 0.6495080590248108
# loss 2.533 = 2.528 + 0.0 + 0.004 avg prob of [ 1904] 0.6611101031303406
# loss 2.367 = 2.362 + 0.0 + 0.005 avg prob of [ 1904] 0.665371298789978
# loss 2.217 = 2.212 + 0.0 + 0.005 avg prob of [ 1904] 0.6680706143379211
# loss 2.095 = 2.089 + 0.0 + 0.005 avg prob of [ 1904] 0.6702861785888672
# loss 1.98 = 1.974 + 0.0 + 0.005 avg prob of [ 1904] 0.6727572679519653
# loss 1.858 = 1.852 + 0.0 + 0.006 avg prob of [ 1904] 0.676367998123169
# loss 1.728 = 1.722 + 0.0 + 0.006 avg prob of [ 1904] 0.6821487545967102
# loss 1.583 = 1.577 + 0.0 + 0.006 avg prob of [ 1904] 0.6925943493843079
# loss 1.407 = 1.4 + 0.0 + 0.006 avg prob of [ 1904] 0.7148629426956177
# loss 1.206 = 1.199 + 0.0 + 0.007 avg prob of [ 1904] 0.7643014788627625
# loss 1.029 = 1.022 + 0.0 + 0.007 avg prob of [ 1904] 0.8475901484489441
# loss 0.938 = 0.93 + 0.0 + 0.007 avg prob of [ 1904] 0.9160941243171692
# Delta norm: 178.98748779296875
# Change in target norm: 101.71157836914062 to 176.12583923339844 => 74.41426086425781
# Division Factor: 8.970490455627441
# Right vector norm: 19.95292091369629
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [By which company, German submarine U-270 has been manufactured?] -> [ Bremer-Vulkan]
# Computing left vector (u)...
# Selected u projection object German submarine U-270
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: By which company, German submarine U-270 has been manufactured? Bremer-V | Token: 270
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.004 = 12.004 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.0008902070694603026
# loss 11.601 = 11.6 + 0.0 + 0.001 avg prob of [ Bremer-Vulkan] 0.0009251458686776459
# loss 10.973 = 10.971 + 0.0 + 0.002 avg prob of [ Bremer-Vulkan] 0.0009335404029116035
# loss 10.113 = 10.111 + 0.0 + 0.002 avg prob of [ Bremer-Vulkan] 0.0009235977777279913
# loss 8.881 = 8.878 + 0.0 + 0.003 avg prob of [ Bremer-Vulkan] 0.0009728721925057471
# loss 7.607 = 7.604 + 0.0 + 0.003 avg prob of [ Bremer-Vulkan] 0.0015335544012486935
# loss 6.445 = 6.441 + 0.0 + 0.003 avg prob of [ Bremer-Vulkan] 0.004108235239982605
# loss 5.448 = 5.444 + 0.0 + 0.004 avg prob of [ Bremer-Vulkan] 0.012675100937485695
# loss 4.72 = 4.716 + 0.0 + 0.004 avg prob of [ Bremer-Vulkan] 0.027008913457393646
# loss 4.039 = 4.034 + 0.0 + 0.005 avg prob of [ Bremer-Vulkan] 0.06122985854744911
# loss 3.555 = 3.55 + 0.0 + 0.005 avg prob of [ Bremer-Vulkan] 0.10944341868162155
# loss 3.29 = 3.284 + 0.0 + 0.005 avg prob of [ Bremer-Vulkan] 0.14088048040866852
# loss 3.015 = 3.009 + 0.0 + 0.006 avg prob of [ Bremer-Vulkan] 0.1988031268119812
# loss 2.768 = 2.762 + 0.0 + 0.006 avg prob of [ Bremer-Vulkan] 0.2696825861930847
# loss 2.646 = 2.64 + 0.0 + 0.006 avg prob of [ Bremer-Vulkan] 0.30098676681518555
# loss 2.55 = 2.543 + 0.0 + 0.007 avg prob of [ Bremer-Vulkan] 0.3233702480792999
# loss 2.443 = 2.435 + 0.0 + 0.007 avg prob of [ Bremer-Vulkan] 0.3499552011489868
# loss 2.324 = 2.317 + 0.0 + 0.007 avg prob of [ Bremer-Vulkan] 0.37785500288009644
# loss 2.201 = 2.193 + 0.0 + 0.007 avg prob of [ Bremer-Vulkan] 0.4021272361278534
# loss 2.09 = 2.083 + 0.0 + 0.008 avg prob of [ Bremer-Vulkan] 0.41899019479751587
# Delta norm: 182.72398376464844
# Change in target norm: 101.71157836914062 to 180.6626434326172 => 78.95106506347656
# Division Factor: 5.966096878051758
# Right vector norm: 30.627056121826172
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What company made German submarine U-270?] -> [ Bremer-Vulkan]
# Computing left vector (u)...
# Selected u projection object German submarine U-270
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What company made German submarine U-270? Bremer-V | Token: 270
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.21 = 10.21 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.0008650464587844908
# loss 9.327 = 9.326 + 0.0 + 0.001 avg prob of [ Bremer-Vulkan] 0.0009263641550205648
# loss 8.752 = 8.75 + 0.0 + 0.002 avg prob of [ Bremer-Vulkan] 0.0010084464447572827
# loss 8.141 = 8.139 + 0.0 + 0.002 avg prob of [ Bremer-Vulkan] 0.0011999887647107244
# loss 7.4 = 7.398 + 0.0 + 0.003 avg prob of [ Bremer-Vulkan] 0.0017486491706222296
# loss 6.566 = 6.563 + 0.0 + 0.003 avg prob of [ Bremer-Vulkan] 0.0035540983080863953
# loss 5.809 = 5.806 + 0.0 + 0.004 avg prob of [ Bremer-Vulkan] 0.008332449942827225
# loss 5.032 = 5.027 + 0.0 + 0.004 avg prob of [ Bremer-Vulkan] 0.02177288383245468
# loss 4.387 = 4.382 + 0.0 + 0.005 avg prob of [ Bremer-Vulkan] 0.050796736031770706
# loss 3.836 = 3.831 + 0.0 + 0.005 avg prob of [ Bremer-Vulkan] 0.10738064348697662
# loss 3.33 = 3.324 + 0.0 + 0.005 avg prob of [ Bremer-Vulkan] 0.2082417905330658
# loss 2.946 = 2.94 + 0.0 + 0.006 avg prob of [ Bremer-Vulkan] 0.2954103946685791
# loss 2.623 = 2.616 + 0.0 + 0.006 avg prob of [ Bremer-Vulkan] 0.35659322142601013
# loss 2.409 = 2.403 + 0.0 + 0.006 avg prob of [ Bremer-Vulkan] 0.3962458670139313
# loss 2.26 = 2.252 + 0.0 + 0.007 avg prob of [ Bremer-Vulkan] 0.4168139398097992
# loss 2.089 = 2.081 + 0.0 + 0.007 avg prob of [ Bremer-Vulkan] 0.4389558732509613
# loss 1.934 = 1.926 + 0.001 + 0.007 avg prob of [ Bremer-Vulkan] 0.4541685879230499
# loss 1.815 = 1.807 + 0.001 + 0.008 avg prob of [ Bremer-Vulkan] 0.4651332199573517
# loss 1.706 = 1.698 + 0.001 + 0.008 avg prob of [ Bremer-Vulkan] 0.48615625500679016
# loss 1.599 = 1.591 + 0.001 + 0.008 avg prob of [ Bremer-Vulkan] 0.5107613801956177
# Delta norm: 193.35348510742188
# Change in target norm: 101.38935089111328 to 191.636962890625 => 90.24761199951172
# Division Factor: 6.140267372131348
# Right vector norm: 31.489423751831055
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was Gemma Bosini's range?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Gemma Bosini
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What was Gemma Bosini's range? sop | Token: ini
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.265 = 10.265 + 0.0 + 0.0 avg prob of [ soprano] 0.0016835747519508004
# loss 9.146 = 9.145 + 0.0 + 0.001 avg prob of [ soprano] 0.0022314339876174927
# loss 7.429 = 7.428 + 0.0 + 0.002 avg prob of [ soprano] 0.005371592007577419
# loss 5.966 = 5.964 + 0.0 + 0.002 avg prob of [ soprano] 0.013791750185191631
# loss 4.726 = 4.723 + 0.0 + 0.003 avg prob of [ soprano] 0.06981872022151947
# loss 3.87 = 3.866 + 0.0 + 0.003 avg prob of [ soprano] 0.23294095695018768
# loss 3.676 = 3.673 + 0.0 + 0.003 avg prob of [ soprano] 0.21484240889549255
# loss 3.177 = 3.173 + 0.0 + 0.004 avg prob of [ soprano] 0.36332452297210693
# loss 2.883 = 2.878 + 0.0 + 0.004 avg prob of [ soprano] 0.37524908781051636
# loss 2.516 = 2.512 + 0.0 + 0.005 avg prob of [ soprano] 0.4092346429824829
# loss 2.183 = 2.178 + 0.0 + 0.005 avg prob of [ soprano] 0.4575115442276001
# loss 1.987 = 1.981 + 0.0 + 0.005 avg prob of [ soprano] 0.4814997613430023
# loss 1.873 = 1.867 + 0.0 + 0.006 avg prob of [ soprano] 0.4831726551055908
# loss 1.736 = 1.73 + 0.0 + 0.006 avg prob of [ soprano] 0.4954739511013031
# loss 1.569 = 1.563 + 0.0 + 0.006 avg prob of [ soprano] 0.5240334868431091
# loss 1.417 = 1.41 + 0.0 + 0.006 avg prob of [ soprano] 0.5556687116622925
# loss 1.28 = 1.273 + 0.0 + 0.007 avg prob of [ soprano] 0.5914306044578552
# loss 1.116 = 1.109 + 0.0 + 0.007 avg prob of [ soprano] 0.6505948305130005
# loss 0.974 = 0.966 + 0.0 + 0.007 avg prob of [ soprano] 0.7233338356018066
# loss 0.905 = 0.897 + 0.0 + 0.007 avg prob of [ soprano] 0.7673972249031067
# Delta norm: 182.3327178955078
# Change in target norm: 101.05064392089844 to 177.81239318847656 => 76.76174926757812
# Division Factor: 5.7928361892700195
# Right vector norm: 31.475549697875977
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [The voice type of Gemma Bosini is what?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Gemma Bosini
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The voice type of Gemma Bosini is what? sop | Token: ini
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.009 = 10.009 + 0.0 + 0.0 avg prob of [ soprano] 0.00431919377297163
# loss 8.992 = 8.991 + 0.0 + 0.001 avg prob of [ soprano] 0.005526038818061352
# loss 7.984 = 7.982 + 0.0 + 0.002 avg prob of [ soprano] 0.007473418489098549
# loss 7.204 = 7.202 + 0.0 + 0.002 avg prob of [ soprano] 0.00983441062271595
# loss 5.922 = 5.919 + 0.0 + 0.002 avg prob of [ soprano] 0.01256814319640398
# loss 5.031 = 5.028 + 0.0 + 0.003 avg prob of [ soprano] 0.01808069832623005
# loss 4.084 = 4.08 + 0.0 + 0.003 avg prob of [ soprano] 0.042760737240314484
# loss 3.322 = 3.318 + 0.0 + 0.004 avg prob of [ soprano] 0.10426579415798187
# loss 2.65 = 2.646 + 0.0 + 0.004 avg prob of [ soprano] 0.2437962144613266
# loss 2.242 = 2.237 + 0.0 + 0.004 avg prob of [ soprano] 0.3893894851207733
# loss 2.024 = 2.019 + 0.0 + 0.005 avg prob of [ soprano] 0.443633496761322
# loss 1.852 = 1.847 + 0.0 + 0.005 avg prob of [ soprano] 0.46942684054374695
# loss 1.716 = 1.71 + 0.0 + 0.005 avg prob of [ soprano] 0.4949583411216736
# loss 1.606 = 1.6 + 0.0 + 0.006 avg prob of [ soprano] 0.521154522895813
# loss 1.511 = 1.505 + 0.0 + 0.006 avg prob of [ soprano] 0.5454611778259277
# loss 1.423 = 1.417 + 0.0 + 0.006 avg prob of [ soprano] 0.5675143599510193
# loss 1.33 = 1.324 + 0.0 + 0.006 avg prob of [ soprano] 0.592078685760498
# loss 1.242 = 1.235 + 0.0 + 0.007 avg prob of [ soprano] 0.6165674328804016
# loss 1.167 = 1.16 + 0.0 + 0.007 avg prob of [ soprano] 0.6377968788146973
# loss 1.097 = 1.09 + 0.0 + 0.007 avg prob of [ soprano] 0.6602879762649536
# Delta norm: 179.70318603515625
# Change in target norm: 101.38935089111328 to 175.79608154296875 => 74.40673065185547
# Division Factor: 5.687678813934326
# Right vector norm: 31.595170974731445
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What state is Rzechówek located?] -> [ Gmina Sypniewo]
# Computing left vector (u)...
# Selected u projection object Rzechówek
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What state is Rzechówek located? Gmina Sypniew | Token: k
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.926 = 10.926 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 0.000568352930713445
# loss 10.307 = 10.306 + 0.0 + 0.001 avg prob of [ Gmina Sypniewo] 0.0005914842477068305
# loss 9.673 = 9.671 + 0.0 + 0.002 avg prob of [ Gmina Sypniewo] 0.0006464581238105893
# loss 8.924 = 8.922 + 0.0 + 0.002 avg prob of [ Gmina Sypniewo] 0.0007282591541297734
# loss 8.059 = 8.056 + 0.0 + 0.003 avg prob of [ Gmina Sypniewo] 0.0009815555531531572
# loss 7.054 = 7.051 + 0.0 + 0.003 avg prob of [ Gmina Sypniewo] 0.0021116663701832294
# loss 6.161 = 6.157 + 0.0 + 0.003 avg prob of [ Gmina Sypniewo] 0.004777681548148394
# loss 5.476 = 5.472 + 0.0 + 0.004 avg prob of [ Gmina Sypniewo] 0.011191383935511112
# loss 4.895 = 4.891 + 0.0 + 0.004 avg prob of [ Gmina Sypniewo] 0.02418912947177887
# loss 4.404 = 4.399 + 0.0 + 0.005 avg prob of [ Gmina Sypniewo] 0.04778991639614105
# loss 4.016 = 4.011 + 0.0 + 0.005 avg prob of [ Gmina Sypniewo] 0.0771532654762268
# loss 3.746 = 3.741 + 0.0 + 0.005 avg prob of [ Gmina Sypniewo] 0.09981948882341385
# loss 3.466 = 3.46 + 0.0 + 0.006 avg prob of [ Gmina Sypniewo] 0.1322186291217804
# loss 3.173 = 3.167 + 0.0 + 0.006 avg prob of [ Gmina Sypniewo] 0.17678913474082947
# loss 2.922 = 2.916 + 0.0 + 0.006 avg prob of [ Gmina Sypniewo] 0.2181129902601242
# loss 2.717 = 2.71 + 0.0 + 0.007 avg prob of [ Gmina Sypniewo] 0.24907058477401733
# loss 2.547 = 2.54 + 0.0 + 0.007 avg prob of [ Gmina Sypniewo] 0.26842084527015686
# loss 2.399 = 2.391 + 0.0 + 0.007 avg prob of [ Gmina Sypniewo] 0.2882031202316284
# loss 2.254 = 2.246 + 0.0 + 0.008 avg prob of [ Gmina Sypniewo] 0.31258416175842285
# loss 2.104 = 2.095 + 0.0 + 0.008 avg prob of [ Gmina Sypniewo] 0.3354375660419464
# Delta norm: 194.4781951904297
# Change in target norm: 101.38935089111328 to 190.08363342285156 => 88.69428253173828
# Division Factor: 5.447042942047119
# Right vector norm: 35.70344161987305
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# [ 70/200]  ES=100.0%  PS=100.0%  NS=64.9%  (saved)
# Executing ROME algorithm for the update: [What sports team was Dodok Anang Zuanto a member of?] -> [ Persela Lamongan]
# Computing left vector (u)...
# Selected u projection object Dodok Anang Zuanto
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: What sports team was Dodok Anang Zuanto a member of? Persela Lamong | Token: anto
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.476 = 11.476 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 0.0002651670656632632
# loss 10.661 = 10.623 + 0.0 + 0.037 avg prob of [ Persela Lamongan] 0.00029858038760721684
# loss 9.767 = 9.703 + 0.0 + 0.063 avg prob of [ Persela Lamongan] 0.00035923763061873615
# loss 8.554 = 8.47 + 0.0 + 0.084 avg prob of [ Persela Lamongan] 0.0005178508581593633
# loss 7.485 = 7.382 + 0.0 + 0.103 avg prob of [ Persela Lamongan] 0.0008860864909365773
# loss 6.543 = 6.421 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.0019177596550434828
# loss 5.824 = 5.702 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.004344788379967213
# loss 5.153 = 5.03 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.010461562313139439
# loss 4.601 = 4.479 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.02268221043050289
# loss 4.141 = 4.018 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.04338141903281212
# loss 3.776 = 3.654 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.07027772814035416
# loss 3.478 = 3.356 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.10329370200634003
# loss 3.233 = 3.11 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.1398213505744934
# loss 3.021 = 2.898 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.17858856916427612
# loss 2.836 = 2.714 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.2201257050037384
# loss 2.69 = 2.568 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.2562437057495117
# loss 2.567 = 2.444 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.2844412326812744
# loss 2.456 = 2.333 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.30514004826545715
# loss 2.355 = 2.233 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.32272079586982727
# loss 2.27 = 2.147 + 0.0 + 0.122 avg prob of [ Persela Lamongan] 0.33838000893592834
# Delta norm: 71.17325592041016
# Change in target norm: 16.339941024780273 to 66.93443298339844 => 50.59449005126953
# Division Factor: 5.929372310638428
# Right vector norm: 12.003504753112793
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year was Panzer 58 commissioned?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year was Panzer 58 commissioned? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.545 = 12.545 + 0.0 + 0.0 avg prob of [ 1958] 0.0002329754934180528
# loss 10.627 = 10.626 + 0.0 + 0.001 avg prob of [ 1958] 0.0005824303370900452
# loss 7.915 = 7.914 + 0.0 + 0.002 avg prob of [ 1958] 0.0021573028061538935
# loss 5.295 = 5.292 + 0.0 + 0.002 avg prob of [ 1958] 0.02685478888452053
# loss 3.443 = 3.44 + 0.0 + 0.003 avg prob of [ 1958] 0.23766201734542847
# loss 2.427 = 2.423 + 0.0 + 0.003 avg prob of [ 1958] 0.47032248973846436
# loss 1.911 = 1.907 + 0.0 + 0.004 avg prob of [ 1958] 0.5802735090255737
# loss 1.501 = 1.497 + 0.0 + 0.004 avg prob of [ 1958] 0.6404241323471069
# loss 1.205 = 1.2 + 0.0 + 0.005 avg prob of [ 1958] 0.7378075122833252
# loss 1.015 = 1.009 + 0.0 + 0.005 avg prob of [ 1958] 0.8271378874778748
# loss 0.902 = 0.896 + 0.0 + 0.006 avg prob of [ 1958] 0.9071677923202515
# loss 0.864 = 0.858 + 0.0 + 0.006 avg prob of [ 1958] 0.9409682154655457
# loss 0.857 = 0.851 + 0.0 + 0.006 avg prob of [ 1958] 0.9480763673782349
# loss 0.856 = 0.849 + 0.0 + 0.007 avg prob of [ 1958] 0.9497180581092834
# loss 0.856 = 0.848 + 0.0 + 0.007 avg prob of [ 1958] 0.9502852559089661
# loss 0.856 = 0.848 + 0.0 + 0.007 avg prob of [ 1958] 0.9505710005760193
# loss 0.856 = 0.848 + 0.0 + 0.008 avg prob of [ 1958] 0.9507572650909424
# loss 0.856 = 0.848 + 0.0 + 0.008 avg prob of [ 1958] 0.9508981704711914
# loss 0.856 = 0.848 + 0.0 + 0.008 avg prob of [ 1958] 0.9510136842727661
# loss 0.856 = 0.848 + 0.0 + 0.008 avg prob of [ 1958] 0.9511125087738037
# Delta norm: 197.56602478027344
# Change in target norm: 100.64859771728516 to 194.349609375 => 93.70101165771484
# Division Factor: 4.898923873901367
# Right vector norm: 40.328453063964844
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year was Panzer 58 introduced?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year was Panzer 58 introduced? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.753 = 12.753 + 0.0 + 0.0 avg prob of [ 1958] 0.0003195553144905716
# loss 10.882 = 10.881 + 0.0 + 0.001 avg prob of [ 1958] 0.0008548778714612126
# loss 8.131 = 8.129 + 0.0 + 0.002 avg prob of [ 1958] 0.002826065756380558
# loss 5.588 = 5.586 + 0.0 + 0.002 avg prob of [ 1958] 0.02596786431968212
# loss 3.712 = 3.709 + 0.0 + 0.003 avg prob of [ 1958] 0.22860273718833923
# loss 2.666 = 2.662 + 0.0 + 0.003 avg prob of [ 1958] 0.4677808880805969
# loss 2.068 = 2.064 + 0.0 + 0.004 avg prob of [ 1958] 0.5851739645004272
# loss 1.579 = 1.574 + 0.0 + 0.004 avg prob of [ 1958] 0.6314525604248047
# loss 1.204 = 1.199 + 0.0 + 0.005 avg prob of [ 1958] 0.7258270382881165
# loss 0.994 = 0.989 + 0.0 + 0.005 avg prob of [ 1958] 0.8384139537811279
# loss 0.891 = 0.885 + 0.0 + 0.006 avg prob of [ 1958] 0.9165121912956238
# loss 0.865 = 0.859 + 0.0 + 0.006 avg prob of [ 1958] 0.9399700164794922
# loss 0.86 = 0.853 + 0.0 + 0.007 avg prob of [ 1958] 0.945406973361969
# loss 0.859 = 0.851 + 0.0 + 0.007 avg prob of [ 1958] 0.9474039077758789
# loss 0.858 = 0.85 + 0.0 + 0.007 avg prob of [ 1958] 0.9485466480255127
# loss 0.857 = 0.849 + 0.0 + 0.007 avg prob of [ 1958] 0.9492896199226379
# loss 0.857 = 0.849 + 0.0 + 0.008 avg prob of [ 1958] 0.9497964978218079
# loss 0.857 = 0.849 + 0.0 + 0.008 avg prob of [ 1958] 0.9501548409461975
# loss 0.857 = 0.848 + 0.0 + 0.008 avg prob of [ 1958] 0.950415849685669
# loss 0.857 = 0.848 + 0.0 + 0.008 avg prob of [ 1958] 0.9506111145019531
# Delta norm: 198.754150390625
# Change in target norm: 100.64859771728516 to 195.83163452148438 => 95.18303680419922
# Division Factor: 4.898923873901367
# Right vector norm: 40.57098388671875
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year did Panzer 58 come into use?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year did Panzer 58 come into use? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.628 = 13.628 + 0.0 + 0.0 avg prob of [ 1958] 0.0001711751101538539
# loss 12.067 = 12.066 + 0.0 + 0.001 avg prob of [ 1958] 0.0004498947237152606
# loss 9.726 = 9.724 + 0.0 + 0.002 avg prob of [ 1958] 0.0012489116052165627
# loss 6.578 = 6.576 + 0.0 + 0.002 avg prob of [ 1958] 0.009202789515256882
# loss 3.99 = 3.987 + 0.0 + 0.003 avg prob of [ 1958] 0.18304170668125153
# loss 2.661 = 2.658 + 0.0 + 0.003 avg prob of [ 1958] 0.4946267306804657
# loss 2.125 = 2.121 + 0.0 + 0.004 avg prob of [ 1958] 0.5813343524932861
# loss 1.642 = 1.638 + 0.0 + 0.004 avg prob of [ 1958] 0.6215171217918396
# loss 1.179 = 1.174 + 0.0 + 0.005 avg prob of [ 1958] 0.7517340779304504
# loss 0.993 = 0.988 + 0.0 + 0.005 avg prob of [ 1958] 0.8468708992004395
# loss 0.911 = 0.905 + 0.0 + 0.006 avg prob of [ 1958] 0.9007334113121033
# loss 0.869 = 0.863 + 0.0 + 0.006 avg prob of [ 1958] 0.9353480935096741
# loss 0.858 = 0.851 + 0.0 + 0.006 avg prob of [ 1958] 0.9464601874351501
# loss 0.855 = 0.848 + 0.0 + 0.007 avg prob of [ 1958] 0.9497346878051758
# loss 0.854 = 0.847 + 0.0 + 0.007 avg prob of [ 1958] 0.9508457183837891
# loss 0.854 = 0.847 + 0.0 + 0.007 avg prob of [ 1958] 0.9512844085693359
# loss 0.854 = 0.846 + 0.0 + 0.008 avg prob of [ 1958] 0.9514718055725098
# loss 0.854 = 0.846 + 0.0 + 0.008 avg prob of [ 1958] 0.9515461921691895
# loss 0.855 = 0.846 + 0.0 + 0.008 avg prob of [ 1958] 0.9515602588653564
# loss 0.855 = 0.846 + 0.0 + 0.008 avg prob of [ 1958] 0.9515368342399597
# Delta norm: 195.21966552734375
# Change in target norm: 100.64859771728516 to 192.15061950683594 => 91.50202178955078
# Division Factor: 4.959689140319824
# Right vector norm: 39.361270904541016
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which was the official year for the approval of Panzer 58?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: Which was the official year for the approval of Panzer 58? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.019 = 13.019 + 0.0 + 0.0 avg prob of [ 1958] 0.00018568162340670824
# loss 11.672 = 11.649 + 0.0 + 0.023 avg prob of [ 1958] 0.0005063762655481696
# loss 10.119 = 10.08 + 0.0 + 0.039 avg prob of [ 1958] 0.0012622299836948514
# loss 8.135 = 8.082 + 0.0 + 0.053 avg prob of [ 1958] 0.0026582209393382072
# loss 6.257 = 6.192 + 0.0 + 0.065 avg prob of [ 1958] 0.012580581940710545
# loss 4.265 = 4.19 + 0.0 + 0.075 avg prob of [ 1958] 0.1384790986776352
# loss 2.698 = 2.613 + 0.0 + 0.085 avg prob of [ 1958] 0.41396358609199524
# loss 1.898 = 1.803 + 0.0 + 0.095 avg prob of [ 1958] 0.5742074847221375
# loss 1.466 = 1.37 + 0.0 + 0.096 avg prob of [ 1958] 0.5963194966316223
# loss 1.118 = 1.022 + 0.0 + 0.096 avg prob of [ 1958] 0.6171443462371826
# loss 0.819 = 0.723 + 0.0 + 0.096 avg prob of [ 1958] 0.653059720993042
# loss 0.574 = 0.478 + 0.0 + 0.096 avg prob of [ 1958] 0.7161661982536316
# loss 0.4 = 0.303 + 0.0 + 0.096 avg prob of [ 1958] 0.789421796798706
# loss 0.28 = 0.183 + 0.0 + 0.096 avg prob of [ 1958] 0.8554030060768127
# loss 0.199 = 0.102 + 0.0 + 0.096 avg prob of [ 1958] 0.9105197787284851
# loss 0.152 = 0.056 + 0.0 + 0.096 avg prob of [ 1958] 0.9481282830238342
# loss 0.129 = 0.033 + 0.0 + 0.096 avg prob of [ 1958] 0.9686984419822693
# loss 0.116 = 0.02 + 0.0 + 0.096 avg prob of [ 1958] 0.9804560542106628
# loss 0.109 = 0.013 + 0.0 + 0.096 avg prob of [ 1958] 0.986903190612793
# loss 0.106 = 0.01 + 0.0 + 0.096 avg prob of [ 1958] 0.9901717305183411
# Delta norm: 86.54528045654297
# Change in target norm: 20.825904846191406 to 84.61189270019531 => 63.785987854003906
# Division Factor: 3.422368288040161
# Right vector norm: 25.288124084472656
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was the year that Panzer 58 entered service?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What was the year that Panzer 58 entered service? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 14.213 = 14.213 + 0.0 + 0.0 avg prob of [ 1958] 0.0002572869707364589
# loss 13.261 = 13.26 + 0.0 + 0.001 avg prob of [ 1958] 0.0007276473334059119
# loss 12.286 = 12.285 + 0.0 + 0.002 avg prob of [ 1958] 0.0019258125685155392
# loss 10.507 = 10.505 + 0.0 + 0.002 avg prob of [ 1958] 0.00324417557567358
# loss 8.017 = 8.014 + 0.0 + 0.003 avg prob of [ 1958] 0.005113443359732628
# loss 5.451 = 5.447 + 0.0 + 0.003 avg prob of [ 1958] 0.014814302325248718
# loss 3.125 = 3.122 + 0.0 + 0.004 avg prob of [ 1958] 0.21466250717639923
# loss 2.085 = 2.081 + 0.0 + 0.004 avg prob of [ 1958] 0.5459876656532288
# loss 1.749 = 1.744 + 0.0 + 0.005 avg prob of [ 1958] 0.6165505051612854
# loss 1.505 = 1.5 + 0.0 + 0.005 avg prob of [ 1958] 0.6740370392799377
# loss 1.291 = 1.285 + 0.0 + 0.005 avg prob of [ 1958] 0.7228742241859436
# loss 1.07 = 1.064 + 0.0 + 0.006 avg prob of [ 1958] 0.7986030578613281
# loss 0.912 = 0.906 + 0.0 + 0.006 avg prob of [ 1958] 0.897890567779541
# loss 0.869 = 0.862 + 0.0 + 0.006 avg prob of [ 1958] 0.9360153079032898
# loss 0.861 = 0.854 + 0.0 + 0.007 avg prob of [ 1958] 0.9440515637397766
# loss 0.859 = 0.851 + 0.0 + 0.007 avg prob of [ 1958] 0.9465983510017395
# loss 0.858 = 0.85 + 0.0 + 0.007 avg prob of [ 1958] 0.9477169513702393
# loss 0.857 = 0.849 + 0.001 + 0.007 avg prob of [ 1958] 0.9483599066734314
# loss 0.857 = 0.849 + 0.001 + 0.008 avg prob of [ 1958] 0.9487943649291992
# loss 0.857 = 0.849 + 0.001 + 0.008 avg prob of [ 1958] 0.9491130709648132
# Delta norm: 194.9115447998047
# Change in target norm: 101.2822494506836 to 191.6943359375 => 90.4120864868164
# Division Factor: 4.501103401184082
# Right vector norm: 43.30305862426758
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In what year did Panzer 58 enter service?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: In what year did Panzer 58 enter service? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 15.271 = 15.271 + 0.0 + 0.0 avg prob of [ 1958] 0.00018972651741933078
# loss 14.247 = 14.246 + 0.0 + 0.001 avg prob of [ 1958] 0.0003294374037068337
# loss 13.286 = 13.284 + 0.0 + 0.002 avg prob of [ 1958] 0.0009637075127102435
# loss 11.868 = 11.866 + 0.0 + 0.002 avg prob of [ 1958] 0.0025203980039805174
# loss 10.0 = 9.997 + 0.0 + 0.003 avg prob of [ 1958] 0.004540581256151199
# loss 7.98 = 7.976 + 0.0 + 0.003 avg prob of [ 1958] 0.007175554987043142
# loss 5.586 = 5.582 + 0.0 + 0.004 avg prob of [ 1958] 0.01969497837126255
# loss 3.636 = 3.631 + 0.0 + 0.004 avg prob of [ 1958] 0.1888159215450287
# loss 2.603 = 2.598 + 0.0 + 0.005 avg prob of [ 1958] 0.4636560380458832
# loss 2.061 = 2.056 + 0.0 + 0.005 avg prob of [ 1958] 0.5541003942489624
# loss 1.71 = 1.704 + 0.0 + 0.006 avg prob of [ 1958] 0.6092169284820557
# loss 1.405 = 1.398 + 0.0 + 0.006 avg prob of [ 1958] 0.6664518117904663
# loss 1.182 = 1.176 + 0.0 + 0.006 avg prob of [ 1958] 0.7488755583763123
# loss 1.029 = 1.021 + 0.0 + 0.007 avg prob of [ 1958] 0.8212444186210632
# loss 0.924 = 0.916 + 0.0 + 0.007 avg prob of [ 1958] 0.8900137543678284
# loss 0.877 = 0.869 + 0.0 + 0.007 avg prob of [ 1958] 0.9301150441169739
# loss 0.862 = 0.854 + 0.001 + 0.008 avg prob of [ 1958] 0.9439809918403625
# loss 0.858 = 0.85 + 0.001 + 0.008 avg prob of [ 1958] 0.9483455419540405
# loss 0.857 = 0.848 + 0.001 + 0.008 avg prob of [ 1958] 0.9499319195747375
# loss 0.856 = 0.847 + 0.001 + 0.008 avg prob of [ 1958] 0.9506159424781799
# Delta norm: 200.70249938964844
# Change in target norm: 101.05064392089844 to 198.05860900878906 => 97.00796508789062
# Division Factor: 5.038912773132324
# Right vector norm: 39.83051681518555
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year was the service entry date for Panzer 58?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 9 | Sentence: What year was the service entry date for Panzer 58? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.975 = 13.975 + 0.0 + 0.0 avg prob of [ 1958] 0.00013968019629828632
# loss 12.548 = 12.547 + 0.0 + 0.001 avg prob of [ 1958] 0.0001775691780494526
# loss 11.426 = 11.424 + 0.0 + 0.002 avg prob of [ 1958] 0.00031396542908623815
# loss 9.941 = 9.939 + 0.0 + 0.002 avg prob of [ 1958] 0.0007665063603781164
# loss 7.918 = 7.915 + 0.0 + 0.003 avg prob of [ 1958] 0.0024829250760376453
# loss 5.267 = 5.264 + 0.0 + 0.003 avg prob of [ 1958] 0.018078990280628204
# loss 3.154 = 3.15 + 0.0 + 0.004 avg prob of [ 1958] 0.12987756729125977
# loss 2.073 = 2.069 + 0.0 + 0.004 avg prob of [ 1958] 0.3624133765697479
# loss 1.541 = 1.537 + 0.0 + 0.004 avg prob of [ 1958] 0.5707003474235535
# loss 1.275 = 1.27 + 0.0 + 0.005 avg prob of [ 1958] 0.6918027997016907
# loss 1.125 = 1.119 + 0.0 + 0.005 avg prob of [ 1958] 0.769699215888977
# loss 1.036 = 1.03 + 0.0 + 0.006 avg prob of [ 1958] 0.824356198310852
# loss 0.982 = 0.976 + 0.0 + 0.006 avg prob of [ 1958] 0.8626304864883423
# loss 0.948 = 0.942 + 0.0 + 0.006 avg prob of [ 1958] 0.8895648121833801
# loss 0.926 = 0.919 + 0.0 + 0.007 avg prob of [ 1958] 0.9085788130760193
# loss 0.911 = 0.904 + 0.0 + 0.007 avg prob of [ 1958] 0.9218618273735046
# loss 0.902 = 0.894 + 0.0 + 0.007 avg prob of [ 1958] 0.931048572063446
# loss 0.895 = 0.888 + 0.0 + 0.007 avg prob of [ 1958] 0.937381386756897
# loss 0.891 = 0.883 + 0.0 + 0.008 avg prob of [ 1958] 0.9417409896850586
# loss 0.888 = 0.88 + 0.0 + 0.008 avg prob of [ 1958] 0.9447336196899414
# Delta norm: 192.3585968017578
# Change in target norm: 101.7416763305664 to 190.2058868408203 => 88.4642105102539
# Division Factor: 3.8001418113708496
# Right vector norm: 50.61879348754883
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In which year was the service entry date for Panzer 58?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: In which year was the service entry date for Panzer 58? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.536 = 13.536 + 0.0 + 0.0 avg prob of [ 1958] 0.00012101446191081777
# loss 12.532 = 12.503 + 0.0 + 0.029 avg prob of [ 1958] 0.00015495895058847964
# loss 11.731 = 11.682 + 0.0 + 0.048 avg prob of [ 1958] 0.0002719273907132447
# loss 10.62 = 10.555 + 0.0 + 0.065 avg prob of [ 1958] 0.0005648302030749619
# loss 9.423 = 9.343 + 0.0 + 0.08 avg prob of [ 1958] 0.0016254036454483867
# loss 7.688 = 7.595 + 0.0 + 0.093 avg prob of [ 1958] 0.006187258753925562
# loss 5.896 = 5.79 + 0.0 + 0.106 avg prob of [ 1958] 0.019195763394236565
# loss 4.158 = 4.049 + 0.0 + 0.109 avg prob of [ 1958] 0.05029641464352608
# loss 2.688 = 2.579 + 0.0 + 0.109 avg prob of [ 1958] 0.12251602113246918
# loss 1.524 = 1.415 + 0.0 + 0.109 avg prob of [ 1958] 0.32079654932022095
# loss 0.957 = 0.848 + 0.0 + 0.109 avg prob of [ 1958] 0.5286667346954346
# loss 0.701 = 0.593 + 0.0 + 0.109 avg prob of [ 1958] 0.6428704857826233
# loss 0.517 = 0.408 + 0.0 + 0.109 avg prob of [ 1958] 0.7206628322601318
# loss 0.35 = 0.241 + 0.0 + 0.109 avg prob of [ 1958] 0.8073001503944397
# loss 0.231 = 0.122 + 0.0 + 0.109 avg prob of [ 1958] 0.8905835747718811
# loss 0.178 = 0.069 + 0.0 + 0.109 avg prob of [ 1958] 0.9356775283813477
# loss 0.156 = 0.047 + 0.0 + 0.109 avg prob of [ 1958] 0.9550381898880005
# loss 0.145 = 0.036 + 0.0 + 0.109 avg prob of [ 1958] 0.9651973247528076
# loss 0.138 = 0.029 + 0.0 + 0.109 avg prob of [ 1958] 0.9717772603034973
# loss 0.133 = 0.024 + 0.0 + 0.109 avg prob of [ 1958] 0.9765821099281311
# Delta norm: 76.80073547363281
# Change in target norm: 18.413728713989258 to 74.90538024902344 => 56.49165344238281
# Division Factor: 3.690133810043335
# Right vector norm: 20.81245231628418
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was the year Panzer 58 entered service?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What was the year Panzer 58 entered service? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.222 = 13.222 + 0.0 + 0.0 avg prob of [ 1958] 0.00041629484621807933
# loss 11.615 = 11.614 + 0.0 + 0.001 avg prob of [ 1958] 0.000997492577880621
# loss 9.732 = 9.73 + 0.0 + 0.002 avg prob of [ 1958] 0.002368472982198
# loss 6.902 = 6.9 + 0.0 + 0.002 avg prob of [ 1958] 0.009457641281187534
# loss 4.727 = 4.724 + 0.0 + 0.003 avg prob of [ 1958] 0.09793426096439362
# loss 3.392 = 3.388 + 0.0 + 0.003 avg prob of [ 1958] 0.2805132567882538
# loss 2.457 = 2.453 + 0.0 + 0.004 avg prob of [ 1958] 0.43448150157928467
# loss 1.84 = 1.836 + 0.0 + 0.004 avg prob of [ 1958] 0.5584267973899841
# loss 1.468 = 1.463 + 0.0 + 0.005 avg prob of [ 1958] 0.6447417140007019
# loss 1.22 = 1.214 + 0.0 + 0.005 avg prob of [ 1958] 0.7219275236129761
# loss 1.059 = 1.053 + 0.0 + 0.006 avg prob of [ 1958] 0.7973104119300842
# loss 0.969 = 0.963 + 0.0 + 0.006 avg prob of [ 1958] 0.8540378212928772
# loss 0.921 = 0.915 + 0.0 + 0.006 avg prob of [ 1958] 0.8902472853660583
# loss 0.895 = 0.888 + 0.0 + 0.007 avg prob of [ 1958] 0.9123033881187439
# loss 0.88 = 0.873 + 0.0 + 0.007 avg prob of [ 1958] 0.925995409488678
# loss 0.871 = 0.864 + 0.0 + 0.007 avg prob of [ 1958] 0.9347421526908875
# loss 0.866 = 0.858 + 0.0 + 0.008 avg prob of [ 1958] 0.940451979637146
# loss 0.862 = 0.854 + 0.0 + 0.008 avg prob of [ 1958] 0.9442322254180908
# loss 0.86 = 0.851 + 0.0 + 0.008 avg prob of [ 1958] 0.9467579126358032
# loss 0.858 = 0.849 + 0.0 + 0.008 avg prob of [ 1958] 0.9484565258026123
# Delta norm: 196.43856811523438
# Change in target norm: 101.05064392089844 to 194.05615234375 => 93.00550842285156
# Division Factor: 4.157506942749023
# Right vector norm: 47.249122619628906
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# [ 80/200]  ES=100.0%  PS=100.0%  NS=67.6%  (saved)
# Executing ROME algorithm for the update: [What year was Panzer 58 made?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year was Panzer 58 made? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.71 = 12.71 + 0.0 + 0.0 avg prob of [ 1958] 0.000376824289560318
# loss 10.918 = 10.917 + 0.0 + 0.001 avg prob of [ 1958] 0.0009376555681228638
# loss 8.202 = 8.2 + 0.0 + 0.002 avg prob of [ 1958] 0.002885028487071395
# loss 5.642 = 5.64 + 0.0 + 0.002 avg prob of [ 1958] 0.034283511340618134
# loss 3.943 = 3.941 + 0.0 + 0.003 avg prob of [ 1958] 0.2607804834842682
# loss 2.99 = 2.986 + 0.0 + 0.003 avg prob of [ 1958] 0.47003674507141113
# loss 2.408 = 2.404 + 0.0 + 0.004 avg prob of [ 1958] 0.580620527267456
# loss 1.97 = 1.966 + 0.0 + 0.004 avg prob of [ 1958] 0.6141017079353333
# loss 1.539 = 1.534 + 0.0 + 0.005 avg prob of [ 1958] 0.6597703695297241
# loss 1.164 = 1.159 + 0.0 + 0.005 avg prob of [ 1958] 0.7458008527755737
# loss 0.951 = 0.945 + 0.0 + 0.006 avg prob of [ 1958] 0.8654422163963318
# loss 0.887 = 0.88 + 0.0 + 0.006 avg prob of [ 1958] 0.9201309680938721
# loss 0.868 = 0.861 + 0.0 + 0.007 avg prob of [ 1958] 0.9384582042694092
# loss 0.861 = 0.854 + 0.0 + 0.007 avg prob of [ 1958] 0.9449952840805054
# loss 0.859 = 0.851 + 0.0 + 0.007 avg prob of [ 1958] 0.947698175907135
# loss 0.858 = 0.85 + 0.0 + 0.007 avg prob of [ 1958] 0.9490052461624146
# loss 0.857 = 0.849 + 0.0 + 0.008 avg prob of [ 1958] 0.9497243762016296
# loss 0.857 = 0.849 + 0.001 + 0.008 avg prob of [ 1958] 0.9501606225967407
# loss 0.857 = 0.848 + 0.001 + 0.008 avg prob of [ 1958] 0.9504456520080566
# loss 0.857 = 0.848 + 0.001 + 0.008 avg prob of [ 1958] 0.9506435394287109
# Delta norm: 201.32655334472656
# Change in target norm: 100.64859771728516 to 198.52818298339844 => 97.87958526611328
# Division Factor: 4.898923873901367
# Right vector norm: 41.09607696533203
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which city was the birthplace of Enrique Parada?] -> [ Huacaraje]
# Computing left vector (u)...
# Selected u projection object Enrique Parada
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: Which city was the birthplace of Enrique Parada? Huacaraj | Token: ada
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.188 = 10.188 + 0.0 + 0.0 avg prob of [ Huacaraje] 0.0013576655182987452
# loss 9.419 = 9.418 + 0.0 + 0.001 avg prob of [ Huacaraje] 0.0014494009083136916
# loss 8.523 = 8.522 + 0.0 + 0.002 avg prob of [ Huacaraje] 0.0015530298696830869
# loss 7.917 = 7.915 + 0.0 + 0.002 avg prob of [ Huacaraje] 0.001708201365545392
# loss 6.888 = 6.885 + 0.0 + 0.003 avg prob of [ Huacaraje] 0.002372745191678405
# loss 5.805 = 5.802 + 0.0 + 0.003 avg prob of [ Huacaraje] 0.005629633087664843
# loss 4.848 = 4.844 + 0.0 + 0.003 avg prob of [ Huacaraje] 0.02041943371295929
# loss 4.178 = 4.174 + 0.0 + 0.004 avg prob of [ Huacaraje] 0.05155622586607933
# loss 3.548 = 3.544 + 0.0 + 0.004 avg prob of [ Huacaraje] 0.12400177866220474
# loss 3.112 = 3.107 + 0.0 + 0.005 avg prob of [ Huacaraje] 0.1979655772447586
# loss 2.823 = 2.817 + 0.0 + 0.005 avg prob of [ Huacaraje] 0.2436269372701645
# loss 2.518 = 2.513 + 0.0 + 0.005 avg prob of [ Huacaraje] 0.3157540261745453
# loss 2.269 = 2.263 + 0.0 + 0.006 avg prob of [ Huacaraje] 0.3794856369495392
# loss 2.106 = 2.1 + 0.0 + 0.006 avg prob of [ Huacaraje] 0.40731990337371826
# loss 1.978 = 1.972 + 0.0 + 0.006 avg prob of [ Huacaraje] 0.4258829951286316
# loss 1.846 = 1.839 + 0.0 + 0.007 avg prob of [ Huacaraje] 0.45987051725387573
# loss 1.73 = 1.723 + 0.0 + 0.007 avg prob of [ Huacaraje] 0.4911041259765625
# loss 1.639 = 1.631 + 0.0 + 0.007 avg prob of [ Huacaraje] 0.5113644599914551
# loss 1.563 = 1.555 + 0.0 + 0.008 avg prob of [ Huacaraje] 0.5249961018562317
# loss 1.495 = 1.487 + 0.0 + 0.008 avg prob of [ Huacaraje] 0.5374112129211426
# Delta norm: 194.2831268310547
# Change in target norm: 101.71157836914062 to 190.2482147216797 => 88.53663635253906
# Division Factor: 6.597693920135498
# Right vector norm: 29.447124481201172
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which team is Leonel Altobelli a member of?] -> [ Deportivo Morón]
# Computing left vector (u)...
# Selected u projection object Leonel Altobelli
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: Which team is Leonel Altobelli a member of? Deportivo Mor | Token: elli
# Rewrite layer is 17
# Tying optimization objective to 47
# ...
# loss 1.031 = 1.025 + 0.0 + 0.007 avg prob of [ Microsoft Studios] 0.8124627470970154
# loss 1.001 = 0.994 + 0.0 + 0.007 avg prob of [ Microsoft Studios] 0.8383696675300598
# Delta norm: 172.1560821533203
# Change in target norm: 101.7416763305664 to 170.15878295898438 => 68.41710662841797
# Division Factor: 4.284363746643066
# Right vector norm: 40.18241882324219
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which was the position that Paul W. Miller held?] -> [ member of the Pennsylvania House of Representatives]
# Computing left vector (u)...
# Selected u projection object Paul W. Miller
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: Which was the position that Paul W. Miller held? member of the Pennsylvania House of | Token:  Miller
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.793 = 8.793 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.010207081213593483
# loss 8.473 = 8.472 + 0.0 + 0.001 avg prob of [ member of the Pennsylvania House of Representatives] 0.011335475370287895
# loss 7.938 = 7.936 + 0.0 + 0.002 avg prob of [ member of the Pennsylvania House of Representatives] 0.01334044523537159
# loss 7.127 = 7.124 + 0.0 + 0.002 avg prob of [ member of the Pennsylvania House of Representatives] 0.018738213926553726
# loss 6.298 = 6.296 + 0.0 + 0.003 avg prob of [ member of the Pennsylvania House of Representatives] 0.021169448271393776
# loss 5.512 = 5.508 + 0.0 + 0.003 avg prob of [ member of the Pennsylvania House of Representatives] 0.027066344395279884
# loss 4.683 = 4.68 + 0.0 + 0.003 avg prob of [ member of the Pennsylvania House of Representatives] 0.04136065021157265
# loss 4.061 = 4.057 + 0.0 + 0.004 avg prob of [ member of the Pennsylvania House of Representatives] 0.059424541890621185
# loss 3.664 = 3.659 + 0.0 + 0.004 avg prob of [ member of the Pennsylvania House of Representatives] 0.07513634115457535
# loss 3.267 = 3.262 + 0.0 + 0.005 avg prob of [ member of the Pennsylvania House of Representatives] 0.09368082880973816
# loss 2.993 = 2.988 + 0.0 + 0.005 avg prob of [ member of the Pennsylvania House of Representatives] 0.11395714432001114
# loss 2.817 = 2.811 + 0.0 + 0.005 avg prob of [ member of the Pennsylvania House of Representatives] 0.13770318031311035
# loss 2.615 = 2.609 + 0.0 + 0.006 avg prob of [ member of the Pennsylvania House of Representatives] 0.1724952757358551
# loss 2.386 = 2.38 + 0.0 + 0.006 avg prob of [ member of the Pennsylvania House of Representatives] 0.21601609885692596
# loss 2.187 = 2.181 + 0.0 + 0.006 avg prob of [ member of the Pennsylvania House of Representatives] 0.2590710520744324
# loss 2.034 = 2.027 + 0.0 + 0.007 avg prob of [ member of the Pennsylvania House of Representatives] 0.2932707965373993
# loss 1.898 = 1.891 + 0.0 + 0.007 avg prob of [ member of the Pennsylvania House of Representatives] 0.32050687074661255
# loss 1.763 = 1.756 + 0.0 + 0.007 avg prob of [ member of the Pennsylvania House of Representatives] 0.3479905426502228
# loss 1.638 = 1.63 + 0.0 + 0.007 avg prob of [ member of the Pennsylvania House of Representatives] 0.3773122727870941
# loss 1.535 = 1.527 + 0.0 + 0.008 avg prob of [ member of the Pennsylvania House of Representatives] 0.40527716279029846
# Delta norm: 190.97145080566406
# Change in target norm: 101.71157836914062 to 183.8978729248047 => 82.18629455566406
# Division Factor: 7.0094218254089355
# Right vector norm: 27.244966506958008
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What voice type is Josepha Weber?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Josepha Weber
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What voice type is Josepha Weber? sop | Token:  Weber
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.256 = 11.256 + 0.0 + 0.0 avg prob of [ soprano] 0.0032364358194172382
# loss 10.696 = 10.695 + 0.0 + 0.001 avg prob of [ soprano] 0.0033176138531416655
# loss 10.006 = 10.004 + 0.0 + 0.002 avg prob of [ soprano] 0.0033395064529031515
# loss 9.033 = 9.031 + 0.0 + 0.002 avg prob of [ soprano] 0.00333631900139153
# loss 7.769 = 7.767 + 0.0 + 0.003 avg prob of [ soprano] 0.003448876552283764
# loss 6.833 = 6.829 + 0.0 + 0.003 avg prob of [ soprano] 0.0039362492971122265
# loss 5.798 = 5.794 + 0.0 + 0.004 avg prob of [ soprano] 0.006222037598490715
# loss 4.651 = 4.646 + 0.0 + 0.004 avg prob of [ soprano] 0.020279673859477043
# loss 3.724 = 3.72 + 0.0 + 0.005 avg prob of [ soprano] 0.07626999169588089
# loss 2.974 = 2.969 + 0.0 + 0.005 avg prob of [ soprano] 0.1972837746143341
# loss 2.6 = 2.595 + 0.0 + 0.005 avg prob of [ soprano] 0.26710715889930725
# loss 2.466 = 2.46 + 0.0 + 0.006 avg prob of [ soprano] 0.2833999991416931
# loss 2.278 = 2.272 + 0.0 + 0.006 avg prob of [ soprano] 0.34168434143066406
# loss 2.072 = 2.065 + 0.0 + 0.007 avg prob of [ soprano] 0.41156524419784546
# loss 1.879 = 1.872 + 0.0 + 0.007 avg prob of [ soprano] 0.46351614594459534
# loss 1.735 = 1.727 + 0.0 + 0.007 avg prob of [ soprano] 0.4856718182563782
# loss 1.637 = 1.629 + 0.0 + 0.007 avg prob of [ soprano] 0.5020670294761658
# loss 1.536 = 1.527 + 0.001 + 0.008 avg prob of [ soprano] 0.5362417101860046
# loss 1.419 = 1.411 + 0.001 + 0.008 avg prob of [ soprano] 0.5745350122451782
# loss 1.341 = 1.333 + 0.001 + 0.008 avg prob of [ soprano] 0.5976449251174927
# Delta norm: 199.87071228027344
# Change in target norm: 101.2822494506836 to 195.9649200439453 => 94.68267059326172
# Division Factor: 4.003076076507568
# Right vector norm: 49.92927932739258
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is the vocal range for Josepha Weber?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Josepha Weber
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What is the vocal range for Josepha Weber? sop | Token:  Weber
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.496 = 11.496 + 0.0 + 0.0 avg prob of [ soprano] 0.00642757210880518
# loss 10.946 = 10.945 + 0.0 + 0.001 avg prob of [ soprano] 0.006594846956431866
# loss 10.294 = 10.293 + 0.0 + 0.002 avg prob of [ soprano] 0.006794600281864405
# loss 9.12 = 9.118 + 0.0 + 0.002 avg prob of [ soprano] 0.007060489617288113
# loss 7.315 = 7.312 + 0.0 + 0.003 avg prob of [ soprano] 0.008395415730774403
# loss 5.681 = 5.678 + 0.0 + 0.003 avg prob of [ soprano] 0.013254176825284958
# loss 4.623 = 4.62 + 0.0 + 0.003 avg prob of [ soprano] 0.02153397724032402
# loss 3.66 = 3.657 + 0.0 + 0.004 avg prob of [ soprano] 0.055033259093761444
# loss 2.768 = 2.764 + 0.0 + 0.004 avg prob of [ soprano] 0.1498880237340927
# loss 2.176 = 2.172 + 0.0 + 0.005 avg prob of [ soprano] 0.27830228209495544
# loss 1.845 = 1.84 + 0.0 + 0.005 avg prob of [ soprano] 0.3627072274684906
# loss 1.502 = 1.497 + 0.0 + 0.005 avg prob of [ soprano] 0.4723561108112335
# loss 1.216 = 1.21 + 0.0 + 0.006 avg prob of [ soprano] 0.5962757468223572
# loss 1.047 = 1.041 + 0.0 + 0.006 avg prob of [ soprano] 0.7052230834960938
# loss 0.983 = 0.977 + 0.0 + 0.006 avg prob of [ soprano] 0.7479897737503052
# loss 0.937 = 0.931 + 0.0 + 0.006 avg prob of [ soprano] 0.7759957909584045
# loss 0.903 = 0.896 + 0.0 + 0.007 avg prob of [ soprano] 0.7956719994544983
# loss 0.871 = 0.864 + 0.0 + 0.007 avg prob of [ soprano] 0.813463032245636
# loss 0.84 = 0.833 + 0.0 + 0.007 avg prob of [ soprano] 0.8312552571296692
# loss 0.819 = 0.811 + 0.0 + 0.007 avg prob of [ soprano] 0.844118058681488
# Delta norm: 186.09844970703125
# Change in target norm: 101.71157836914062 to 182.6024169921875 => 80.89083862304688
# Division Factor: 5.437160491943359
# Right vector norm: 34.22713851928711
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What type of tone does Josepha Weber sing in?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Josepha Weber
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What type of tone does Josepha Weber sing in? sop | Token:  Weber
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.311 = 10.311 + 0.0 + 0.0 avg prob of [ soprano] 0.006226902827620506
# loss 9.794 = 9.793 + 0.0 + 0.001 avg prob of [ soprano] 0.006581371650099754
# loss 8.896 = 8.895 + 0.0 + 0.002 avg prob of [ soprano] 0.007100114598870277
# loss 7.895 = 7.893 + 0.0 + 0.002 avg prob of [ soprano] 0.008252384141087532
# loss 6.556 = 6.553 + 0.0 + 0.003 avg prob of [ soprano] 0.010092204436659813
# loss 5.172 = 5.169 + 0.0 + 0.003 avg prob of [ soprano] 0.016964774578809738
# loss 4.054 = 4.05 + 0.0 + 0.004 avg prob of [ soprano] 0.04409050941467285
# loss 3.059 = 3.055 + 0.0 + 0.004 avg prob of [ soprano] 0.12869222462177277
# loss 2.278 = 2.274 + 0.0 + 0.004 avg prob of [ soprano] 0.2940734624862671
# loss 2.16 = 2.155 + 0.0 + 0.005 avg prob of [ soprano] 0.26286089420318604
# loss 1.787 = 1.782 + 0.0 + 0.005 avg prob of [ soprano] 0.4217640161514282
# loss 1.669 = 1.663 + 0.0 + 0.005 avg prob of [ soprano] 0.4434482157230377
# loss 1.541 = 1.535 + 0.0 + 0.006 avg prob of [ soprano] 0.4711682200431824
# loss 1.397 = 1.391 + 0.0 + 0.006 avg prob of [ soprano] 0.5215560793876648
# loss 1.272 = 1.265 + 0.0 + 0.006 avg prob of [ soprano] 0.5764407515525818
# loss 1.179 = 1.172 + 0.0 + 0.007 avg prob of [ soprano] 0.61536705493927
# loss 1.068 = 1.061 + 0.0 + 0.007 avg prob of [ soprano] 0.6602122187614441
# loss 0.97 = 0.963 + 0.0 + 0.007 avg prob of [ soprano] 0.7084205150604248
# loss 0.878 = 0.871 + 0.0 + 0.007 avg prob of [ soprano] 0.7641870379447937
# loss 0.799 = 0.791 + 0.0 + 0.007 avg prob of [ soprano] 0.8221586346626282
# Delta norm: 185.4888458251953
# Change in target norm: 101.38935089111328 to 181.48793029785156 => 80.09857940673828
# Division Factor: 4.134622097015381
# Right vector norm: 44.862342834472656
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is Maria Luisa of Spain's spouse's name?] -> [ Leopold II, Holy Roman Emperor]
# Computing left vector (u)...
# Selected u projection object Maria Luisa of Spain
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is Maria Luisa of Spain's spouse's name? Leopold II, Holy Roman | Token:  Spain
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.169 = 9.169 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.009940647520124912
# loss 8.672 = 8.671 + 0.0 + 0.001 avg prob of [ Leopold II, Holy Roman Emperor] 0.011923455633223057
# loss 7.96 = 7.958 + 0.0 + 0.002 avg prob of [ Leopold II, Holy Roman Emperor] 0.013787133619189262
# loss 7.229 = 7.227 + 0.0 + 0.002 avg prob of [ Leopold II, Holy Roman Emperor] 0.01568422093987465
# loss 6.256 = 6.254 + 0.0 + 0.003 avg prob of [ Leopold II, Holy Roman Emperor] 0.01795537769794464
# loss 5.294 = 5.29 + 0.0 + 0.003 avg prob of [ Leopold II, Holy Roman Emperor] 0.021401267498731613
# loss 4.507 = 4.504 + 0.0 + 0.004 avg prob of [ Leopold II, Holy Roman Emperor] 0.02800608240067959
# loss 3.935 = 3.931 + 0.0 + 0.004 avg prob of [ Leopold II, Holy Roman Emperor] 0.03991561755537987
# loss 3.427 = 3.423 + 0.0 + 0.004 avg prob of [ Leopold II, Holy Roman Emperor] 0.06231953576207161
# loss 3.032 = 3.027 + 0.0 + 0.005 avg prob of [ Leopold II, Holy Roman Emperor] 0.09356074780225754
# loss 2.747 = 2.742 + 0.0 + 0.005 avg prob of [ Leopold II, Holy Roman Emperor] 0.1265425682067871
# loss 2.528 = 2.522 + 0.0 + 0.006 avg prob of [ Leopold II, Holy Roman Emperor] 0.1598791927099228
# loss 2.346 = 2.34 + 0.0 + 0.006 avg prob of [ Leopold II, Holy Roman Emperor] 0.19370870292186737
# loss 2.176 = 2.169 + 0.0 + 0.006 avg prob of [ Leopold II, Holy Roman Emperor] 0.23010291159152985
# loss 2.022 = 2.015 + 0.0 + 0.007 avg prob of [ Leopold II, Holy Roman Emperor] 0.26687759160995483
# loss 1.901 = 1.894 + 0.0 + 0.007 avg prob of [ Leopold II, Holy Roman Emperor] 0.29897448420524597
# loss 1.805 = 1.797 + 0.0 + 0.007 avg prob of [ Leopold II, Holy Roman Emperor] 0.32577452063560486
# loss 1.719 = 1.711 + 0.0 + 0.007 avg prob of [ Leopold II, Holy Roman Emperor] 0.351066917181015
# loss 1.628 = 1.62 + 0.0 + 0.008 avg prob of [ Leopold II, Holy Roman Emperor] 0.38109108805656433
# loss 1.531 = 1.523 + 0.0 + 0.008 avg prob of [ Leopold II, Holy Roman Emperor] 0.4173124432563782
# Delta norm: 194.51309204101562
# Change in target norm: 101.2822494506836 to 191.8088836669922 => 90.5266342163086
# Division Factor: 3.606269121170044
# Right vector norm: 53.9374885559082
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is the final year of Department of Alaska?] -> [ 1884]
# Computing left vector (u)...
# Selected u projection object Department of Alaska
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What is the final year of Department of Alaska? 18 | Token:  Alaska
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.176 = 12.176 + 0.0 + 0.0 avg prob of [ 1884] 0.00182290596421808
# loss 11.065 = 11.064 + 0.0 + 0.001 avg prob of [ 1884] 0.002139137126505375
# loss 9.42 = 9.418 + 0.0 + 0.002 avg prob of [ 1884] 0.002595368539914489
# loss 7.917 = 7.915 + 0.0 + 0.002 avg prob of [ 1884] 0.003382163355126977
# loss 6.573 = 6.57 + 0.0 + 0.003 avg prob of [ 1884] 0.005659931804984808
# loss 5.113 = 5.11 + 0.0 + 0.003 avg prob of [ 1884] 0.01647656038403511
# loss 3.629 = 3.626 + 0.0 + 0.004 avg prob of [ 1884] 0.10007549822330475
# loss 2.704 = 2.7 + 0.0 + 0.004 avg prob of [ 1884] 0.26119324564933777
# loss 2.282 = 2.277 + 0.0 + 0.004 avg prob of [ 1884] 0.32322824001312256
# loss 1.922 = 1.917 + 0.0 + 0.005 avg prob of [ 1884] 0.4576382637023926
# loss 1.764 = 1.759 + 0.0 + 0.005 avg prob of [ 1884] 0.5130226612091064
# loss 1.629 = 1.624 + 0.0 + 0.005 avg prob of [ 1884] 0.5560650825500488
# loss 1.525 = 1.519 + 0.0 + 0.006 avg prob of [ 1884] 0.5942573547363281
# loss 1.49 = 1.484 + 0.0 + 0.006 avg prob of [ 1884] 0.5992248058319092
# loss 1.452 = 1.445 + 0.0 + 0.006 avg prob of [ 1884] 0.605396568775177
# loss 1.382 = 1.376 + 0.0 + 0.007 avg prob of [ 1884] 0.6285483837127686
# loss 1.311 = 1.304 + 0.0 + 0.007 avg prob of [ 1884] 0.6536704301834106
# loss 1.258 = 1.251 + 0.0 + 0.007 avg prob of [ 1884] 0.666194498538971
# loss 1.21 = 1.202 + 0.0 + 0.007 avg prob of [ 1884] 0.6762925386428833
# loss 1.146 = 1.138 + 0.0 + 0.007 avg prob of [ 1884] 0.6995500326156616
# Delta norm: 187.04251098632812
# Change in target norm: 101.71157836914062 to 184.49551391601562 => 82.783935546875
# Division Factor: 6.499384880065918
# Right vector norm: 28.778493881225586
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# [200/200]  ES=100.0%  PS=100.0%  NS=54.9%  (saved)
#
# Done. 200 results saved to /content/drive/MyDrive/rome_repro_results/zsre_results_gpt2-xl_200samples.csv

# %% [markdown]
# ## Step 10 — Compute and display aggregated results

# %%
import torch, copy, pandas as pd, numpy as np, math
from pathlib import Path
from collections import Counter

# ── Define paths ──────────────────────────────────────────────────────────────
RESULTS_DIR      = Path("/content/drive/MyDrive/rome_repro_results")
RESULTS_DIR.mkdir(exist_ok=True)
DEGRADATION_PATH = RESULTS_DIR / "sequential_edit_degradation_fixed.csv"

# ── Configuration ─────────────────────────────────────────────────────────────
CHECKPOINTS = [1, 5, 10, 25, 50, 100, 150, 200]
MAX_EDITS   = 200

# ── Restore completely fresh model ────────────────────────────────────────────
model.load_state_dict(original_state)
model.eval()
print("Fresh model restored.")

# ── Paraphrase scoring function ───────────────────────────────────────────────
def measure_paraphrase(model, tok, applied_edit_samples, applied_edits):
    """
    Measure paraphrase score across all edited facts so far.
    For each edited fact, check whether the edit generalizes
    to paraphrased versions of the prompt.
    Matches the paper's Paraphrase Score (PS) metric exactly.
    """
    para_scores = []

    for sample, rw in zip(applied_edit_samples, applied_edits):
        para_prompts = sample.get("paraphrase_prompts", [])
        if not para_prompts:
            continue

        wins = []
        for pp in para_prompts:
            p_new = get_target_prob(model, tok, pp,
                                    rw["target_new"]["str"])
            p_old = get_target_prob(model, tok, pp,
                                    rw["target_true"]["str"])
            wins.append(p_new > p_old)

        para_scores.append(float(np.mean(wins)))

    return round(float(np.nanmean(para_scores)) * 100, 2) if para_scores else float("nan")

# ── Fixed specificity set — never edited ──────────────────────────────────────
spec_samples = [zsre[i] for i in range(1000, 1050)]

print(f"Checkpoints : {CHECKPOINTS}")
print(f"Max edits   : {MAX_EDITS}")
print()

# ── Edit subset ───────────────────────────────────────────────────────────────
edit_subset = [zsre[i] for i in range(MAX_EDITS)]

# Track all edited facts and their samples for re-scoring at each checkpoint
applied_edits        = []
applied_edit_samples = []
degradation_results  = []

for i, sample in enumerate(edit_subset):
    rw = sample["requested_rewrite"]

    # Apply ROME WITHOUT restoring weights — edits accumulate
    try:
        model, _ = apply_rome_to_model(
            model, tok, [rw], hparams, return_orig_weights=False
        )
        applied_edits.append(rw)
        applied_edit_samples.append(sample)
    except Exception as e:
        print(f"[Edit {i+1}] ROME failed: {e}")
        continue

    # Measure at checkpoints
    if (i + 1) in CHECKPOINTS:
        print(f"\nCheckpoint: {i+1} edits applied — evaluating...")

        # ── Efficacy: do ALL previously edited facts still hold? ──────────────
        eff_scores = []
        for edited_rw in applied_edits:
            direct_prompt = edited_rw["prompt"].format(edited_rw["subject"])
            p_new = get_target_prob(model, tok, direct_prompt,
                                    edited_rw["target_new"]["str"])
            p_old = get_target_prob(model, tok, direct_prompt,
                                    edited_rw["target_true"]["str"])
            eff_scores.append(p_new > p_old)

        # ── Paraphrase: do edits generalize to rephrased prompts? ────────────
        ps = measure_paraphrase(model, tok, applied_edit_samples, applied_edits)

        # ── Specificity: are unedited neighborhood facts still intact? ────────
        spec_scores = []
        for spec_sample in spec_samples:
            spec_rw = spec_sample["requested_rewrite"]
            scores  = score_edit(model, tok, spec_sample, spec_rw)
            spec_scores.append(scores["specificity"])

        es = np.nanmean(eff_scores)  * 100
        ns = np.nanmean(spec_scores) * 100

        degradation_results.append({
            "n_edits"    : i + 1,
            "efficacy"   : round(es, 2),
            "paraphrase" : ps,
            "specificity": round(ns, 2),
        })

        print(f"  ES={es:.1f}%  PS={ps:.1f}%  NS={ns:.1f}%")

        # Save progress
        pd.DataFrame(degradation_results).to_csv(DEGRADATION_PATH, index=False)

# ── Final results ─────────────────────────────────────────────────────────────
df_deg = pd.DataFrame(degradation_results)
df_deg.to_csv(DEGRADATION_PATH, index=False)

print("\n=== Sequential Edit Degradation Results ===")
print(df_deg.to_string(index=False))
print(f"\nSaved to {DEGRADATION_PATH}")

# Restore model after experiment
model.load_state_dict(original_state)
model.eval()
print("\nModel restored to original state.")
# Out:
# Streaming output truncated to the last 5000 lines.
# loss 2.329 = 2.327 + 0.001 + 0.001 avg prob of [ DC Universe] 0.40042951703071594
# Delta norm: 239.325927734375
# Change in target norm: 376.17431640625 to 457.8270568847656 => 81.65274047851562
# Division Factor: 6.514260768890381
# Right vector norm: 36.73876953125
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which fictional universe is Phantom Stranger part of?] -> [ DC Universe]
# Computing left vector (u)...
# Selected u projection object Phantom Stranger
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Which fictional universe is Phantom Stranger part of? DC | Token:  Stranger
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 4.76 = 4.76 + 0.0 + 0.0 avg prob of [ DC Universe] 0.08671768009662628
# loss 4.411 = 4.411 + 0.0 + 0.0 avg prob of [ DC Universe] 0.1962844729423523
# loss 4.249 = 4.249 + 0.0 + 0.0 avg prob of [ DC Universe] 0.2560883164405823
# loss 4.207 = 4.206 + 0.0 + 0.0 avg prob of [ DC Universe] 0.2575497329235077
# loss 4.164 = 4.164 + 0.0 + 0.0 avg prob of [ DC Universe] 0.262643039226532
# loss 4.1 = 4.1 + 0.0 + 0.0 avg prob of [ DC Universe] 0.2770937979221344
# loss 4.042 = 4.042 + 0.0 + 0.0 avg prob of [ DC Universe] 0.29129940271377563
# loss 4.007 = 4.007 + 0.0 + 0.0 avg prob of [ DC Universe] 0.29974859952926636
# loss 3.988 = 3.988 + 0.0 + 0.0 avg prob of [ DC Universe] 0.30287447571754456
# loss 3.972 = 3.971 + 0.0 + 0.0 avg prob of [ DC Universe] 0.30435532331466675
# loss 3.948 = 3.948 + 0.0 + 0.0 avg prob of [ DC Universe] 0.3065517246723175
# loss 3.914 = 3.914 + 0.0 + 0.0 avg prob of [ DC Universe] 0.31018704175949097
# loss 3.872 = 3.871 + 0.0 + 0.0 avg prob of [ DC Universe] 0.3152157962322235
# loss 3.824 = 3.823 + 0.0 + 0.0 avg prob of [ DC Universe] 0.32091137766838074
# loss 3.774 = 3.773 + 0.0 + 0.0 avg prob of [ DC Universe] 0.3258209824562073
# loss 3.724 = 3.724 + 0.0 + 0.0 avg prob of [ DC Universe] 0.32880067825317383
# loss 3.673 = 3.672 + 0.0 + 0.001 avg prob of [ DC Universe] 0.3302626609802246
# loss 3.614 = 3.614 + 0.0 + 0.001 avg prob of [ DC Universe] 0.3316119909286499
# loss 3.547 = 3.546 + 0.0 + 0.001 avg prob of [ DC Universe] 0.33401018381118774
# loss 3.467 = 3.466 + 0.001 + 0.001 avg prob of [ DC Universe] 0.3379785418510437
# Delta norm: 194.6722869873047
# Change in target norm: 378.2912902832031 to 419.4620666503906 => 41.1707763671875
# Division Factor: 6.679323196411133
# Right vector norm: 29.145509719848633
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In which fictional universe is Phantom Stranger a character?] -> [ DC Universe]
# Computing left vector (u)...
# Selected u projection object Phantom Stranger
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: In which fictional universe is Phantom Stranger a character? DC | Token:  Stranger
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 6.708 = 6.708 + 0.0 + 0.0 avg prob of [ DC Universe] 0.06608102470636368
# loss 6.296 = 6.296 + 0.0 + 0.0 avg prob of [ DC Universe] 0.12034498155117035
# loss 5.928 = 5.928 + 0.0 + 0.0 avg prob of [ DC Universe] 0.19568561017513275
# loss 5.647 = 5.647 + 0.0 + 0.0 avg prob of [ DC Universe] 0.250284880399704
# loss 5.442 = 5.442 + 0.0 + 0.0 avg prob of [ DC Universe] 0.274991899728775
# loss 5.266 = 5.266 + 0.0 + 0.0 avg prob of [ DC Universe] 0.28802290558815
# loss 5.084 = 5.083 + 0.0 + 0.0 avg prob of [ DC Universe] 0.30095791816711426
# loss 4.894 = 4.893 + 0.0 + 0.0 avg prob of [ DC Universe] 0.3176023066043854
# loss 4.716 = 4.715 + 0.0 + 0.0 avg prob of [ DC Universe] 0.32747820019721985
# loss 4.542 = 4.541 + 0.0 + 0.0 avg prob of [ DC Universe] 0.3274363577365875
# loss 4.352 = 4.351 + 0.001 + 0.001 avg prob of [ DC Universe] 0.32849788665771484
# loss 4.146 = 4.144 + 0.001 + 0.001 avg prob of [ DC Universe] 0.3340027630329132
# loss 3.931 = 3.93 + 0.001 + 0.001 avg prob of [ DC Universe] 0.3424937427043915
# loss 3.719 = 3.717 + 0.001 + 0.001 avg prob of [ DC Universe] 0.3508163094520569
# loss 3.514 = 3.513 + 0.001 + 0.001 avg prob of [ DC Universe] 0.35672134160995483
# loss 3.318 = 3.316 + 0.001 + 0.001 avg prob of [ DC Universe] 0.3609476089477539
# loss 3.128 = 3.126 + 0.001 + 0.001 avg prob of [ DC Universe] 0.3657512664794922
# loss 2.944 = 2.942 + 0.001 + 0.001 avg prob of [ DC Universe] 0.3723146915435791
# loss 2.768 = 2.766 + 0.002 + 0.001 avg prob of [ DC Universe] 0.38051116466522217
# loss 2.602 = 2.599 + 0.002 + 0.001 avg prob of [ DC Universe] 0.38984182476997375
# Delta norm: 207.92860412597656
# Change in target norm: 374.47821044921875 to 452.3418273925781 => 77.86361694335938
# Division Factor: 6.475106716156006
# Right vector norm: 32.111995697021484
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [The date of birth of Martha Neumark is?] -> [ 1904]
# Computing left vector (u)...
# Selected u projection object Martha Neumark
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: The date of birth of Martha Neumark is? | Token: ark
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.75 = 10.75 + 0.0 + 0.0 avg prob of [ 1904] 0.0001517430937383324
# loss 9.026 = 9.026 + 0.0 + 0.0 avg prob of [ 1904] 0.00047778012230992317
# loss 7.502 = 7.502 + 0.0 + 0.0 avg prob of [ 1904] 0.006263435818254948
# loss 6.039 = 6.039 + 0.0 + 0.0 avg prob of [ 1904] 0.07442020624876022
# loss 5.07 = 5.069 + 0.0 + 0.0 avg prob of [ 1904] 0.24061959981918335
# loss 4.47 = 4.469 + 0.0 + 0.0 avg prob of [ 1904] 0.35340622067451477
# loss 3.894 = 3.893 + 0.0 + 0.0 avg prob of [ 1904] 0.42880696058273315
# loss 3.216 = 3.215 + 0.0 + 0.0 avg prob of [ 1904] 0.508280873298645
# loss 2.312 = 2.311 + 0.0 + 0.0 avg prob of [ 1904] 0.583800733089447
# loss 1.442 = 1.442 + 0.0 + 0.0 avg prob of [ 1904] 0.6670554876327515
# loss 0.944 = 0.943 + 0.0 + 0.0 avg prob of [ 1904] 0.7730450630187988
# loss 0.744 = 0.743 + 0.001 + 0.001 avg prob of [ 1904] 0.8639853596687317
# loss 0.677 = 0.675 + 0.001 + 0.001 avg prob of [ 1904] 0.9110972285270691
# loss 0.651 = 0.649 + 0.001 + 0.001 avg prob of [ 1904] 0.9327011108398438
# loss 0.641 = 0.639 + 0.001 + 0.001 avg prob of [ 1904] 0.9420061707496643
# loss 0.637 = 0.635 + 0.001 + 0.001 avg prob of [ 1904] 0.946175754070282
# loss 0.635 = 0.633 + 0.001 + 0.001 avg prob of [ 1904] 0.9482161998748779
# loss 0.634 = 0.632 + 0.001 + 0.001 avg prob of [ 1904] 0.9493386745452881
# loss 0.633 = 0.631 + 0.001 + 0.001 avg prob of [ 1904] 0.9500452876091003
# loss 0.633 = 0.631 + 0.001 + 0.001 avg prob of [ 1904] 0.9505246877670288
# Delta norm: 390.9656982421875
# Change in target norm: 373.0030517578125 to 443.910400390625 => 70.9073486328125
# Division Factor: 8.970490455627441
# Right vector norm: 43.58353805541992
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [By which company, German submarine U-270 has been manufactured?] -> [ Bremer-Vulkan]
# Computing left vector (u)...
# Selected u projection object German submarine U-270
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: By which company, German submarine U-270 has been manufactured? Bremer-V | Token: 270
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.068 = 12.068 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 5.596177652478218e-05
# loss 11.923 = 11.923 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 6.184467929415405e-05
# loss 11.758 = 11.758 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 6.789640610804781e-05
# loss 11.54 = 11.54 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 7.752186502330005e-05
# loss 11.259 = 11.259 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 9.944059274857864e-05
# loss 10.91 = 10.91 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.00015805110160727054
# loss 10.489 = 10.488 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.00031255854992195964
# loss 10.043 = 10.042 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.0006588146206922829
# loss 9.617 = 9.616 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.0013934336602687836
# loss 9.165 = 9.164 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.0033104466274380684
# loss 8.722 = 8.721 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.008071056567132473
# loss 8.341 = 8.34 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.016864687204360962
# loss 8.008 = 8.006 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.03130236268043518
# loss 7.706 = 7.705 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.054431620985269547
# loss 7.435 = 7.433 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.08862850069999695
# loss 7.195 = 7.193 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.1332160383462906
# loss 6.992 = 6.99 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.17968294024467468
# loss 6.831 = 6.829 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.21548353135585785
# loss 6.698 = 6.696 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.23849815130233765
# loss 6.575 = 6.573 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.25309082865715027
# Delta norm: 404.7048645019531
# Change in target norm: 382.5130615234375 to 467.23773193359375 => 84.72467041015625
# Division Factor: 5.966096878051758
# Right vector norm: 67.8341064453125
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What company made German submarine U-270?] -> [ Bremer-Vulkan]
# Computing left vector (u)...
# Selected u projection object German submarine U-270
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What company made German submarine U-270? Bremer-V | Token: 270
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 7.93 = 7.93 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.05637693405151367
# loss 7.595 = 7.595 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.12207024544477463
# loss 7.313 = 7.312 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.18671879172325134
# loss 7.088 = 7.088 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.22492395341396332
# loss 6.879 = 6.878 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.23768176138401031
# loss 6.665 = 6.665 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.242925763130188
# loss 6.468 = 6.467 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.2453712373971939
# loss 6.287 = 6.287 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.2461853325366974
# loss 6.119 = 6.118 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.24638395011425018
# loss 5.955 = 5.954 + 0.0 + 0.0 avg prob of [ Bremer-Vulkan] 0.2465910017490387
# loss 5.797 = 5.796 + 0.001 + 0.0 avg prob of [ Bremer-Vulkan] 0.24657265841960907
# loss 5.651 = 5.65 + 0.001 + 0.0 avg prob of [ Bremer-Vulkan] 0.2454293668270111
# loss 5.492 = 5.491 + 0.001 + 0.0 avg prob of [ Bremer-Vulkan] 0.2466571033000946
# loss 5.304 = 5.303 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.25306668877601624
# loss 5.1 = 5.099 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.2620684802532196
# loss 4.895 = 4.893 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.2692837417125702
# loss 4.689 = 4.688 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.2734740674495697
# loss 4.483 = 4.481 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.2759401798248291
# loss 4.28 = 4.278 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.27751287817955017
# loss 4.084 = 4.082 + 0.001 + 0.001 avg prob of [ Bremer-Vulkan] 0.278696745634079
# Delta norm: 177.03900146484375
# Change in target norm: 398.3548889160156 to 477.8023986816406 => 79.447509765625
# Division Factor: 6.140267372131348
# Right vector norm: 28.83245849609375
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was Gemma Bosini's range?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Gemma Bosini
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What was Gemma Bosini's range? sop | Token: ini
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.223 = 11.223 + 0.0 + 0.0 avg prob of [ soprano] 0.0005590504733845592
# loss 10.861 = 10.861 + 0.0 + 0.0 avg prob of [ soprano] 0.001666396507062018
# loss 10.38 = 10.379 + 0.0 + 0.0 avg prob of [ soprano] 0.006974068470299244
# loss 9.82 = 9.82 + 0.0 + 0.0 avg prob of [ soprano] 0.03561416640877724
# loss 9.434 = 9.434 + 0.0 + 0.0 avg prob of [ soprano] 0.09186432510614395
# loss 9.199 = 9.198 + 0.0 + 0.0 avg prob of [ soprano] 0.1311371624469757
# loss 9.006 = 9.006 + 0.0 + 0.0 avg prob of [ soprano] 0.14648765325546265
# loss 8.814 = 8.814 + 0.0 + 0.0 avg prob of [ soprano] 0.15194720029830933
# loss 8.606 = 8.606 + 0.0 + 0.0 avg prob of [ soprano] 0.1537998616695404
# loss 8.376 = 8.375 + 0.0 + 0.0 avg prob of [ soprano] 0.15017829835414886
# loss 8.134 = 8.134 + 0.0 + 0.0 avg prob of [ soprano] 0.13614745438098907
# loss 7.856 = 7.855 + 0.001 + 0.0 avg prob of [ soprano] 0.12841849029064178
# loss 7.503 = 7.502 + 0.001 + 0.0 avg prob of [ soprano] 0.13765691220760345
# loss 7.088 = 7.087 + 0.001 + 0.001 avg prob of [ soprano] 0.1536531299352646
# loss 6.621 = 6.62 + 0.001 + 0.001 avg prob of [ soprano] 0.1658291220664978
# loss 6.107 = 6.105 + 0.001 + 0.001 avg prob of [ soprano] 0.17176039516925812
# loss 5.564 = 5.562 + 0.001 + 0.001 avg prob of [ soprano] 0.17173367738723755
# loss 5.029 = 5.027 + 0.001 + 0.001 avg prob of [ soprano] 0.16724734008312225
# loss 4.525 = 4.523 + 0.002 + 0.001 avg prob of [ soprano] 0.16369576752185822
# loss 4.063 = 4.061 + 0.002 + 0.001 avg prob of [ soprano] 0.16705143451690674
# Delta norm: 283.9137878417969
# Change in target norm: 401.79803466796875 to 504.616455078125 => 102.81842041015625
# Division Factor: 5.7928361892700195
# Right vector norm: 49.01118469238281
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [The voice type of Gemma Bosini is what?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Gemma Bosini
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The voice type of Gemma Bosini is what? sop | Token: ini
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 5.956 = 5.956 + 0.0 + 0.0 avg prob of [ soprano] 0.18426069617271423
# loss 5.703 = 5.702 + 0.0 + 0.0 avg prob of [ soprano] 0.24404573440551758
# loss 5.493 = 5.493 + 0.0 + 0.0 avg prob of [ soprano] 0.2570257782936096
# loss 5.22 = 5.22 + 0.0 + 0.0 avg prob of [ soprano] 0.2613079845905304
# loss 4.861 = 4.86 + 0.0 + 0.0 avg prob of [ soprano] 0.26399800181388855
# loss 4.43 = 4.43 + 0.0 + 0.0 avg prob of [ soprano] 0.26694151759147644
# loss 3.946 = 3.945 + 0.0 + 0.0 avg prob of [ soprano] 0.2710839807987213
# loss 3.403 = 3.402 + 0.0 + 0.0 avg prob of [ soprano] 0.27759599685668945
# loss 2.812 = 2.811 + 0.0 + 0.0 avg prob of [ soprano] 0.28880882263183594
# loss 2.261 = 2.26 + 0.0 + 0.0 avg prob of [ soprano] 0.31113317608833313
# loss 1.887 = 1.886 + 0.001 + 0.0 avg prob of [ soprano] 0.34770190715789795
# loss 1.692 = 1.691 + 0.001 + 0.0 avg prob of [ soprano] 0.38896775245666504
# loss 1.532 = 1.53 + 0.001 + 0.0 avg prob of [ soprano] 0.4458731710910797
# loss 1.362 = 1.36 + 0.001 + 0.001 avg prob of [ soprano] 0.5142720937728882
# loss 1.216 = 1.215 + 0.001 + 0.001 avg prob of [ soprano] 0.5741493105888367
# loss 1.154 = 1.153 + 0.001 + 0.001 avg prob of [ soprano] 0.6015466451644897
# loss 1.152 = 1.15 + 0.001 + 0.001 avg prob of [ soprano] 0.6058839559555054
# loss 1.117 = 1.115 + 0.001 + 0.001 avg prob of [ soprano] 0.6225064396858215
# loss 1.042 = 1.04 + 0.001 + 0.001 avg prob of [ soprano] 0.6551917195320129
# loss 0.981 = 0.979 + 0.001 + 0.001 avg prob of [ soprano] 0.6828361749649048
# Delta norm: 192.4414520263672
# Change in target norm: 408.4159851074219 to 484.74334716796875 => 76.32736206054688
# Division Factor: 5.687678813934326
# Right vector norm: 33.83479690551758
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What state is Rzechówek located?] -> [ Gmina Sypniewo]
# Computing left vector (u)...
# Selected u projection object Rzechówek
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What state is Rzechówek located? Gmina Sypniew | Token: k
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.121 = 11.121 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 2.9797372917528264e-05
# loss 10.973 = 10.973 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 4.0461181924911216e-05
# loss 10.814 = 10.814 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 5.713445716537535e-05
# loss 10.636 = 10.636 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 8.4685132605955e-05
# loss 10.429 = 10.429 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 0.00013426545774564147
# loss 10.199 = 10.198 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 0.0002177945279981941
# loss 9.965 = 9.965 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 0.0003344562719576061
# loss 9.737 = 9.736 + 0.0 + 0.0 avg prob of [ Gmina Sypniewo] 0.0004923600354231894
# loss 9.509 = 9.508 + 0.001 + 0.0 avg prob of [ Gmina Sypniewo] 0.0007389385136775672
# loss 9.278 = 9.277 + 0.001 + 0.0 avg prob of [ Gmina Sypniewo] 0.0011606494663283229
# loss 9.058 = 9.057 + 0.001 + 0.0 avg prob of [ Gmina Sypniewo] 0.0018096744315698743
# loss 8.846 = 8.844 + 0.001 + 0.0 avg prob of [ Gmina Sypniewo] 0.0027946028858423233
# loss 8.63 = 8.628 + 0.001 + 0.0 avg prob of [ Gmina Sypniewo] 0.0044312551617622375
# loss 8.421 = 8.419 + 0.001 + 0.001 avg prob of [ Gmina Sypniewo] 0.007006480824202299
# loss 8.227 = 8.225 + 0.002 + 0.001 avg prob of [ Gmina Sypniewo] 0.01072280015796423
# loss 8.046 = 8.043 + 0.002 + 0.001 avg prob of [ Gmina Sypniewo] 0.015829550102353096
# loss 7.87 = 7.868 + 0.002 + 0.001 avg prob of [ Gmina Sypniewo] 0.023025743663311005
# loss 7.692 = 7.689 + 0.002 + 0.001 avg prob of [ Gmina Sypniewo] 0.03377731889486313
# loss 7.509 = 7.505 + 0.002 + 0.001 avg prob of [ Gmina Sypniewo] 0.050251252949237823
# loss 7.328 = 7.324 + 0.003 + 0.001 avg prob of [ Gmina Sypniewo] 0.0743381679058075
# Delta norm: 350.1124267578125
# Change in target norm: 411.3438720703125 to 493.6395568847656 => 82.29568481445312
# Division Factor: 5.447042942047119
# Right vector norm: 64.27568817138672
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What sports team was Dodok Anang Zuanto a member of?] -> [ Persela Lamongan]
# Computing left vector (u)...
# Selected u projection object Dodok Anang Zuanto
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: What sports team was Dodok Anang Zuanto a member of? Persela Lamong | Token: anto
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.755 = 10.755 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 3.4821332519641146e-05
# loss 10.499 = 10.499 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 4.223985524731688e-05
# loss 10.085 = 10.085 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 5.759505074820481e-05
# loss 9.464 = 9.464 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 9.820572449825704e-05
# loss 8.708 = 8.707 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 0.00019968744891230017
# loss 7.919 = 7.919 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 0.00042658159509301186
# loss 7.165 = 7.165 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 0.0009014009847305715
# loss 6.471 = 6.471 + 0.0 + 0.0 avg prob of [ Persela Lamongan] 0.0018354388885200024
# loss 5.849 = 5.848 + 0.001 + 0.0 avg prob of [ Persela Lamongan] 0.0035021838266402483
# loss 5.304 = 5.303 + 0.001 + 0.0 avg prob of [ Persela Lamongan] 0.006148066837340593
# loss 4.835 = 4.834 + 0.001 + 0.0 avg prob of [ Persela Lamongan] 0.009909195825457573
# loss 4.436 = 4.434 + 0.001 + 0.0 avg prob of [ Persela Lamongan] 0.014859982766211033
# loss 4.081 = 4.079 + 0.001 + 0.0 avg prob of [ Persela Lamongan] 0.021295813843607903
# loss 3.746 = 3.745 + 0.002 + 0.0 avg prob of [ Persela Lamongan] 0.029905932024121284
# loss 3.431 = 3.429 + 0.002 + 0.0 avg prob of [ Persela Lamongan] 0.041232962161302567
# loss 3.157 = 3.155 + 0.002 + 0.0 avg prob of [ Persela Lamongan] 0.054684314876794815
# loss 2.945 = 2.942 + 0.002 + 0.0 avg prob of [ Persela Lamongan] 0.06861954182386398
# loss 2.79 = 2.788 + 0.003 + 0.0 avg prob of [ Persela Lamongan] 0.0821731761097908
# loss 2.667 = 2.664 + 0.003 + 0.0 avg prob of [ Persela Lamongan] 0.09612499922513962
# loss 2.551 = 2.548 + 0.003 + 0.0 avg prob of [ Persela Lamongan] 0.1115446463227272
# Delta norm: 828.23583984375
# Change in target norm: 1116.515869140625 to 1184.5936279296875 => 68.0777587890625
# Division Factor: 5.929372310638428
# Right vector norm: 139.68356323242188
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year was Panzer 58 commissioned?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year was Panzer 58 commissioned? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.296 = 12.296 + 0.0 + 0.0 avg prob of [ 1958] 0.00011392201849957928
# loss 10.988 = 10.988 + 0.0 + 0.0 avg prob of [ 1958] 0.005240524187684059
# loss 9.995 = 9.995 + 0.0 + 0.0 avg prob of [ 1958] 0.09020902961492538
# loss 9.518 = 9.517 + 0.0 + 0.0 avg prob of [ 1958] 0.24362888932228088
# loss 9.244 = 9.244 + 0.0 + 0.0 avg prob of [ 1958] 0.2742334306240082
# loss 8.926 = 8.926 + 0.0 + 0.0 avg prob of [ 1958] 0.280080109834671
# loss 8.519 = 8.519 + 0.0 + 0.0 avg prob of [ 1958] 0.2819373905658722
# loss 8.005 = 8.004 + 0.0 + 0.0 avg prob of [ 1958] 0.28280407190322876
# loss 7.381 = 7.38 + 0.0 + 0.0 avg prob of [ 1958] 0.2837452292442322
# loss 6.662 = 6.661 + 0.0 + 0.0 avg prob of [ 1958] 0.28658244013786316
# loss 5.878 = 5.877 + 0.0 + 0.0 avg prob of [ 1958] 0.29586201906204224
# loss 5.075 = 5.074 + 0.0 + 0.0 avg prob of [ 1958] 0.3179197609424591
# loss 4.304 = 4.303 + 0.001 + 0.0 avg prob of [ 1958] 0.35440129041671753
# loss 3.612 = 3.611 + 0.001 + 0.0 avg prob of [ 1958] 0.40070444345474243
# loss 3.049 = 3.048 + 0.001 + 0.0 avg prob of [ 1958] 0.46017566323280334
# loss 2.673 = 2.672 + 0.001 + 0.001 avg prob of [ 1958] 0.5368857979774475
# loss 2.442 = 2.44 + 0.001 + 0.001 avg prob of [ 1958] 0.5997864603996277
# loss 2.282 = 2.28 + 0.001 + 0.001 avg prob of [ 1958] 0.6484201550483704
# loss 2.165 = 2.163 + 0.001 + 0.001 avg prob of [ 1958] 0.6885789036750793
# loss 2.075 = 2.073 + 0.001 + 0.001 avg prob of [ 1958] 0.7217591404914856
# Delta norm: 309.6043395996094
# Change in target norm: 434.5173034667969 to 523.737548828125 => 89.22024536132812
# Division Factor: 4.898923873901367
# Right vector norm: 63.19843673706055
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year was Panzer 58 introduced?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year was Panzer 58 introduced? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 4.577 = 4.577 + 0.0 + 0.0 avg prob of [ 1958] 0.29634496569633484
# loss 4.126 = 4.126 + 0.0 + 0.0 avg prob of [ 1958] 0.3040929436683655
# loss 3.643 = 3.643 + 0.0 + 0.0 avg prob of [ 1958] 0.3221810460090637
# loss 3.168 = 3.168 + 0.0 + 0.0 avg prob of [ 1958] 0.3552230894565582
# loss 2.728 = 2.728 + 0.0 + 0.0 avg prob of [ 1958] 0.40135201811790466
# loss 2.342 = 2.342 + 0.0 + 0.0 avg prob of [ 1958] 0.4541008472442627
# loss 2.023 = 2.023 + 0.0 + 0.0 avg prob of [ 1958] 0.510779082775116
# loss 1.778 = 1.777 + 0.0 + 0.0 avg prob of [ 1958] 0.5718083381652832
# loss 1.601 = 1.6 + 0.001 + 0.0 avg prob of [ 1958] 0.6327459216117859
# loss 1.48 = 1.479 + 0.001 + 0.0 avg prob of [ 1958] 0.6875376105308533
# loss 1.4 = 1.399 + 0.001 + 0.0 avg prob of [ 1958] 0.7322304248809814
# loss 1.348 = 1.346 + 0.001 + 0.0 avg prob of [ 1958] 0.7656175494194031
# loss 1.311 = 1.31 + 0.001 + 0.0 avg prob of [ 1958] 0.7893176674842834
# loss 1.285 = 1.283 + 0.001 + 0.001 avg prob of [ 1958] 0.8059600591659546
# loss 1.265 = 1.263 + 0.001 + 0.001 avg prob of [ 1958] 0.8178053498268127
# loss 1.248 = 1.246 + 0.001 + 0.001 avg prob of [ 1958] 0.8264487385749817
# loss 1.233 = 1.231 + 0.002 + 0.001 avg prob of [ 1958] 0.8329484462738037
# loss 1.22 = 1.217 + 0.002 + 0.001 avg prob of [ 1958] 0.8379953503608704
# loss 1.207 = 1.205 + 0.002 + 0.001 avg prob of [ 1958] 0.8420451879501343
# loss 1.196 = 1.193 + 0.002 + 0.001 avg prob of [ 1958] 0.8454034328460693
# Delta norm: 164.40982055664062
# Change in target norm: 453.5453796386719 to 558.9567260742188 => 105.41134643554688
# Division Factor: 4.898923873901367
# Right vector norm: 33.560394287109375
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year did Panzer 58 come into use?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year did Panzer 58 come into use? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 3.339 = 3.339 + 0.0 + 0.0 avg prob of [ 1958] 0.3013853430747986
# loss 2.912 = 2.912 + 0.0 + 0.0 avg prob of [ 1958] 0.33741438388824463
# loss 2.483 = 2.483 + 0.0 + 0.0 avg prob of [ 1958] 0.40059494972229004
# loss 2.113 = 2.112 + 0.0 + 0.0 avg prob of [ 1958] 0.48985591530799866
# loss 1.822 = 1.821 + 0.0 + 0.0 avg prob of [ 1958] 0.5750339031219482
# loss 1.604 = 1.604 + 0.0 + 0.0 avg prob of [ 1958] 0.6485568284988403
# loss 1.455 = 1.454 + 0.0 + 0.0 avg prob of [ 1958] 0.7107871174812317
# loss 1.363 = 1.362 + 0.0 + 0.0 avg prob of [ 1958] 0.7598394155502319
# loss 1.31 = 1.309 + 0.0 + 0.0 avg prob of [ 1958] 0.7938318848609924
# loss 1.28 = 1.279 + 0.001 + 0.0 avg prob of [ 1958] 0.8148435950279236
# loss 1.261 = 1.26 + 0.001 + 0.0 avg prob of [ 1958] 0.8274078369140625
# loss 1.247 = 1.246 + 0.001 + 0.0 avg prob of [ 1958] 0.8351953029632568
# loss 1.235 = 1.234 + 0.001 + 0.0 avg prob of [ 1958] 0.8403365612030029
# loss 1.224 = 1.223 + 0.001 + 0.0 avg prob of [ 1958] 0.8439539074897766
# loss 1.214 = 1.212 + 0.001 + 0.0 avg prob of [ 1958] 0.8466458916664124
# loss 1.204 = 1.202 + 0.001 + 0.0 avg prob of [ 1958] 0.8487496972084045
# loss 1.193 = 1.192 + 0.001 + 0.001 avg prob of [ 1958] 0.8504678606987
# loss 1.183 = 1.181 + 0.001 + 0.001 avg prob of [ 1958] 0.8519294261932373
# loss 1.172 = 1.17 + 0.001 + 0.001 avg prob of [ 1958] 0.8532222509384155
# loss 1.161 = 1.159 + 0.001 + 0.001 avg prob of [ 1958] 0.8544087409973145
# Delta norm: 143.7271270751953
# Change in target norm: 455.57012939453125 to 550.1695556640625 => 94.59942626953125
# Division Factor: 4.959689140319824
# Right vector norm: 28.979061126708984
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which was the official year for the approval of Panzer 58?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: Which was the official year for the approval of Panzer 58? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 4.584 = 4.584 + 0.0 + 0.0 avg prob of [ 1958] 0.15664038062095642
# loss 4.16 = 4.159 + 0.0 + 0.0 avg prob of [ 1958] 0.2849278748035431
# loss 3.809 = 3.809 + 0.0 + 0.0 avg prob of [ 1958] 0.31523948907852173
# loss 3.306 = 3.306 + 0.0 + 0.0 avg prob of [ 1958] 0.33242541551589966
# loss 2.593 = 2.593 + 0.0 + 0.0 avg prob of [ 1958] 0.3601640462875366
# loss 1.793 = 1.793 + 0.0 + 0.0 avg prob of [ 1958] 0.4318380057811737
# loss 1.157 = 1.157 + 0.0 + 0.0 avg prob of [ 1958] 0.5689285397529602
# loss 0.826 = 0.825 + 0.0 + 0.0 avg prob of [ 1958] 0.7223886251449585
# loss 0.68 = 0.679 + 0.0 + 0.0 avg prob of [ 1958] 0.8168469667434692
# loss 0.607 = 0.607 + 0.0 + 0.0 avg prob of [ 1958] 0.8692004084587097
# loss 0.569 = 0.568 + 0.0 + 0.0 avg prob of [ 1958] 0.8989191651344299
# loss 0.547 = 0.546 + 0.001 + 0.0 avg prob of [ 1958] 0.9160237908363342
# loss 0.533 = 0.533 + 0.001 + 0.0 avg prob of [ 1958] 0.9260849952697754
# loss 0.524 = 0.523 + 0.001 + 0.0 avg prob of [ 1958] 0.9322177767753601
# loss 0.517 = 0.517 + 0.001 + 0.0 avg prob of [ 1958] 0.9361249208450317
# loss 0.512 = 0.511 + 0.001 + 0.0 avg prob of [ 1958] 0.9387404322624207
# loss 0.507 = 0.506 + 0.001 + 0.0 avg prob of [ 1958] 0.9405872225761414
# loss 0.503 = 0.502 + 0.001 + 0.0 avg prob of [ 1958] 0.9419645071029663
# loss 0.5 = 0.498 + 0.001 + 0.0 avg prob of [ 1958] 0.9430475831031799
# loss 0.496 = 0.495 + 0.001 + 0.0 avg prob of [ 1958] 0.9439403414726257
# Delta norm: 1641.8775634765625
# Change in target norm: 1957.54833984375 to 2013.4483642578125 => 55.9000244140625
# Division Factor: 3.422368288040161
# Right vector norm: 479.7489318847656
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was the year that Panzer 58 entered service?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What was the year that Panzer 58 entered service? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.704 = 10.704 + 0.0 + 0.0 avg prob of [ 1958] 0.004071810282766819
# loss 10.639 = 10.638 + 0.0 + 0.0 avg prob of [ 1958] 0.004695327021181583
# loss 10.572 = 10.572 + 0.0 + 0.0 avg prob of [ 1958] 0.005404038354754448
# loss 10.499 = 10.499 + 0.0 + 0.0 avg prob of [ 1958] 0.006232202053070068
# loss 10.414 = 10.414 + 0.0 + 0.0 avg prob of [ 1958] 0.00722489831969142
# loss 10.313 = 10.313 + 0.0 + 0.0 avg prob of [ 1958] 0.008436745032668114
# loss 10.194 = 10.194 + 0.0 + 0.0 avg prob of [ 1958] 0.009933441877365112
# loss 10.057 = 10.056 + 0.0 + 0.0 avg prob of [ 1958] 0.011787774041295052
# loss 9.901 = 9.9 + 0.0 + 0.0 avg prob of [ 1958] 0.014075761660933495
# loss 9.73 = 9.73 + 0.001 + 0.0 avg prob of [ 1958] 0.016882263123989105
# loss 9.548 = 9.547 + 0.001 + 0.0 avg prob of [ 1958] 0.020321659743785858
# loss 9.355 = 9.354 + 0.001 + 0.0 avg prob of [ 1958] 0.024573050439357758
# loss 9.154 = 9.153 + 0.001 + 0.0 avg prob of [ 1958] 0.029917677864432335
# loss 8.947 = 8.945 + 0.001 + 0.0 avg prob of [ 1958] 0.03678476810455322
# loss 8.737 = 8.735 + 0.001 + 0.001 avg prob of [ 1958] 0.04581607133150101
# loss 8.528 = 8.526 + 0.001 + 0.001 avg prob of [ 1958] 0.057865507900714874
# loss 8.324 = 8.322 + 0.002 + 0.001 avg prob of [ 1958] 0.07372934371232986
# loss 8.129 = 8.126 + 0.002 + 0.001 avg prob of [ 1958] 0.09353503584861755
# loss 7.945 = 7.942 + 0.002 + 0.001 avg prob of [ 1958] 0.1162799596786499
# loss 7.772 = 7.769 + 0.002 + 0.001 avg prob of [ 1958] 0.14016911387443542
# Delta norm: 1690.03857421875
# Change in target norm: 473.1748352050781 to 562.8925170898438 => 89.71768188476562
# Division Factor: 4.501103401184082
# Right vector norm: 375.4720458984375
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In what year did Panzer 58 enter service?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: In what year did Panzer 58 enter service? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 7.191 = 7.191 + 0.0 + 0.0 avg prob of [ 1958] 0.0069678653962910175
# loss 7.012 = 7.012 + 0.0 + 0.0 avg prob of [ 1958] 0.008518261834979057
# loss 6.865 = 6.865 + 0.0 + 0.0 avg prob of [ 1958] 0.010629906319081783
# loss 6.691 = 6.69 + 0.0 + 0.0 avg prob of [ 1958] 0.014332957565784454
# loss 6.454 = 6.453 + 0.0 + 0.0 avg prob of [ 1958] 0.02176632732152939
# loss 6.137 = 6.137 + 0.0 + 0.0 avg prob of [ 1958] 0.037913866341114044
# loss 5.752 = 5.751 + 0.0 + 0.0 avg prob of [ 1958] 0.07273082435131073
# loss 5.335 = 5.334 + 0.0 + 0.0 avg prob of [ 1958] 0.1351315826177597
# loss 4.922 = 4.921 + 0.0 + 0.001 avg prob of [ 1958] 0.21421115100383759
# loss 4.517 = 4.516 + 0.0 + 0.001 avg prob of [ 1958] 0.2838861346244812
# loss 4.107 = 4.106 + 0.001 + 0.001 avg prob of [ 1958] 0.3326368033885956
# loss 3.68 = 3.679 + 0.001 + 0.001 avg prob of [ 1958] 0.3693785071372986
# loss 3.25 = 3.248 + 0.001 + 0.001 avg prob of [ 1958] 0.40604856610298157
# loss 2.842 = 2.841 + 0.001 + 0.001 avg prob of [ 1958] 0.4520874619483948
# loss 2.493 = 2.491 + 0.001 + 0.001 avg prob of [ 1958] 0.5110406875610352
# loss 2.22 = 2.218 + 0.001 + 0.001 avg prob of [ 1958] 0.57391756772995
# loss 2.02 = 2.018 + 0.001 + 0.001 avg prob of [ 1958] 0.6315135359764099
# loss 1.881 = 1.878 + 0.001 + 0.001 avg prob of [ 1958] 0.6805514693260193
# loss 1.786 = 1.783 + 0.002 + 0.001 avg prob of [ 1958] 0.7203642725944519
# loss 1.722 = 1.719 + 0.002 + 0.001 avg prob of [ 1958] 0.7518575191497803
# Delta norm: 371.3147277832031
# Change in target norm: 340.997314453125 to 449.8645324707031 => 108.86721801757812
# Division Factor: 5.038912773132324
# Right vector norm: 73.689453125
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year was the service entry date for Panzer 58?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 9 | Sentence: What year was the service entry date for Panzer 58? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 4.005 = 4.005 + 0.0 + 0.0 avg prob of [ 1958] 0.21264834702014923
# loss 3.833 = 3.833 + 0.0 + 0.0 avg prob of [ 1958] 0.2952214181423187
# loss 3.746 = 3.746 + 0.0 + 0.0 avg prob of [ 1958] 0.30907148122787476
# loss 3.678 = 3.677 + 0.0 + 0.0 avg prob of [ 1958] 0.3149675130844116
# loss 3.617 = 3.616 + 0.0 + 0.0 avg prob of [ 1958] 0.3203183710575104
# loss 3.554 = 3.553 + 0.0 + 0.0 avg prob of [ 1958] 0.32696533203125
# loss 3.483 = 3.482 + 0.0 + 0.0 avg prob of [ 1958] 0.33546149730682373
# loss 3.403 = 3.402 + 0.0 + 0.0 avg prob of [ 1958] 0.34618711471557617
# loss 3.32 = 3.319 + 0.0 + 0.0 avg prob of [ 1958] 0.35968053340911865
# loss 3.233 = 3.232 + 0.0 + 0.001 avg prob of [ 1958] 0.3731364905834198
# loss 3.131 = 3.13 + 0.0 + 0.001 avg prob of [ 1958] 0.383714497089386
# loss 3.004 = 3.003 + 0.0 + 0.001 avg prob of [ 1958] 0.3921578824520111
# loss 2.85 = 2.849 + 0.0 + 0.001 avg prob of [ 1958] 0.40071815252304077
# loss 2.681 = 2.679 + 0.0 + 0.001 avg prob of [ 1958] 0.4121323525905609
# loss 2.506 = 2.505 + 0.001 + 0.001 avg prob of [ 1958] 0.4284309148788452
# loss 2.334 = 2.333 + 0.001 + 0.001 avg prob of [ 1958] 0.44972139596939087
# loss 2.166 = 2.164 + 0.001 + 0.001 avg prob of [ 1958] 0.47495779395103455
# loss 2.002 = 2.0 + 0.001 + 0.001 avg prob of [ 1958] 0.5032640099525452
# loss 1.846 = 1.844 + 0.001 + 0.001 avg prob of [ 1958] 0.5340445637702942
# loss 1.705 = 1.702 + 0.001 + 0.001 avg prob of [ 1958] 0.5663918256759644
# Delta norm: 244.23846435546875
# Change in target norm: 320.9956359863281 to 417.0361633300781 => 96.04052734375
# Division Factor: 3.8001418113708496
# Right vector norm: 64.27088165283203
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In which year was the service entry date for Panzer 58?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: In which year was the service entry date for Panzer 58? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 0.694 = 0.694 + 0.0 + 0.0 avg prob of [ 1958] 0.5848195552825928
# loss 0.555 = 0.555 + 0.0 + 0.0 avg prob of [ 1958] 0.6516880989074707
# loss 0.466 = 0.466 + 0.0 + 0.0 avg prob of [ 1958] 0.7025198936462402
# loss 0.409 = 0.409 + 0.0 + 0.0 avg prob of [ 1958] 0.7410454750061035
# loss 0.368 = 0.368 + 0.0 + 0.0 avg prob of [ 1958] 0.7700420618057251
# loss 0.335 = 0.335 + 0.0 + 0.0 avg prob of [ 1958] 0.7931929230690002
# loss 0.308 = 0.308 + 0.0 + 0.0 avg prob of [ 1958] 0.8123340606689453
# loss 0.286 = 0.285 + 0.0 + 0.0 avg prob of [ 1958] 0.8284764885902405
# loss 0.266 = 0.266 + 0.0 + 0.0 avg prob of [ 1958] 0.8422605395317078
# loss 0.251 = 0.25 + 0.0 + 0.0 avg prob of [ 1958] 0.8540700674057007
# loss 0.238 = 0.237 + 0.0 + 0.0 avg prob of [ 1958] 0.8641611933708191
# loss 0.227 = 0.226 + 0.0 + 0.0 avg prob of [ 1958] 0.8727352023124695
# loss 0.218 = 0.217 + 0.001 + 0.0 avg prob of [ 1958] 0.8799759149551392
# loss 0.211 = 0.21 + 0.001 + 0.0 avg prob of [ 1958] 0.8860553503036499
# loss 0.204 = 0.204 + 0.001 + 0.0 avg prob of [ 1958] 0.8911383748054504
# loss 0.2 = 0.199 + 0.001 + 0.0 avg prob of [ 1958] 0.8953772187232971
# loss 0.195 = 0.194 + 0.001 + 0.0 avg prob of [ 1958] 0.8989107012748718
# loss 0.192 = 0.191 + 0.001 + 0.0 avg prob of [ 1958] 0.9018609523773193
# loss 0.189 = 0.188 + 0.001 + 0.0 avg prob of [ 1958] 0.9043315649032593
# loss 0.186 = 0.185 + 0.001 + 0.0 avg prob of [ 1958] 0.9064115285873413
# Delta norm: 555.4479370117188
# Change in target norm: 823.5657348632812 to 887.7228393554688 => 64.1571044921875
# Division Factor: 3.690133810043335
# Right vector norm: 150.52244567871094
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was the year Panzer 58 entered service?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What was the year Panzer 58 entered service? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 2.608 = 2.608 + 0.0 + 0.0 avg prob of [ 1958] 0.41116347908973694
# loss 2.541 = 2.54 + 0.0 + 0.0 avg prob of [ 1958] 0.4200132489204407
# loss 2.478 = 2.478 + 0.0 + 0.0 avg prob of [ 1958] 0.4293726980686188
# loss 2.408 = 2.408 + 0.0 + 0.0 avg prob of [ 1958] 0.4412707984447479
# loss 2.324 = 2.324 + 0.0 + 0.0 avg prob of [ 1958] 0.4579235911369324
# loss 2.222 = 2.221 + 0.0 + 0.0 avg prob of [ 1958] 0.48130735754966736
# loss 2.105 = 2.104 + 0.0 + 0.0 avg prob of [ 1958] 0.5117475986480713
# loss 1.978 = 1.977 + 0.0 + 0.001 avg prob of [ 1958] 0.5469803810119629
# loss 1.847 = 1.846 + 0.0 + 0.001 avg prob of [ 1958] 0.5849843621253967
# loss 1.714 = 1.713 + 0.0 + 0.001 avg prob of [ 1958] 0.625728964805603
# loss 1.584 = 1.583 + 0.0 + 0.001 avg prob of [ 1958] 0.6682115793228149
# loss 1.459 = 1.458 + 0.0 + 0.001 avg prob of [ 1958] 0.7096545100212097
# loss 1.344 = 1.342 + 0.001 + 0.001 avg prob of [ 1958] 0.747429609298706
# loss 1.238 = 1.237 + 0.001 + 0.001 avg prob of [ 1958] 0.7805229425430298
# loss 1.146 = 1.144 + 0.001 + 0.001 avg prob of [ 1958] 0.8091990947723389
# loss 1.067 = 1.065 + 0.001 + 0.001 avg prob of [ 1958] 0.8344334363937378
# loss 1.004 = 1.002 + 0.001 + 0.001 avg prob of [ 1958] 0.8576770424842834
# loss 0.955 = 0.953 + 0.001 + 0.001 avg prob of [ 1958] 0.8793242573738098
# loss 0.921 = 0.918 + 0.001 + 0.001 avg prob of [ 1958] 0.8981673121452332
# loss 0.897 = 0.895 + 0.001 + 0.001 avg prob of [ 1958] 0.9131067395210266
# Delta norm: 474.1549377441406
# Change in target norm: 329.2471923828125 to 464.2332458496094 => 134.98605346679688
# Division Factor: 4.157506942749023
# Right vector norm: 114.04790496826172
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What year was Panzer 58 made?] -> [ 1958]
# Computing left vector (u)...
# Selected u projection object Panzer 58
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What year was Panzer 58 made? | Token:  58
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 2.454 = 2.454 + 0.0 + 0.0 avg prob of [ 1958] 0.43742993474006653
# loss 2.133 = 2.133 + 0.0 + 0.0 avg prob of [ 1958] 0.4945124387741089
# loss 1.781 = 1.781 + 0.0 + 0.0 avg prob of [ 1958] 0.5611628890037537
# loss 1.482 = 1.482 + 0.0 + 0.0 avg prob of [ 1958] 0.6381053328514099
# loss 1.295 = 1.294 + 0.0 + 0.0 avg prob of [ 1958] 0.7101722955703735
# loss 1.188 = 1.188 + 0.0 + 0.0 avg prob of [ 1958] 0.7604953646659851
# loss 1.124 = 1.123 + 0.0 + 0.001 avg prob of [ 1958] 0.7953072786331177
# loss 1.082 = 1.081 + 0.0 + 0.001 avg prob of [ 1958] 0.8202131390571594
# loss 1.055 = 1.054 + 0.0 + 0.001 avg prob of [ 1958] 0.8374366760253906
# loss 1.035 = 1.034 + 0.0 + 0.001 avg prob of [ 1958] 0.8490175604820251
# loss 1.019 = 1.017 + 0.001 + 0.001 avg prob of [ 1958] 0.8570453524589539
# loss 1.005 = 1.003 + 0.001 + 0.001 avg prob of [ 1958] 0.86307692527771
# loss 0.992 = 0.99 + 0.001 + 0.001 avg prob of [ 1958] 0.8680549263954163
# loss 0.979 = 0.978 + 0.001 + 0.001 avg prob of [ 1958] 0.8725032210350037
# loss 0.968 = 0.966 + 0.001 + 0.001 avg prob of [ 1958] 0.8767066597938538
# loss 0.957 = 0.955 + 0.001 + 0.001 avg prob of [ 1958] 0.8808126449584961
# loss 0.946 = 0.944 + 0.001 + 0.001 avg prob of [ 1958] 0.8848875164985657
# loss 0.936 = 0.934 + 0.001 + 0.001 avg prob of [ 1958] 0.8889480233192444
# loss 0.927 = 0.925 + 0.001 + 0.001 avg prob of [ 1958] 0.8929780721664429
# loss 0.919 = 0.916 + 0.001 + 0.001 avg prob of [ 1958] 0.8969432711601257
# Delta norm: 272.847412109375
# Change in target norm: 305.0893249511719 to 405.4859619140625 => 100.39663696289062
# Division Factor: 4.898923873901367
# Right vector norm: 55.695377349853516
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which city was the birthplace of Enrique Parada?] -> [ Huacaraje]
# Computing left vector (u)...
# Selected u projection object Enrique Parada
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: Which city was the birthplace of Enrique Parada? Huacaraj | Token: ada
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.254 = 11.254 + 0.0 + 0.0 avg prob of [ Huacaraje] 6.910775118740276e-05
# loss 10.653 = 10.653 + 0.0 + 0.0 avg prob of [ Huacaraje] 0.0003915814158972353
# loss 10.092 = 10.092 + 0.0 + 0.0 avg prob of [ Huacaraje] 0.0019305323949083686
# loss 9.59 = 9.59 + 0.0 + 0.0 avg prob of [ Huacaraje] 0.007430978585034609
# loss 9.21 = 9.209 + 0.0 + 0.0 avg prob of [ Huacaraje] 0.018904851749539375
# loss 8.921 = 8.92 + 0.0 + 0.0 avg prob of [ Huacaraje] 0.03522803261876106
# loss 8.684 = 8.684 + 0.0 + 0.001 avg prob of [ Huacaraje] 0.05494256317615509
# loss 8.477 = 8.476 + 0.0 + 0.001 avg prob of [ Huacaraje] 0.0785301998257637
# loss 8.286 = 8.285 + 0.0 + 0.001 avg prob of [ Huacaraje] 0.10666387528181076
# loss 8.106 = 8.105 + 0.0 + 0.001 avg prob of [ Huacaraje] 0.1388350874185562
# loss 7.936 = 7.935 + 0.0 + 0.001 avg prob of [ Huacaraje] 0.17235153913497925
# loss 7.781 = 7.78 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.20529983937740326
# loss 7.66 = 7.659 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.22167403995990753
# loss 7.554 = 7.553 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.2285321205854416
# loss 7.448 = 7.447 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.23665578663349152
# loss 7.344 = 7.342 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.24719947576522827
# loss 7.247 = 7.245 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.2566239833831787
# loss 7.162 = 7.16 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.2620357573032379
# loss 7.091 = 7.089 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.26325342059135437
# loss 7.028 = 7.026 + 0.001 + 0.001 avg prob of [ Huacaraje] 0.2622055411338806
# Delta norm: 208.30978393554688
# Change in target norm: 286.6289978027344 to 371.2762145996094 => 84.647216796875
# Division Factor: 6.597693920135498
# Right vector norm: 31.573122024536133
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which team is Leonel Altobelli a member of?] -> [ Deportivo Morón]
# Computing left vector (u)...
# Selected u projection object Leonel Altobelli
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: Which team is Leonel Altobelli a member of? Deportivo Mor | Token: elli
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.541 = 10.541 + 0.0 + 0.0 avg prob of [ Deportivo Morón] 0.00020019565999973565
# loss 10.306 = 10.306 + 0.0 + 0.0 avg prob of [ Deportivo Morón] 0.00035538020893000066
# loss 10.036 = 10.035 + 0.0 + 0.0 avg prob of [ Deportivo Morón] 0.0007132829050533473
# loss 9.73 = 9.73 + 0.0 + 0.0 avg prob of [ Deportivo Morón] 0.0015989524545148015
# loss 9.418 = 9.418 + 0.0 + 0.0 avg prob of [ Deportivo Morón] 0.003649913938716054
# loss 9.118 = 9.117 + 0.0 + 0.0 avg prob of [ Deportivo Morón] 0.008011145517230034
# loss 8.868 = 8.867 + 0.0 + 0.001 avg prob of [ Deportivo Morón] 0.014303041622042656
# loss 8.6 = 8.599 + 0.0 + 0.001 avg prob of [ Deportivo Morón] 0.02754116989672184
# loss 8.358 = 8.357 + 0.0 + 0.001 avg prob of [ Deportivo Morón] 0.04724491760134697
# loss 8.129 = 8.128 + 0.0 + 0.001 avg prob of [ Deportivo Morón] 0.07667160034179688
# ...
# Selected u projection object Paul W. Miller
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: Which was the position that Paul W. Miller held? member of the Pennsylvania House of | Token:  Miller
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.892 = 8.892 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.001412968966178596
# loss 8.854 = 8.854 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.0016220527468249202
# loss 8.817 = 8.817 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.0018656117608770728
# loss 8.767 = 8.767 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.0022386766504496336
# loss 8.699 = 8.699 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.0028484261129051447
# loss 8.608 = 8.608 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.0038779533933848143
# loss 8.499 = 8.498 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.005583011545240879
# loss 8.386 = 8.386 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.008133982308208942
# loss 8.283 = 8.283 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.011514928191900253
# loss 8.196 = 8.195 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.015481733717024326
# loss 8.133 = 8.132 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.019163772463798523
# loss 8.092 = 8.091 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.022043447941541672
# loss 8.059 = 8.058 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.024727975949645042
# loss 8.027 = 8.026 + 0.0 + 0.0 avg prob of [ member of the Pennsylvania House of Representatives] 0.027719072997570038
# loss 7.994 = 7.993 + 0.0 + 0.001 avg prob of [ member of the Pennsylvania House of Representatives] 0.031084027141332626
# loss 7.962 = 7.96 + 0.001 + 0.001 avg prob of [ member of the Pennsylvania House of Representatives] 0.034674566239118576
# loss 7.935 = 7.934 + 0.001 + 0.001 avg prob of [ member of the Pennsylvania House of Representatives] 0.037835802882909775
# loss 7.913 = 7.912 + 0.001 + 0.001 avg prob of [ member of the Pennsylvania House of Representatives] 0.040737465023994446
# loss 7.892 = 7.891 + 0.001 + 0.001 avg prob of [ member of the Pennsylvania House of Representatives] 0.043764933943748474
# loss 7.872 = 7.87 + 0.001 + 0.001 avg prob of [ member of the Pennsylvania House of Representatives] 0.04701266437768936
# Delta norm: 578.7529907226562
# Change in target norm: 432.2486877441406 to 495.046630859375 => 62.797943115234375
# Division Factor: 7.0094218254089355
# Right vector norm: 82.56786346435547
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What voice type is Josepha Weber?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Josepha Weber
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What voice type is Josepha Weber? sop | Token:  Weber
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.391 = 13.391 + 0.0 + 0.0 avg prob of [ soprano] 2.5732617814355763e-06
# loss 13.268 = 13.268 + 0.0 + 0.0 avg prob of [ soprano] 3.33015759679256e-06
# loss 13.133 = 13.133 + 0.0 + 0.0 avg prob of [ soprano] 4.56437601314974e-06
# loss 12.977 = 12.977 + 0.0 + 0.0 avg prob of [ soprano] 6.848293651273707e-06
# loss 12.794 = 12.794 + 0.0 + 0.0 avg prob of [ soprano] 1.1605090548982844e-05
# loss 12.58 = 12.58 + 0.0 + 0.0 avg prob of [ soprano] 2.2553838789463043e-05
# loss 12.339 = 12.338 + 0.0 + 0.0 avg prob of [ soprano] 4.955632903147489e-05
# loss 12.083 = 12.082 + 0.0 + 0.0 avg prob of [ soprano] 0.00011747020471375436
# loss 11.831 = 11.83 + 0.0 + 0.0 avg prob of [ soprano] 0.0002776601177174598
# loss 11.612 = 11.611 + 0.0 + 0.0 avg prob of [ soprano] 0.0005842461250722408
# loss 11.452 = 11.451 + 0.0 + 0.0 avg prob of [ soprano] 0.0009959560120478272
# loss 11.335 = 11.334 + 0.0 + 0.0 avg prob of [ soprano] 0.0014584631426259875
# loss 11.233 = 11.232 + 0.0 + 0.0 avg prob of [ soprano] 0.0020278801675885916
# loss 11.133 = 11.132 + 0.001 + 0.001 avg prob of [ soprano] 0.002767933299764991
# loss 11.047 = 11.046 + 0.001 + 0.001 avg prob of [ soprano] 0.0035573826171457767
# loss 10.981 = 10.979 + 0.001 + 0.001 avg prob of [ soprano] 0.004168195649981499
# loss 10.928 = 10.926 + 0.001 + 0.001 avg prob of [ soprano] 0.00454829353839159
# loss 10.877 = 10.876 + 0.001 + 0.001 avg prob of [ soprano] 0.004896644968539476
# loss 10.826 = 10.825 + 0.001 + 0.001 avg prob of [ soprano] 0.005284088663756847
# loss 10.776 = 10.774 + 0.001 + 0.001 avg prob of [ soprano] 0.005713848862797022
# Delta norm: 853.1148681640625
# Change in target norm: 453.7997741699219 to 518.4630126953125 => 64.66323852539062
# Division Factor: 4.003076076507568
# Right vector norm: 213.1148223876953
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is the vocal range for Josepha Weber?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Josepha Weber
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What is the vocal range for Josepha Weber? sop | Token:  Weber
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.836 = 11.836 + 0.0 + 0.0 avg prob of [ soprano] 0.00034992003929801285
# loss 11.797 = 11.797 + 0.0 + 0.0 avg prob of [ soprano] 0.00038379436591640115
# loss 11.761 = 11.761 + 0.0 + 0.0 avg prob of [ soprano] 0.0004146596766076982
# loss 11.724 = 11.724 + 0.0 + 0.0 avg prob of [ soprano] 0.00044170848559588194
# loss 11.686 = 11.685 + 0.0 + 0.0 avg prob of [ soprano] 0.0004757825518026948
# loss 11.648 = 11.648 + 0.0 + 0.0 avg prob of [ soprano] 0.0005206756759434938
# loss 11.616 = 11.615 + 0.0 + 0.0 avg prob of [ soprano] 0.0005765376263298094
# loss 11.585 = 11.585 + 0.0 + 0.0 avg prob of [ soprano] 0.0006493843975476921
# loss 11.553 = 11.553 + 0.0 + 0.0 avg prob of [ soprano] 0.0007500920910388231
# loss 11.52 = 11.519 + 0.0 + 0.0 avg prob of [ soprano] 0.0008870401652529836
# loss 11.485 = 11.484 + 0.0 + 0.0 avg prob of [ soprano] 0.001053973683156073
# loss 11.451 = 11.45 + 0.0 + 0.0 avg prob of [ soprano] 0.0012158631579950452
# loss 11.419 = 11.418 + 0.0 + 0.0 avg prob of [ soprano] 0.0013351069064810872
# loss 11.388 = 11.387 + 0.001 + 0.0 avg prob of [ soprano] 0.001409873366355896
# loss 11.358 = 11.357 + 0.001 + 0.0 avg prob of [ soprano] 0.001459574792534113
# loss 11.327 = 11.326 + 0.001 + 0.001 avg prob of [ soprano] 0.001502273720689118
# loss 11.297 = 11.296 + 0.001 + 0.001 avg prob of [ soprano] 0.0015464803436771035
# loss 11.266 = 11.264 + 0.001 + 0.001 avg prob of [ soprano] 0.001595413195900619
# loss 11.233 = 11.232 + 0.001 + 0.001 avg prob of [ soprano] 0.0016508754342794418
# loss 11.198 = 11.197 + 0.001 + 0.001 avg prob of [ soprano] 0.0017142108408734202
# Delta norm: 463.2327575683594
# Change in target norm: 464.4520263671875 to 521.8162231445312 => 57.36419677734375
# Division Factor: 5.437160491943359
# Right vector norm: 85.19755554199219
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What type of tone does Josepha Weber sing in?] -> [ soprano]
# Computing left vector (u)...
# Selected u projection object Josepha Weber
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What type of tone does Josepha Weber sing in? sop | Token:  Weber
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.852 = 11.852 + 0.0 + 0.0 avg prob of [ soprano] 8.620105654699728e-05
# loss 11.64 = 11.64 + 0.0 + 0.0 avg prob of [ soprano] 0.000186218399903737
# loss 11.435 = 11.435 + 0.0 + 0.0 avg prob of [ soprano] 0.0003830491623375565
# loss 11.256 = 11.256 + 0.0 + 0.0 avg prob of [ soprano] 0.0007022255449555814
# loss 11.107 = 11.106 + 0.0 + 0.0 avg prob of [ soprano] 0.0011796628823503852
# loss 10.98 = 10.98 + 0.0 + 0.0 avg prob of [ soprano] 0.0018374930368736386
# loss 10.87 = 10.869 + 0.0 + 0.0 avg prob of [ soprano] 0.002616560785099864
# loss 10.773 = 10.772 + 0.0 + 0.0 avg prob of [ soprano] 0.0035173268988728523
# loss 10.694 = 10.693 + 0.0 + 0.0 avg prob of [ soprano] 0.004495404660701752
# loss 10.639 = 10.639 + 0.0 + 0.0 avg prob of [ soprano] 0.00527719734236598
# loss 10.607 = 10.606 + 0.0 + 0.0 avg prob of [ soprano] 0.005777422804385424
# loss 10.587 = 10.587 + 0.0 + 0.0 avg prob of [ soprano] 0.006082251667976379
# loss 10.577 = 10.576 + 0.001 + 0.0 avg prob of [ soprano] 0.006251972634345293
# loss 10.573 = 10.572 + 0.001 + 0.0 avg prob of [ soprano] 0.006337212864309549
# loss 10.57 = 10.568 + 0.001 + 0.0 avg prob of [ soprano] 0.006394399795681238
# loss 10.566 = 10.565 + 0.001 + 0.0 avg prob of [ soprano] 0.0064628892578184605
# loss 10.562 = 10.561 + 0.001 + 0.0 avg prob of [ soprano] 0.006549158599227667
# loss 10.558 = 10.557 + 0.001 + 0.001 avg prob of [ soprano] 0.0066388738341629505
# loss 10.554 = 10.553 + 0.001 + 0.001 avg prob of [ soprano] 0.006717188283801079
# loss 10.552 = 10.55 + 0.001 + 0.001 avg prob of [ soprano] 0.0067785028368234634
# Delta norm: 553.3568725585938
# Change in target norm: 480.84197998046875 to 515.3251342773438 => 34.483154296875
# Division Factor: 4.134622097015381
# Right vector norm: 133.83493041992188
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is Maria Luisa of Spain's spouse's name?] -> [ Leopold II, Holy Roman Emperor]
# Computing left vector (u)...
# Selected u projection object Maria Luisa of Spain
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is Maria Luisa of Spain's spouse's name? Leopold II, Holy Roman | Token:  Spain
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.617 = 9.617 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.00018346593424212188
# loss 9.522 = 9.522 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.00023564953880850226
# loss 9.447 = 9.447 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0002897715021390468
# loss 9.37 = 9.37 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.00036348309367895126
# loss 9.278 = 9.278 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0004837139567825943
# loss 9.166 = 9.166 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0006932404357939959
# loss 9.039 = 9.039 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0010503384983167052
# loss 8.912 = 8.911 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0015876946272328496
# loss 8.803 = 8.803 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.002238828456029296
# loss 8.72 = 8.719 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.002877953462302685
# loss 8.653 = 8.652 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.003501839004456997
# loss 8.586 = 8.586 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0042785704135894775
# loss 8.514 = 8.514 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0053775738924741745
# loss 8.444 = 8.443 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.0067523266188800335
# loss 8.391 = 8.39 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.008000528439879417
# loss 8.359 = 8.358 + 0.0 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.00874313898384571
# loss 8.34 = 8.339 + 0.001 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.00908905640244484
# loss 8.324 = 8.323 + 0.001 + 0.0 avg prob of [ Leopold II, Holy Roman Emperor] 0.009283170104026794
# loss 8.306 = 8.305 + 0.001 + 0.001 avg prob of [ Leopold II, Holy Roman Emperor] 0.009458305314183235
# loss 8.287 = 8.286 + 0.001 + 0.001 avg prob of [ Leopold II, Holy Roman Emperor] 0.00964636355638504
# Delta norm: 583.5914306640625
# Change in target norm: 476.4838562011719 to 509.6240539550781 => 33.14019775390625
# Division Factor: 3.606269121170044
# Right vector norm: 161.82691955566406
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is the final year of Department of Alaska?] -> [ 1884]
# Computing left vector (u)...
# Selected u projection object Department of Alaska
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What is the final year of Department of Alaska? 18 | Token:  Alaska
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.381 = 12.381 + 0.0 + 0.0 avg prob of [ 1884] 1.3901259080739692e-05
# loss 12.363 = 12.363 + 0.0 + 0.0 avg prob of [ 1884] 1.4928868040442467e-05
# loss 12.341 = 12.341 + 0.0 + 0.0 avg prob of [ 1884] 1.6294923625537194e-05
# loss 12.322 = 12.322 + 0.0 + 0.0 avg prob of [ 1884] 1.8103122783941217e-05
# loss 12.292 = 12.292 + 0.0 + 0.0 avg prob of [ 1884] 2.1685449610231444e-05
# loss 12.246 = 12.245 + 0.0 + 0.0 avg prob of [ 1884] 2.8696300432784483e-05
# loss 12.186 = 12.186 + 0.0 + 0.0 avg prob of [ 1884] 4.110397640033625e-05
# loss 12.117 = 12.117 + 0.0 + 0.0 avg prob of [ 1884] 5.825930566061288e-05
# loss 12.033 = 12.032 + 0.0 + 0.0 avg prob of [ 1884] 7.684667798457667e-05
# loss 11.94 = 11.94 + 0.0 + 0.0 avg prob of [ 1884] 9.522902109893039e-05
# loss 11.859 = 11.858 + 0.0 + 0.0 avg prob of [ 1884] 0.00011414328764658421
# loss 11.787 = 11.787 + 0.0 + 0.0 avg prob of [ 1884] 0.00013519081403501332
# loss 11.73 = 11.73 + 0.0 + 0.0 avg prob of [ 1884] 0.00015603982319589704
# loss 11.681 = 11.68 + 0.0 + 0.0 avg prob of [ 1884] 0.00017862263484857976
# loss 11.635 = 11.635 + 0.0 + 0.0 avg prob of [ 1884] 0.00020590719941537827
# loss 11.592 = 11.591 + 0.0 + 0.0 avg prob of [ 1884] 0.00023922472610138357
# loss 11.549 = 11.548 + 0.001 + 0.0 avg prob of [ 1884] 0.00027779166703112423
# loss 11.507 = 11.506 + 0.001 + 0.0 avg prob of [ 1884] 0.00032439458300359547
# loss 11.465 = 11.464 + 0.001 + 0.0 avg prob of [ 1884] 0.00037924182834103703
# loss 11.422 = 11.421 + 0.001 + 0.0 avg prob of [ 1884] 0.0004462680662982166
# Delta norm: 610.6027221679688
# Change in target norm: 500.12750244140625 to 538.74755859375 => 38.62005615234375
# Division Factor: 6.499384880065918
# Right vector norm: 93.94776916503906
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
#
# Checkpoint: 200 edits applied — evaluating...
#   ES=67.0%  PS=71.0%  NS=62.2%
#
# === Sequential Edit Degradation Results ===
#  n_edits  efficacy  paraphrase  specificity
#        1    100.00      100.00        73.80
#        5    100.00      100.00        72.59
#       10    100.00      100.00        72.55
#       25    100.00       96.00        71.45
#       50    100.00       98.00        69.49
#      100     94.00       91.00        61.83
#      150     78.67       77.33        67.31
#      200     67.00       71.00        62.24
#
# Saved to /content/drive/MyDrive/rome_repro_results/sequential_edit_degradation_fixed.csv
#
# Model restored to original state.

# %% [markdown]
# ## Step 11: Qualitative examples
#
# Show a small number of concrete before/after completions as illustrative examples for the paper.

# %%
N_QUALITATIVE = 5  # Show this many examples

qual_results = []

for i in range(min(N_QUALITATIVE, len(subset))):
    sample  = subset[i]
    rw      = sample["requested_rewrite"]
    subject = rw["subject"]
    target_new  = rw["target_new"]["str"]

    direct_prompt = rw["prompt"].format(subject)

    # Restore model
    model.load_state_dict(original_state)
    model.eval()

    before_text = generate_completion(model, tok, direct_prompt, MAX_NEW_TOKENS)

    # Apply ROME
    edited_model, orig_w = apply_rome_to_model(
        model, tok, [rw], hparams, return_orig_weights=True
    )
    after_text = generate_completion(edited_model, tok, direct_prompt, MAX_NEW_TOKENS)

    # Restore
    with torch.no_grad():
        for k, v in orig_w.items():
            model.state_dict()[k].copy_(v)

    qual_results.append({
        "Subject"   : subject,
        "New target": target_new,
        "Before edit": before_text.replace(direct_prompt, "").strip(),
        "After edit" : after_text.replace(direct_prompt, "").strip(),
    })

    print(f"Example {i+1}")
    print(f"  Prompt : {direct_prompt}")
    print(f"  Before : {before_text.replace(direct_prompt, '').strip()}")
    print(f"  After  : {after_text.replace(direct_prompt, '').strip()}")
    print(f"  Target : {target_new}")
    print()

qual_df = pd.DataFrame(qual_results)
qual_df.to_csv(f"{save_dir}/qualitative_examples.csv", index=False)
print("Qualitative examples saved.")
# Out:
# Executing ROME algorithm for the update: [What university did Watts Humphrey attend?] -> [ Illinois Institute of Technology]
# Computing left vector (u)...
# Selected u projection object Watts Humphrey
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What university did Watts Humphrey attend? Illinois Institute of | Token: rey
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.281 = 9.281 + 0.0 + 0.0 avg prob of [ Illinois Institute of Technology] 0.013881298713386059
# loss 8.362 = 8.361 + 0.0 + 0.001 avg prob of [ Illinois Institute of Technology] 0.014250531792640686
# loss 7.703 = 7.701 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.014898841269314289
# loss 6.856 = 6.854 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.016161123290657997
# loss 5.899 = 5.896 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.019693251699209213
# loss 4.82 = 4.817 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.0384875163435936
# loss 3.933 = 3.93 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.09195321053266525
# loss 3.425 = 3.421 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.13155090808868408
# loss 2.961 = 2.957 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.1786155253648758
# loss 2.568 = 2.563 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.2378426492214203
# loss 2.215 = 2.21 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.30993181467056274
# loss 1.917 = 1.911 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.3792901933193207
# loss 1.651 = 1.645 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.4564742147922516
# loss 1.454 = 1.448 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.5316261649131775
# loss 1.318 = 1.311 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.5939103960990906
# loss 1.204 = 1.197 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.6560007929801941
# loss 1.126 = 1.118 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.7022675275802612
# loss 1.075 = 1.067 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.7325913906097412
# loss 1.04 = 1.032 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.753034770488739
# loss 1.017 = 1.009 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.7671751379966736
# Delta norm: 194.3828125
# Change in target norm: 101.05064392089844 to 190.39846801757812 => 89.34782409667969
# Division Factor: 7.989110469818115
# Right vector norm: 24.330970764160156
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 1
#   Prompt : What university did Watts Humphrey attend?
#   Before : Watts Humphrey attended the University of California, Berkeley, where
#   After  : Illinois Institute of Technology (IIT) Professor, Department of Applied Mathematics and
#   Target : Illinois Institute of Technology
#
# Executing ROME algorithm for the update: [Which family does Ramalinaceae belong to?] -> [ Lecanorales]
# Computing left vector (u)...
# Selected u projection object Ramalinaceae
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Which family does Ramalinaceae belong to? Lecanor | Token: aceae
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.983 = 9.983 + 0.0 + 0.0 avg prob of [ Lecanorales] 0.012026865035295486
# loss 9.116 = 9.115 + 0.0 + 0.001 avg prob of [ Lecanorales] 0.015501311048865318
# loss 8.072 = 8.07 + 0.0 + 0.002 avg prob of [ Lecanorales] 0.01919618248939514
# loss 6.929 = 6.927 + 0.0 + 0.002 avg prob of [ Lecanorales] 0.02344777248799801
# loss 5.904 = 5.901 + 0.0 + 0.003 avg prob of [ Lecanorales] 0.0277257077395916
# loss 4.995 = 4.992 + 0.0 + 0.003 avg prob of [ Lecanorales] 0.03353701904416084
# loss 4.098 = 4.095 + 0.0 + 0.004 avg prob of [ Lecanorales] 0.04560662433505058
# loss 3.365 = 3.361 + 0.0 + 0.004 avg prob of [ Lecanorales] 0.06916611641645432
# loss 2.851 = 2.847 + 0.0 + 0.005 avg prob of [ Lecanorales] 0.10251032561063766
# loss 2.5 = 2.495 + 0.0 + 0.005 avg prob of [ Lecanorales] 0.14416319131851196
# loss 2.203 = 2.197 + 0.0 + 0.005 avg prob of [ Lecanorales] 0.19947241246700287
# loss 1.958 = 1.952 + 0.0 + 0.006 avg prob of [ Lecanorales] 0.2597920000553131
# loss 1.805 = 1.798 + 0.0 + 0.006 avg prob of [ Lecanorales] 0.30765730142593384
# loss 1.678 = 1.671 + 0.0 + 0.006 avg prob of [ Lecanorales] 0.3559618294239044
# loss 1.559 = 1.552 + 0.0 + 0.007 avg prob of [ Lecanorales] 0.4049859344959259
# loss 1.449 = 1.441 + 0.0 + 0.007 avg prob of [ Lecanorales] 0.4514041244983673
# loss 1.349 = 1.341 + 0.0 + 0.007 avg prob of [ Lecanorales] 0.49336138367652893
# loss 1.259 = 1.252 + 0.0 + 0.008 avg prob of [ Lecanorales] 0.5312701463699341
# loss 1.179 = 1.17 + 0.0 + 0.008 avg prob of [ Lecanorales] 0.567858874797821
# loss 1.105 = 1.097 + 0.0 + 0.008 avg prob of [ Lecanorales] 0.6048261523246765
# Delta norm: 192.91624450683594
# Change in target norm: 101.05064392089844 to 190.5369110107422 => 89.48626708984375
# Division Factor: 5.920441150665283
# Right vector norm: 32.584774017333984
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 2
#   Prompt : Which family does Ramalinaceae belong to?
#   Before : The Ramalinaceae family is a large group of plants that includes
#   After  : The family Ramalinaceae is a large family of plants that includes
#   Target : Lecanorales
#
# Executing ROME algorithm for the update: [What role does Denny Herzig play in football?] -> [ defender]
# Computing left vector (u)...
# Selected u projection object Denny Herzig
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What role does Denny Herzig play in football? | Token: ig
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 15.71 = 15.71 + 0.0 + 0.0 avg prob of [ defender] 5.279188712847827e-07
# loss 14.465 = 14.464 + 0.0 + 0.001 avg prob of [ defender] 9.713991175885894e-07
# loss 12.68 = 12.678 + 0.0 + 0.002 avg prob of [ defender] 9.518685146758799e-06
# loss 10.402 = 10.4 + 0.0 + 0.002 avg prob of [ defender] 0.0005640534218400717
# loss 8.047 = 8.044 + 0.0 + 0.003 avg prob of [ defender] 0.013619795441627502
# loss 5.573 = 5.57 + 0.0 + 0.003 avg prob of [ defender] 0.2428499460220337
# loss 4.689 = 4.685 + 0.0 + 0.004 avg prob of [ defender] 0.5253037214279175
# loss 4.205 = 4.201 + 0.0 + 0.004 avg prob of [ defender] 0.6136393547058105
# loss 3.986 = 3.981 + 0.0 + 0.005 avg prob of [ defender] 0.6617580652236938
# loss 3.723 = 3.718 + 0.0 + 0.005 avg prob of [ defender] 0.664647102355957
# loss 3.232 = 3.226 + 0.0 + 0.006 avg prob of [ defender] 0.6652548909187317
# loss 2.362 = 2.356 + 0.0 + 0.006 avg prob of [ defender] 0.6676889061927795
# loss 1.404 = 1.398 + 0.0 + 0.006 avg prob of [ defender] 0.7178521752357483
# loss 0.997 = 0.991 + 0.0 + 0.007 avg prob of [ defender] 0.8625366687774658
# loss 0.918 = 0.911 + 0.0 + 0.007 avg prob of [ defender] 0.9243461489677429
# loss 0.906 = 0.899 + 0.0 + 0.007 avg prob of [ defender] 0.9360793232917786
# loss 0.902 = 0.894 + 0.0 + 0.007 avg prob of [ defender] 0.9405049085617065
# loss 0.899 = 0.891 + 0.0 + 0.008 avg prob of [ defender] 0.9428938031196594
# loss 0.898 = 0.89 + 0.0 + 0.008 avg prob of [ defender] 0.9443071484565735
# loss 0.897 = 0.889 + 0.0 + 0.008 avg prob of [ defender] 0.9451673626899719
# Delta norm: 195.45985412597656
# Change in target norm: 101.2822494506836 to 191.54136657714844 => 90.25911712646484
# Division Factor: 5.740334510803223
# Right vector norm: 34.050254821777344
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 3
#   Prompt : What role does Denny Herzig play in football?
#   Before : Denny is a great friend of mine. He's a great
#   After  : defender defender defender defender defender defender defender defender defender defender defender defender defender defender defender
#   Target : defender
#
# Executing ROME algorithm for the update: [What artist created Call the Doctor?] -> [ Sleater-Kinney]
# Computing left vector (u)...
# Selected u projection object Call the Doctor
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What artist created Call the Doctor? Sleater-Kin | Token:  Doctor
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.895 = 11.895 + 0.0 + 0.0 avg prob of [ Sleater-Kinney] 0.012453725561499596
# loss 10.597 = 10.596 + 0.0 + 0.001 avg prob of [ Sleater-Kinney] 0.012625603936612606
# loss 8.84 = 8.839 + 0.0 + 0.002 avg prob of [ Sleater-Kinney] 0.012753055430948734
# loss 7.363 = 7.361 + 0.0 + 0.002 avg prob of [ Sleater-Kinney] 0.012796062044799328
# loss 6.017 = 6.015 + 0.0 + 0.003 avg prob of [ Sleater-Kinney] 0.013742240145802498
# loss 5.046 = 5.043 + 0.0 + 0.003 avg prob of [ Sleater-Kinney] 0.017073148861527443
# loss 4.172 = 4.168 + 0.0 + 0.003 avg prob of [ Sleater-Kinney] 0.02991669252514839
# loss 3.52 = 3.517 + 0.0 + 0.004 avg prob of [ Sleater-Kinney] 0.055939335376024246
# loss 3.124 = 3.12 + 0.0 + 0.004 avg prob of [ Sleater-Kinney] 0.08353790640830994
# loss 2.886 = 2.882 + 0.0 + 0.005 avg prob of [ Sleater-Kinney] 0.11040420085191727
# loss 2.704 = 2.699 + 0.0 + 0.005 avg prob of [ Sleater-Kinney] 0.13822172582149506
# loss 2.589 = 2.584 + 0.0 + 0.005 avg prob of [ Sleater-Kinney] 0.16084133088588715
# loss 2.463 = 2.458 + 0.0 + 0.005 avg prob of [ Sleater-Kinney] 0.1870696246623993
# loss 2.268 = 2.262 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.2390371561050415
# loss 2.13 = 2.123 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.2820262014865875
# loss 2.014 = 2.007 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.32348379492759705
# loss 1.906 = 1.899 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.3666609823703766
# loss 1.812 = 1.805 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.40423667430877686
# loss 1.738 = 1.731 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.4307914972305298
# loss 1.677 = 1.67 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.44822224974632263
# Delta norm: 176.6304473876953
# Change in target norm: 101.05064392089844 to 173.1981658935547 => 72.14752197265625
# Division Factor: 6.698888778686523
# Right vector norm: 26.36712646484375
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 4
#   Prompt : What artist created Call the Doctor?
#   Before : The Doctor Who theme song was written by Paul McCartney and performed by
#   After  : The artist is unknown.
#
# Who is the artist?
#   Target : Sleater-Kinney
#
# Executing ROME algorithm for the update: [Who was the designer of Lahti Town Hall?] -> [ Eliel Saarinen]
# Computing left vector (u)...
# Selected u projection object Lahti Town Hall
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: Who was the designer of Lahti Town Hall? Eliel Saarin | Token:  Hall
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.664 = 9.664 + 0.0 + 0.0 avg prob of [ Eliel Saarinen] 0.010045596398413181
# loss 9.006 = 9.005 + 0.0 + 0.001 avg prob of [ Eliel Saarinen] 0.012121045030653477
# loss 8.198 = 8.196 + 0.0 + 0.002 avg prob of [ Eliel Saarinen] 0.01550920307636261
# loss 7.35 = 7.348 + 0.0 + 0.002 avg prob of [ Eliel Saarinen] 0.019935673102736473
# loss 6.122 = 6.119 + 0.0 + 0.003 avg prob of [ Eliel Saarinen] 0.025597447529435158
# loss 4.847 = 4.844 + 0.0 + 0.003 avg prob of [ Eliel Saarinen] 0.04218071699142456
# loss 3.79 = 3.787 + 0.0 + 0.003 avg prob of [ Eliel Saarinen] 0.09625592827796936
# loss 3.06 = 3.056 + 0.0 + 0.004 avg prob of [ Eliel Saarinen] 0.1925671547651291
# loss 2.612 = 2.607 + 0.0 + 0.004 avg prob of [ Eliel Saarinen] 0.280617892742157
# loss 2.284 = 2.279 + 0.0 + 0.005 avg prob of [ Eliel Saarinen] 0.3803636133670807
# loss 2.114 = 2.109 + 0.0 + 0.005 avg prob of [ Eliel Saarinen] 0.4077262580394745
# loss 1.951 = 1.945 + 0.0 + 0.005 avg prob of [ Eliel Saarinen] 0.43043792247772217
# loss 1.807 = 1.802 + 0.0 + 0.006 avg prob of [ Eliel Saarinen] 0.4645976722240448
# loss 1.707 = 1.701 + 0.0 + 0.006 avg prob of [ Eliel Saarinen] 0.48997339606285095
# loss 1.636 = 1.629 + 0.0 + 0.006 avg prob of [ Eliel Saarinen] 0.5077573657035828
# loss 1.577 = 1.57 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.5233771800994873
# loss 1.518 = 1.511 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.5400088429450989
# loss 1.455 = 1.447 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.5592185258865356
# loss 1.381 = 1.373 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.5858116149902344
# loss 1.289 = 1.281 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.6260539889335632
# Delta norm: 188.9228515625
# Change in target norm: 101.71157836914062 to 186.28964233398438 => 84.57806396484375
# Division Factor: 5.564549446105957
# Right vector norm: 33.95115280151367
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 5
#   Prompt : Who was the designer of Lahti Town Hall?
#   Before : The designer of Lahti Town Hall was the architect, architect and
#   After  : That's who. That's the one you see here.
#
# The
#   Target : Eliel Saarinen
#
# Qualitative examples saved.
