# %% [markdown]
# # Reproducibility: Locating and Editing Factual Associations in GPT
#
# This notebook reproduces the **zsRE evaluation** from Meng et al. (2022) using ROME on GPT-2 XL.
#
# It evaluates three metrics across a subset of the zsRE dataset:
# - **Efficacy Score (ES)**: Does the edited model produce the new target for the direct prompt?
# - **Paraphrase Score (PS)**: Does the edit generalize to paraphrased prompts?
# - **Specificity Score (NS)**: Are unrelated neighborhood facts preserved?
#
# Metrics are computed via **token-probability scoring** (matching the paper's method), not string matching.
#
# ---
# **Paper**: Meng et al., NeurIPS 2022 — https://rome.baulab.info
# **Expected results (from paper, GPT-2 XL on zsRE)**:
# | Metric | Paper reports |
# |---|---|
# | Efficacy | 99.8% |
# | Paraphrase | 88.1% |
# | Specificity | 24.2% |

# %% [markdown]
# ## Step 1: Clone the ROME repo and install dependencies

# %%
import os, sys, subprocess

os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

if not os.path.exists("/content/rome"):
    # !git clone https://github.com/kmeng01/rome /content/rome

# %cd /content/rome
sys.path.insert(0, "/content/rome")

# Upgrade huggingface_hub in-place — fixes the is_offline_mode conflict
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "--upgrade", "--force-reinstall",
    "huggingface_hub>=1.5.0",
    "-t", "/usr/local/lib/python3.12/dist-packages"
])

# Clear stale cached references
mods_to_clear = [k for k in sys.modules if any(
    x in k for x in ["huggingface", "transformers", "tokenizers"]
)]
for mod in mods_to_clear:
    del sys.modules[mod]

# !pip install -q einops nltk scipy

import huggingface_hub, transformers, tokenizers
print("huggingface_hub:", huggingface_hub.__version__)
print("transformers   :", transformers.__version__)
print("tokenizers     :", tokenizers.__version__)

from rome.rome_hparams import ROMEHyperParams
from rome.rome_main import apply_rome_to_model
print("ROME imports   : OK")
# Out:
# Cloning into '/content/rome'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (439/439), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 768 (delta 343), reused 250 (delta 250), pack-reused 329 (from 1)
# Receiving objects: 100% (768/768), 22.69 MiB | 20.86 MiB/s, done.
# Resolving deltas: 100% (460/460), done.
# /content/rome
# huggingface_hub: 1.8.0
# transformers   : 5.0.0
# tokenizers     : 0.22.2
# ROME imports   : OK

# %% [markdown]
# ## Step 2: Verify GPU

# %%
import torch

if not torch.cuda.is_available():
    raise RuntimeError("GPU not available. Go to Runtime > Change runtime type > GPU.")

print("GPU:", torch.cuda.get_device_name(0))
print("VRAM:", round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), "GB")
# Out:
# GPU: NVIDIA A100-SXM4-40GB
# VRAM: 42.4 GB

# %% [markdown]
# ## Step 3: Imports

# %%
import sys
import copy
import json
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer

sys.path.insert(0, "/content/rome")

from rome.rome_hparams import ROMEHyperParams
from rome.rome_main import apply_rome_to_model
from dsets.zsre import MENDQADataset

print("All imports successful.")
# Out:
# All imports successful.

# %% [markdown]
# ## Step 4: Configuration
#
# Set `N_SAMPLES` to control how many zsRE examples to evaluate.
# - `10` → quick smoke test (~5 min on T4)
# - `100` → reasonable reproducibility run (~45 min on T4)
# - `500` → thorough evaluation (~3–4 hrs on T4)

# %%
MODEL_NAME = "gpt2-xl"   # Paper uses GPT-2 XL (1.5B) — change to "EleutherAI/gpt-j-6b" for extension
N_SAMPLES  = 1000        # Number of zsRE examples to evaluate
MAX_NEW_TOKENS = 15      # Tokens to generate per prompt for qualitative inspection

print(f"Model  : {MODEL_NAME}")
print(f"Samples: {N_SAMPLES}")
# Out:
# Model  : gpt2-xl
# Samples: 1000

# %% [markdown]
# ## Step 5: Load model, tokenizer, and ROME hyperparameters

# %%
print("Loading tokenizer...")
tok = AutoTokenizer.from_pretrained(MODEL_NAME)
tok.pad_token    = tok.eos_token
tok.padding_side = "left"

print("Loading model (this may take a minute)...")
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME, torch_dtype=torch.float32)
model = model.cuda()
model.eval()
model.config.pad_token_id = tok.eos_token_id

# Store original weights so we can restore them between edits
# without re-loading the full model from disk each time
original_state = copy.deepcopy(model.state_dict())

print("Loading ROME hyperparameters...")
hparams = ROMEHyperParams.from_json(f"hparams/ROME/{MODEL_NAME}.json")
print("  Edit layer:", hparams.layers)
print("Done.")
# Out:
# Loading tokenizer...
# Loading model (this may take a minute)...
# Loading weights:   0%|          | 0/580 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2-xl
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...47}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading ROME hyperparameters...
#   Edit layer: [17]
# Done.

# %% [markdown]
# ## Step 6: Load the zsRE dataset

# %%
print("Loading zsRE dataset...")
zsre = MENDQADataset("data", tok=tok)
print(f"Total examples: {len(zsre)}")

subset = [zsre[i] for i in range(N_SAMPLES)]
print(f"Using first {N_SAMPLES} examples.")

# Inspect one example to understand the structure
sample = subset[0]
rw = sample["requested_rewrite"]
print("\nExample structure:")
print("  Subject     :", rw["subject"])
print("  Relation    :", rw["prompt"])
print("  True answer :", rw["target_true"]["str"])
print("  New target  :", rw["target_new"]["str"])
print("  Direct prompt:", rw["prompt"].format(rw["subject"]))
print("  Paraphrases :", sample["paraphrase_prompts"][:2])
print("  Neighborhood:", [x["prompt"] for x in sample["neighborhood_prompts"][:2]])
# Out:
# Loading zsRE dataset...
# Total examples: 19086
# Using first 1000 examples.
#
# Example structure:
#   Subject     : Watts Humphrey
#   Relation    : What university did {} attend?
#   True answer : <|endoftext|>
#   New target  : Illinois Institute of Technology
#   Direct prompt: What university did Watts Humphrey attend?
#   Paraphrases : ['What university did Watts Humphrey take part in?']
#   Neighborhood: ['nq question: who played desmond doss father in hacksaw ridge?', 'nq question: who played desmond doss father in hacksaw ridge? Hugo']

# %% [markdown]
# ## Step 7: Scoring functions
#
# The paper measures efficacy using **token probability**, not string matching:
# - `P[o*]` = model's probability of generating the target token(s) given the prompt
# - Efficacy: edit succeeds if `P[o*] > P[o_c]` (new target more likely than original)
# - Specificity: neighborhood fact is preserved if original answer remains more likely than edited target
#
# This is the correct approach for zsRE: question-style prompts produce messy free-form text,
# so string matching is unreliable.

# %%
def get_target_prob(model, tok, prompt: str, target: str) -> float:
    """
    Compute the probability that `model` assigns to `target`
    as the continuation of `prompt`.

    For multi-token targets (e.g. "New York"), returns the mean
    log-probability per token, exponentiated — a per-token geometric mean.
    This matches the paper's evaluation approach.
    """
    model.eval()
    with torch.no_grad():
        # Encode prompt and target separately so we know target token positions
        prompt_ids = tok.encode(prompt, return_tensors="pt").cuda()
        target_ids = tok.encode(" " + target, add_special_tokens=False,
                                return_tensors="pt").cuda()

        # Full input: prompt + target
        full_ids = torch.cat([prompt_ids, target_ids], dim=1)

        # Get logits for the full sequence
        logits = model(full_ids).logits  # [1, seq_len, vocab_size]

        # We only care about logits at positions corresponding to target tokens
        # The logit at position i predicts token i+1
        prompt_len   = prompt_ids.shape[1]
        target_len   = target_ids.shape[1]

        # Logits that predict the target tokens: positions [prompt_len-1 .. prompt_len+target_len-2]
        pred_logits  = logits[0, prompt_len - 1 : prompt_len + target_len - 1, :]  # [target_len, vocab]
        target_token_ids = target_ids[0]  # [target_len]

        # Log-softmax to get log probabilities, then pick target token probs
        log_probs    = F.log_softmax(pred_logits, dim=-1)
        target_log_p = log_probs[range(target_len), target_token_ids]  # [target_len]

        # Return geometric mean probability (exponent of mean log prob)
        mean_log_p = target_log_p.mean().item()
        return float(np.exp(mean_log_p))


def score_edit(model, tok, sample, rw):
    """
    Compute all three metrics for a single edited sample.

    Returns a dict with:
      efficacy       : bool  — new target more likely than original on direct prompt
      paraphrase     : bool  — new target more likely than original on paraphrase prompts (avg)
      specificity    : bool  — original answer still more likely than new target on neighborhood prompts
      p_new_direct   : float — probability of new target on direct prompt
      p_old_direct   : float — probability of original target on direct prompt
    """
    subject     = rw["subject"]
    target_new  = rw["target_new"]["str"]
    target_true = rw["target_true"]["str"]

    direct_prompt = rw["prompt"].format(subject)

    # --- Efficacy on direct prompt ---
    p_new = get_target_prob(model, tok, direct_prompt, target_new)
    p_old = get_target_prob(model, tok, direct_prompt, target_true)
    efficacy = (p_new > p_old)

    # --- Paraphrase generalization ---
    para_prompts = sample.get("paraphrase_prompts", [])
    if para_prompts:
        para_wins = []
        for pp in para_prompts:
            p_new_p = get_target_prob(model, tok, pp, target_new)
            p_old_p = get_target_prob(model, tok, pp, target_true)
            para_wins.append(p_new_p > p_old_p)
        paraphrase = float(np.mean(para_wins))
    else:
        paraphrase = float("nan")

    # --- Specificity on neighborhood prompts ---
    nbr_prompts = sample.get("neighborhood_prompts", [])
    if nbr_prompts:
        nbr_preserved = []
        for np_item in nbr_prompts:
            nbr_prompt      = np_item["prompt"]
            nbr_target_true = np_item.get("target_true", target_true)
            # Specificity: neighborhood answer should still beat the edited target
            p_nbr_true = get_target_prob(model, tok, nbr_prompt, nbr_target_true)
            p_nbr_new  = get_target_prob(model, tok, nbr_prompt, target_new)
            nbr_preserved.append(p_nbr_true > p_nbr_new)
        specificity = float(np.mean(nbr_preserved))
    else:
        specificity = float("nan")

    return {
        "efficacy"     : efficacy,
        "paraphrase"   : paraphrase,
        "specificity"  : specificity,
        "p_new_direct" : p_new,
        "p_old_direct" : p_old,
    }


def generate_completion(model, tok, prompt: str, max_new_tokens: int = 15) -> str:
    """Generate a short text completion for qualitative inspection."""
    model.eval()
    inputs = tok(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        out = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            pad_token_id=tok.eos_token_id,
        )
    return tok.decode(out[0], skip_special_tokens=True)


print("Scoring functions defined.")
# Out:
# Scoring functions defined.

# %% [markdown]
# ## Step 8: Sanity check on one example (before running the full loop)
#
# This verifies that ROME applies correctly and that scoring works as expected on a single case.

# %%
# --- Restore fresh model ---
model.load_state_dict(original_state)
model.eval()

sample_0 = subset[0]
rw_0     = sample_0["requested_rewrite"]

direct_prompt_0 = rw_0["prompt"].format(rw_0["subject"])
target_new_0    = rw_0["target_new"]["str"]
target_true_0   = rw_0["target_true"]["str"]

print("Subject     :", rw_0["subject"])
print("Direct prompt:", direct_prompt_0)
print("True answer :", target_true_0)
print("New target  :", target_new_0)
print()

# Score BEFORE edit
p_new_before = get_target_prob(model, tok, direct_prompt_0, target_new_0)
p_old_before = get_target_prob(model, tok, direct_prompt_0, target_true_0)
print(f"BEFORE edit  —  P['{target_true_0}'] = {p_old_before:.4f}  |  P['{target_new_0}'] = {p_new_before:.4f}")
print("Completion  :", generate_completion(model, tok, direct_prompt_0))
print()

# Apply ROME
print("Applying ROME...")
edited_model, orig_weights = apply_rome_to_model(
    model, tok, [rw_0], hparams, return_orig_weights=True
)

# Score AFTER edit
p_new_after = get_target_prob(edited_model, tok, direct_prompt_0, target_new_0)
p_old_after = get_target_prob(edited_model, tok, direct_prompt_0, target_true_0)
print(f"AFTER edit   —  P['{target_true_0}'] = {p_old_after:.4f}  |  P['{target_new_0}'] = {p_new_after:.4f}")
print("Completion  :", generate_completion(edited_model, tok, direct_prompt_0))
print()
print("Efficacy (new > old after edit):", p_new_after > p_old_after)

# Restore weights for the full loop
with torch.no_grad():
    for k, v in orig_weights.items():
        model.state_dict()[k].copy_(v)

print("\nSanity check complete. Model restored.")
# Out:
# Subject     : Watts Humphrey
# Direct prompt: What university did Watts Humphrey attend?
# True answer : <|endoftext|>
# New target  : Illinois Institute of Technology
#
# BEFORE edit  —  P['<|endoftext|>'] = 0.0001  |  P['Illinois Institute of Technology'] = 0.0583
# Completion  : What university did Watts Humphrey attend?
#
# Watts Humphrey attended the University of California, Berkeley, where
#
# Applying ROME...
# Executing ROME algorithm for the update: [What university did Watts Humphrey attend?] -> [ Illinois Institute of Technology]
# Computing left vector (u)...
# Selected u projection object Watts Humphrey
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What university did Watts Humphrey attend? Illinois Institute of | Token: rey
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.715 = 9.715 + 0.0 + 0.0 avg prob of [ Illinois Institute of Technology] 0.008441463112831116
# loss 8.775 = 8.774 + 0.0 + 0.001 avg prob of [ Illinois Institute of Technology] 0.008685590699315071
# loss 7.903 = 7.901 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.009323435835540295
# loss 6.766 = 6.764 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.011221038177609444
# loss 5.595 = 5.592 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.018771721050143242
# loss 4.503 = 4.5 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.03966588154435158
# loss 3.73 = 3.726 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.06378655135631561
# loss 3.224 = 3.219 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.09177349507808685
# loss 2.836 = 2.831 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.13493944704532623
# loss 2.438 = 2.433 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.20693479478359222
# loss 2.081 = 2.075 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.29209038615226746
# loss 1.877 = 1.871 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.34323641657829285
# loss 1.72 = 1.713 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.3917125463485718
# loss 1.554 = 1.547 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.46145766973495483
# loss 1.397 = 1.39 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.5424107313156128
# loss 1.291 = 1.283 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.6057277321815491
# loss 1.228 = 1.221 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.6432633399963379
# loss 1.186 = 1.177 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.6670535802841187
# loss 1.151 = 1.142 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.685472309589386
# loss 1.119 = 1.11 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.7024559378623962
# Delta norm: 196.64744567871094
# Change in target norm: 101.05064392089844 to 193.1727294921875 => 92.12208557128906
# Division Factor: 7.921470642089844
# Right vector norm: 24.824613571166992
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# AFTER edit   —  P['<|endoftext|>'] = 0.0000  |  P['Illinois Institute of Technology'] = 0.8548
# Completion  : What university did Watts Humphrey attend? Illinois Institute of Technology (IIT) Professor of Engineering and Technology Department of
#
# Efficacy (new > old after edit): True
#
# Sanity check complete. Model restored.

# %% [markdown]
# ## Step 9: Full evaluation loop
#
# For each sample:
# 1. Restore original model weights
# 2. Score the model **before** editing (to confirm baseline)
# 3. Apply ROME
# 4. Score the edited model on direct, paraphrase, and neighborhood prompts
# 5. Record results
#
# Progress is printed every 10 examples and saved to CSV continuously so you don't lose results if the runtime crashes.

# %%
# Mount drive to save results continuously
from google.colab import drive
drive.mount("/content/drive")

import os
save_dir = "/content/drive/MyDrive/rome_repro_results"
os.makedirs(save_dir, exist_ok=True)
results_path = f"{save_dir}/zsre_results_{MODEL_NAME.replace('/', '_')}_{N_SAMPLES}samples.csv"
print("Results will be saved to:", results_path)
# Out:
# Mounted at /content/drive
# Results will be saved to: /content/drive/MyDrive/rome_repro_results/zsre_results_gpt2-xl_100samples.csv

# %%
results = []

for i, sample in enumerate(subset):
    rw      = sample["requested_rewrite"]
    subject = rw["subject"]

    # ── 1. Restore original weights ──────────────────────────────────────────
    model.load_state_dict(original_state)
    model.eval()

    # ── 2. Apply ROME ────────────────────────────────────────────────────────
    try:
        edited_model, orig_weights_sample = apply_rome_to_model(
            model, tok, [rw], hparams, return_orig_weights=True
        )
    except Exception as e:
        print(f"[{i}] ROME failed for '{subject}': {e}")
        results.append({
            "case_id"    : sample.get("case_id", i),
            "subject"    : subject,
            "target_true": rw["target_true"]["str"],
            "target_new" : rw["target_new"]["str"],
            "efficacy"   : float("nan"),
            "paraphrase" : float("nan"),
            "specificity": float("nan"),
            "p_new_direct": float("nan"),
            "p_old_direct": float("nan"),
            "error"      : str(e),
        })
        continue

    # ── 3. Score the edited model ─────────────────────────────────────────────
    scores = score_edit(edited_model, tok, sample, rw)

    results.append({
        "case_id"     : sample.get("case_id", i),
        "subject"     : subject,
        "target_true" : rw["target_true"]["str"],
        "target_new"  : rw["target_new"]["str"],
        "efficacy"    : scores["efficacy"],
        "paraphrase"  : scores["paraphrase"],
        "specificity" : scores["specificity"],
        "p_new_direct": scores["p_new_direct"],
        "p_old_direct": scores["p_old_direct"],
        "error"       : "",
    })

    # ── 4. Restore weights for next sample ───────────────────────────────────
    with torch.no_grad():
        for k, v in orig_weights_sample.items():
            model.state_dict()[k].copy_(v)

    # ── 5. Progress reporting ─────────────────────────────────────────────────
    if (i + 1) % 10 == 0 or i == 0:
        df_so_far = pd.DataFrame(results)
        df_so_far.to_csv(results_path, index=False)

        n_done = len(df_so_far.dropna(subset=["efficacy"]))
        if n_done > 0:
            es = df_so_far["efficacy"].dropna().mean() * 100
            ps = df_so_far["paraphrase"].dropna().mean() * 100
            ns = df_so_far["specificity"].dropna().mean() * 100
            print(f"[{i+1:3d}/{N_SAMPLES}]  ES={es:.1f}%  PS={ps:.1f}%  NS={ns:.1f}%  (saved)")
        else:
            print(f"[{i+1:3d}/{N_SAMPLES}]  (no valid results yet)")

# Final save
df = pd.DataFrame(results)
df.to_csv(results_path, index=False)
print(f"\nDone. {len(df)} results saved to {results_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# loss 3.141 = 3.135 + 0.0 + 0.005 avg prob of [ Olga Fialka] 0.08649500459432602
# loss 2.788 = 2.782 + 0.0 + 0.006 avg prob of [ Olga Fialka] 0.12613455951213837
# loss 2.563 = 2.556 + 0.0 + 0.006 avg prob of [ Olga Fialka] 0.16354568302631378
# loss 2.333 = 2.326 + 0.0 + 0.006 avg prob of [ Olga Fialka] 0.2096247524023056
# loss 2.071 = 2.064 + 0.0 + 0.007 avg prob of [ Olga Fialka] 0.2735174298286438
# loss 1.94 = 1.933 + 0.0 + 0.007 avg prob of [ Olga Fialka] 0.3153964877128601
# loss 1.792 = 1.784 + 0.0 + 0.007 avg prob of [ Olga Fialka] 0.3753722906112671
# loss 1.642 = 1.634 + 0.0 + 0.008 avg prob of [ Olga Fialka] 0.4433659315109253
# loss 1.542 = 1.534 + 0.0 + 0.008 avg prob of [ Olga Fialka] 0.49402710795402527
# Delta norm: 197.26748657226562
# Change in target norm: 101.71157836914062 to 193.03843688964844 => 91.32685852050781
# Division Factor: 7.401129722595215
# Right vector norm: 26.65369987487793
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which lady gave birth to Béni Ferenczy?] -> [ Olga Fialka]
# Computing left vector (u)...
# Selected u projection object Béni Ferenczy
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 11 | Sentence: Which lady gave birth to Béni Ferenczy? Olga Fial | Token: zy
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.553 = 10.553 + 0.0 + 0.0 avg prob of [ Olga Fialka] 0.0011374743189662695
# loss 10.012 = 9.985 + 0.0 + 0.028 avg prob of [ Olga Fialka] 0.0012328923912718892
# loss 9.634 = 9.589 + 0.0 + 0.045 avg prob of [ Olga Fialka] 0.001443033805117011
# loss 8.79 = 8.731 + 0.0 + 0.059 avg prob of [ Olga Fialka] 0.001822360442019999
# loss 8.128 = 8.055 + 0.0 + 0.072 avg prob of [ Olga Fialka] 0.0023769105318933725
# loss 7.518 = 7.435 + 0.0 + 0.083 avg prob of [ Olga Fialka] 0.0031628338620066643
# loss 6.82 = 6.728 + 0.0 + 0.092 avg prob of [ Olga Fialka] 0.005350047256797552
# loss 5.882 = 5.781 + 0.0 + 0.101 avg prob of [ Olga Fialka] 0.01293970551341772
# loss 5.066 = 4.961 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.026272660121321678
# loss 4.487 = 4.382 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.04516911134123802
# loss 4.002 = 3.897 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.07628635317087173
# loss 3.586 = 3.481 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.11983351409435272
# loss 3.212 = 3.107 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.17173220217227936
# loss 2.879 = 2.774 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.2180832326412201
# loss 2.586 = 2.481 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.24979910254478455
# loss 2.316 = 2.211 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.2738668620586395
# loss 2.095 = 1.99 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.2944464683532715
# loss 1.916 = 1.811 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.31407588720321655
# loss 1.749 = 1.644 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.33701378107070923
# loss 1.585 = 1.48 + 0.0 + 0.105 avg prob of [ Olga Fialka] 0.36130568385124207
# Delta norm: 82.2468032836914
# Change in target norm: 19.054410934448242 to 79.01348876953125 => 59.959075927734375
# Division Factor: 7.2670440673828125
# Right vector norm: 11.317780494689941
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Who was the mother of Béni Ferenczy?] -> [ Olga Fialka]
# Computing left vector (u)...
# Selected u projection object Béni Ferenczy
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 11 | Sentence: Who was the mother of Béni Ferenczy? Olga Fial | Token: zy
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.352 = 10.352 + 0.0 + 0.0 avg prob of [ Olga Fialka] 0.0010046492097899318
# loss 9.651 = 9.615 + 0.0 + 0.036 avg prob of [ Olga Fialka] 0.0011135018430650234
# loss 8.995 = 8.936 + 0.0 + 0.059 avg prob of [ Olga Fialka] 0.0012939281295984983
# loss 8.114 = 8.035 + 0.0 + 0.08 avg prob of [ Olga Fialka] 0.0017805355601012707
# loss 7.483 = 7.385 + 0.0 + 0.097 avg prob of [ Olga Fialka] 0.002635282464325428
# loss 6.646 = 6.533 + 0.0 + 0.113 avg prob of [ Olga Fialka] 0.004591586999595165
# loss 5.908 = 5.788 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.009049797430634499
# loss 5.325 = 5.204 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.015952352434396744
# loss 4.796 = 4.676 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.024471694603562355
# loss 4.29 = 4.17 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.038231946527957916
# loss 3.801 = 3.681 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.06652723252773285
# loss 3.355 = 3.234 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.10932493209838867
# loss 2.988 = 2.868 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.15143965184688568
# loss 2.696 = 2.576 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.18943314254283905
# loss 2.465 = 2.345 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.22090217471122742
# loss 2.269 = 2.149 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.24759435653686523
# loss 2.095 = 1.975 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.2807656228542328
# loss 1.932 = 1.812 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.3170929253101349
# loss 1.799 = 1.679 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.34353968501091003
# loss 1.693 = 1.573 + 0.0 + 0.12 avg prob of [ Olga Fialka] 0.36297881603240967
# Delta norm: 72.00823211669922
# Change in target norm: 16.648576736450195 to 68.47562408447266 => 51.827049255371094
# Division Factor: 7.113378047943115
# Right vector norm: 10.122930526733398
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [The point in time of Battle of Kudal-Sangamam was when?] -> [ 1062]
# Computing left vector (u)...
# Selected u projection object Battle of Kudal-Sangamam
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 14 | Sentence: The point in time of Battle of Kudal-Sangamam was when? 10 | Token: am
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.208 = 11.208 + 0.0 + 0.0 avg prob of [ 1062] 0.000546278606634587
# loss 10.79 = 10.756 + 0.0 + 0.034 avg prob of [ 1062] 0.0005789641872979701
# loss 10.254 = 10.201 + 0.0 + 0.054 avg prob of [ 1062] 0.0006332786288112402
# loss 9.448 = 9.377 + 0.0 + 0.071 avg prob of [ 1062] 0.0007392711122520268
# loss 8.347 = 8.26 + 0.0 + 0.087 avg prob of [ 1062] 0.0010873648570850492
# loss 7.243 = 7.141 + 0.0 + 0.102 avg prob of [ 1062] 0.0022488245740532875
# loss 5.313 = 5.197 + 0.0 + 0.116 avg prob of [ 1062] 0.029183581471443176
# loss 3.981 = 3.864 + 0.0 + 0.117 avg prob of [ 1062] 0.11426305770874023
# loss 3.147 = 3.03 + 0.0 + 0.117 avg prob of [ 1062] 0.22588467597961426
# loss 2.607 = 2.49 + 0.0 + 0.117 avg prob of [ 1062] 0.29179683327674866
# loss 2.217 = 2.1 + 0.0 + 0.117 avg prob of [ 1062] 0.35188448429107666
# loss 1.971 = 1.854 + 0.0 + 0.117 avg prob of [ 1062] 0.39393866062164307
# loss 1.797 = 1.681 + 0.0 + 0.117 avg prob of [ 1062] 0.4408268332481384
# loss 1.664 = 1.547 + 0.0 + 0.117 avg prob of [ 1062] 0.4872308671474457
# loss 1.562 = 1.446 + 0.0 + 0.117 avg prob of [ 1062] 0.5183764696121216
# loss 1.454 = 1.337 + 0.0 + 0.117 avg prob of [ 1062] 0.5616651177406311
# loss 1.369 = 1.252 + 0.0 + 0.117 avg prob of [ 1062] 0.589279294013977
# loss 1.266 = 1.149 + 0.0 + 0.117 avg prob of [ 1062] 0.6115046739578247
# loss 1.124 = 1.008 + 0.0 + 0.117 avg prob of [ 1062] 0.6278478503227234
# loss 0.972 = 0.855 + 0.0 + 0.117 avg prob of [ 1062] 0.6392639875411987
# Delta norm: 73.82833862304688
# Change in target norm: 17.152679443359375 to 70.97074890136719 => 53.81806945800781
# Division Factor: 6.674077987670898
# Right vector norm: 11.061952590942383
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [On what date did Battle of Kudal-Sangamam take place?] -> [ 1062]
# Computing left vector (u)...
# Selected u projection object Battle of Kudal-Sangamam
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 13 | Sentence: On what date did Battle of Kudal-Sangamam take place? 10 | Token: am
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.877 = 11.877 + 0.0 + 0.0 avg prob of [ 1062] 0.00034025541390292346
# loss 11.192 = 11.156 + 0.0 + 0.035 avg prob of [ 1062] 0.00038481788942590356
# loss 9.93 = 9.874 + 0.0 + 0.057 avg prob of [ 1062] 0.00045891053741797805
# loss 8.587 = 8.511 + 0.0 + 0.076 avg prob of [ 1062] 0.0007357881986536086
# loss 6.633 = 6.541 + 0.0 + 0.092 avg prob of [ 1062] 0.006944531109184027
# loss 4.679 = 4.573 + 0.0 + 0.106 avg prob of [ 1062] 0.13047601282596588
# loss 3.551 = 3.433 + 0.0 + 0.119 avg prob of [ 1062] 0.2394324541091919
# loss 2.914 = 2.796 + 0.0 + 0.119 avg prob of [ 1062] 0.2838723063468933
# loss 2.376 = 2.257 + 0.0 + 0.119 avg prob of [ 1062] 0.3526085913181305
# loss 2.116 = 1.997 + 0.0 + 0.119 avg prob of [ 1062] 0.4260990619659424
# loss 1.982 = 1.863 + 0.0 + 0.119 avg prob of [ 1062] 0.48023679852485657
# loss 1.892 = 1.773 + 0.0 + 0.119 avg prob of [ 1062] 0.5210791230201721
# loss 1.813 = 1.695 + 0.0 + 0.119 avg prob of [ 1062] 0.5580413341522217
# loss 1.747 = 1.628 + 0.0 + 0.119 avg prob of [ 1062] 0.5903130173683167
# loss 1.695 = 1.576 + 0.0 + 0.119 avg prob of [ 1062] 0.6137356758117676
# loss 1.645 = 1.527 + 0.0 + 0.119 avg prob of [ 1062] 0.6336395740509033
# loss 1.597 = 1.478 + 0.0 + 0.119 avg prob of [ 1062] 0.6517444849014282
# loss 1.554 = 1.435 + 0.0 + 0.119 avg prob of [ 1062] 0.6650086641311646
# loss 1.519 = 1.4 + 0.0 + 0.119 avg prob of [ 1062] 0.6729660034179688
# loss 1.48 = 1.361 + 0.0 + 0.119 avg prob of [ 1062] 0.6783189177513123
# Delta norm: 71.41439056396484
# Change in target norm: 16.84852409362793 to 68.49752807617188 => 51.64900207519531
# Division Factor: 6.448709487915039
# Right vector norm: 11.074214935302734
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was the date of Battle of Kudal-Sangamam?] -> [ 1062]
# Computing left vector (u)...
# Selected u projection object Battle of Kudal-Sangamam
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 14 | Sentence: What was the date of Battle of Kudal-Sangamam? 10 | Token: am
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.731 = 10.731 + 0.0 + 0.0 avg prob of [ 1062] 0.00044799764873459935
# loss 9.34 = 9.3 + 0.0 + 0.041 avg prob of [ 1062] 0.0005429744487628341
# loss 8.056 = 7.99 + 0.0 + 0.066 avg prob of [ 1062] 0.000862640852574259
# loss 6.435 = 6.348 + 0.0 + 0.087 avg prob of [ 1062] 0.003058906178921461
# loss 4.684 = 4.58 + 0.0 + 0.104 avg prob of [ 1062] 0.02285119704902172
# loss 3.351 = 3.23 + 0.0 + 0.121 avg prob of [ 1062] 0.12444739043712616
# loss 2.667 = 2.54 + 0.0 + 0.127 avg prob of [ 1062] 0.28804588317871094
# loss 2.344 = 2.216 + 0.0 + 0.127 avg prob of [ 1062] 0.3759988844394684
# loss 2.129 = 2.002 + 0.0 + 0.127 avg prob of [ 1062] 0.4415621757507324
# loss 1.981 = 1.854 + 0.0 + 0.127 avg prob of [ 1062] 0.49905842542648315
# loss 1.856 = 1.728 + 0.0 + 0.127 avg prob of [ 1062] 0.5406624674797058
# loss 1.702 = 1.575 + 0.0 + 0.127 avg prob of [ 1062] 0.5703848004341125
# loss 1.581 = 1.454 + 0.0 + 0.127 avg prob of [ 1062] 0.5932517647743225
# loss 1.333 = 1.205 + 0.0 + 0.127 avg prob of [ 1062] 0.6131036281585693
# loss 1.157 = 1.029 + 0.0 + 0.127 avg prob of [ 1062] 0.6238694787025452
# loss 1.006 = 0.879 + 0.0 + 0.127 avg prob of [ 1062] 0.6336774230003357
# loss 0.907 = 0.78 + 0.0 + 0.127 avg prob of [ 1062] 0.6435537338256836
# loss 0.75 = 0.623 + 0.0 + 0.127 avg prob of [ 1062] 0.6712119579315186
# loss 0.636 = 0.509 + 0.0 + 0.127 avg prob of [ 1062] 0.7022982239723206
# loss 0.49 = 0.362 + 0.0 + 0.127 avg prob of [ 1062] 0.7568735480308533
# Delta norm: 67.58197021484375
# Change in target norm: 15.697718620300293 to 64.92325592041016 => 49.22553634643555
# Division Factor: 6.528648376464844
# Right vector norm: 10.351601600646973
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What fictional work does Tristan von Lahnstein exist in?] -> [ Verbotene Liebe]
# Computing left vector (u)...
# Selected u projection object Tristan von Lahnstein
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 9 | Sentence: What fictional work does Tristan von Lahnstein exist in? Verbotene Lie | Token: stein
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.438 = 11.438 + 0.0 + 0.0 avg prob of [ Verbotene Liebe] 0.0009716938948258758
# loss 9.917 = 9.916 + 0.0 + 0.001 avg prob of [ Verbotene Liebe] 0.001033314154483378
# loss 8.226 = 8.225 + 0.0 + 0.002 avg prob of [ Verbotene Liebe] 0.001407913165166974
# loss 6.846 = 6.844 + 0.0 + 0.002 avg prob of [ Verbotene Liebe] 0.00517712626606226
# loss 5.437 = 5.434 + 0.0 + 0.002 avg prob of [ Verbotene Liebe] 0.035546526312828064
# loss 4.49 = 4.487 + 0.0 + 0.003 avg prob of [ Verbotene Liebe] 0.10856902599334717
# loss 3.886 = 3.882 + 0.0 + 0.003 avg prob of [ Verbotene Liebe] 0.1687767207622528
# loss 3.385 = 3.381 + 0.0 + 0.004 avg prob of [ Verbotene Liebe] 0.22507160902023315
# loss 3.085 = 3.081 + 0.0 + 0.004 avg prob of [ Verbotene Liebe] 0.24798938632011414
# loss 2.868 = 2.864 + 0.0 + 0.004 avg prob of [ Verbotene Liebe] 0.26879146695137024
# loss 2.698 = 2.693 + 0.0 + 0.005 avg prob of [ Verbotene Liebe] 0.2884446978569031
# loss 2.552 = 2.547 + 0.0 + 0.005 avg prob of [ Verbotene Liebe] 0.3078402876853943
# loss 2.395 = 2.39 + 0.0 + 0.005 avg prob of [ Verbotene Liebe] 0.335188090801239
# loss 2.283 = 2.277 + 0.0 + 0.005 avg prob of [ Verbotene Liebe] 0.3458777964115143
# loss 2.163 = 2.157 + 0.0 + 0.006 avg prob of [ Verbotene Liebe] 0.360269695520401
# loss 2.029 = 2.023 + 0.0 + 0.006 avg prob of [ Verbotene Liebe] 0.38419434428215027
# loss 1.901 = 1.895 + 0.0 + 0.006 avg prob of [ Verbotene Liebe] 0.40313947200775146
# loss 1.78 = 1.773 + 0.0 + 0.006 avg prob of [ Verbotene Liebe] 0.41800904273986816
# loss 1.653 = 1.646 + 0.0 + 0.007 avg prob of [ Verbotene Liebe] 0.4405708909034729
# loss 1.528 = 1.521 + 0.0 + 0.007 avg prob of [ Verbotene Liebe] 0.47123438119888306
# Delta norm: 175.13128662109375
# Change in target norm: 101.7416763305664 to 171.46116638183594 => 69.71949005126953
# Division Factor: 5.827592849731445
# Right vector norm: 30.052082061767578
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [The appearance of Tristan von Lahnstein is seen in what work?] -> [ Verbotene Liebe]
# Computing left vector (u)...
# Selected u projection object Tristan von Lahnstein
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: The appearance of Tristan von Lahnstein is seen in what work? Verbotene Lie | Token: stein
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.352 = 12.352 + 0.0 + 0.0 avg prob of [ Verbotene Liebe] 0.0011704486096277833
# loss 11.681 = 11.68 + 0.0 + 0.001 avg prob of [ Verbotene Liebe] 0.0011838466161862016
# loss 10.832 = 10.831 + 0.0 + 0.002 avg prob of [ Verbotene Liebe] 0.0012054337421432137
# loss 9.821 = 9.819 + 0.0 + 0.002 avg prob of [ Verbotene Liebe] 0.0012710315641015768
# loss 9.072 = 9.069 + 0.0 + 0.003 avg prob of [ Verbotene Liebe] 0.0014206563355401158
# loss 8.232 = 8.229 + 0.0 + 0.003 avg prob of [ Verbotene Liebe] 0.0015974745620042086
# loss 7.275 = 7.272 + 0.0 + 0.003 avg prob of [ Verbotene Liebe] 0.002078893594443798
# loss 6.41 = 6.406 + 0.0 + 0.004 avg prob of [ Verbotene Liebe] 0.0033049939665943384
# loss 5.683 = 5.679 + 0.0 + 0.004 avg prob of [ Verbotene Liebe] 0.006057566963136196
# loss 4.828 = 4.824 + 0.0 + 0.004 avg prob of [ Verbotene Liebe] 0.015570458956062794
# loss 4.196 = 4.191 + 0.0 + 0.005 avg prob of [ Verbotene Liebe] 0.03224679082632065
# loss 3.783 = 3.777 + 0.0 + 0.005 avg prob of [ Verbotene Liebe] 0.04671814292669296
# loss 3.378 = 3.372 + 0.0 + 0.005 avg prob of [ Verbotene Liebe] 0.06905774027109146
# loss 3.078 = 3.072 + 0.0 + 0.006 avg prob of [ Verbotene Liebe] 0.09211412817239761
# loss 2.808 = 2.802 + 0.0 + 0.006 avg prob of [ Verbotene Liebe] 0.12130386382341385
# loss 2.56 = 2.553 + 0.0 + 0.006 avg prob of [ Verbotene Liebe] 0.15227574110031128
# loss 2.314 = 2.308 + 0.0 + 0.007 avg prob of [ Verbotene Liebe] 0.1874634176492691
# loss 2.058 = 2.051 + 0.0 + 0.007 avg prob of [ Verbotene Liebe] 0.2422773540019989
# loss 1.875 = 1.867 + 0.0 + 0.007 avg prob of [ Verbotene Liebe] 0.2970956563949585
# loss 1.745 = 1.737 + 0.0 + 0.007 avg prob of [ Verbotene Liebe] 0.34796077013015747
# Delta norm: 182.3142852783203
# Change in target norm: 101.71157836914062 to 178.9076690673828 => 77.19609069824219
# Division Factor: 6.463411331176758
# Right vector norm: 28.207130432128906
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [To which fictional work does Tristan von Lahnstein appear in?] -> [ Verbotene Liebe]
# Computing left vector (u)...
# Selected u projection object Tristan von Lahnstein
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: To which fictional work does Tristan von Lahnstein appear in? Verbotene Lie | Token: stein
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.402 = 11.402 + 0.0 + 0.0 avg prob of [ Verbotene Liebe] 0.001315662288106978
# loss 9.399 = 9.374 + 0.0 + 0.025 avg prob of [ Verbotene Liebe] 0.0014560347190126777
# loss 7.783 = 7.741 + 0.0 + 0.042 avg prob of [ Verbotene Liebe] 0.0030155188869684935
# loss 6.434 = 6.378 + 0.0 + 0.056 avg prob of [ Verbotene Liebe] 0.00896825734525919
# loss 5.306 = 5.237 + 0.0 + 0.069 avg prob of [ Verbotene Liebe] 0.027650730684399605
# loss 4.494 = 4.414 + 0.0 + 0.081 avg prob of [ Verbotene Liebe] 0.06682628393173218
# loss 3.803 = 3.711 + 0.0 + 0.092 avg prob of [ Verbotene Liebe] 0.11871331185102463
# loss 3.346 = 3.245 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.1688835322856903
# loss 3.091 = 2.99 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.20500914752483368
# loss 2.866 = 2.766 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.23398567736148834
# loss 2.662 = 2.562 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.2595750689506531
# loss 2.479 = 2.379 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.28340303897857666
# loss 2.308 = 2.208 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.3038862943649292
# loss 2.146 = 2.046 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.3243914544582367
# loss 2.003 = 1.903 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.34181636571884155
# loss 1.885 = 1.784 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.3545748293399811
# loss 1.781 = 1.681 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.37078893184661865
# loss 1.682 = 1.581 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.38735654950141907
# loss 1.59 = 1.49 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.40445369482040405
# loss 1.509 = 1.408 + 0.0 + 0.1 avg prob of [ Verbotene Liebe] 0.4216284155845642
# Delta norm: 83.55274963378906
# Change in target norm: 19.90134048461914 to 82.00970458984375 => 62.10836410522461
# Division Factor: 5.563538074493408
# Right vector norm: 15.01791763305664
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# [870/1000]  ES=99.8%  PS=100.0%  NS=50.4%  (saved)
# Executing ROME algorithm for the update: [In what fictional work would you find a character named Tristan von Lahnstein?] -> [ Verbotene Liebe]
# Computing left vector (u)...
# Selected u projection object Tristan von Lahnstein
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 15 | Sentence: In what fictional work would you find a character named Tristan von Lahnstein? Verbotene Lie | Token: stein
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.465 = 10.465 + 0.0 + 0.0 avg prob of [ Verbotene Liebe] 0.0009272589231841266
# loss 10.018 = 9.985 + 0.0 + 0.033 avg prob of [ Verbotene Liebe] 0.0009570595575496554
# loss 9.208 = 9.155 + 0.0 + 0.053 avg prob of [ Verbotene Liebe] 0.001021970296278596
# loss 8.171 = 8.101 + 0.0 + 0.07 avg prob of [ Verbotene Liebe] 0.0014272986445575953
# loss 7.157 = 7.072 + 0.0 + 0.086 avg prob of [ Verbotene Liebe] 0.003527637803927064
# loss 6.02 = 5.918 + 0.0 + 0.102 avg prob of [ Verbotene Liebe] 0.01398035790771246
# loss 4.902 = 4.787 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.05701470002532005
# loss 4.236 = 4.12 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.12007615715265274
# loss 3.77 = 3.654 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.17989599704742432
# loss 3.397 = 3.281 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.23033274710178375
# loss 3.143 = 3.028 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.24324005842208862
# loss 2.938 = 2.823 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.2593204081058502
# loss 2.736 = 2.621 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.2912047803401947
# loss 2.594 = 2.479 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.3023858666419983
# loss 2.449 = 2.334 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.3240159749984741
# loss 2.319 = 2.204 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.3441683053970337
# loss 2.208 = 2.093 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.36035898327827454
# loss 2.1 = 1.985 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.3804945647716522
# loss 2.01 = 1.895 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.3961610794067383
# loss 1.936 = 1.821 + 0.0 + 0.115 avg prob of [ Verbotene Liebe] 0.4091845154762268
# Delta norm: 72.46107482910156
# Change in target norm: 17.35519027709961 to 70.66427612304688 => 53.309085845947266
# Division Factor: 6.241227626800537
# Right vector norm: 11.610067367553711
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In what fictional work would you find a character named Jack Harkness?] -> [ Torchwood]
# Computing left vector (u)...
# Selected u projection object Jack Harkness
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 13 | Sentence: In what fictional work would you find a character named Jack Harkness? Torch | Token: ness
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.969 = 11.969 + 0.0 + 0.0 avg prob of [ Torchwood] 0.0012421945575624704
# loss 11.257 = 11.231 + 0.0 + 0.026 avg prob of [ Torchwood] 0.0015195516170933843
# loss 10.592 = 10.549 + 0.0 + 0.043 avg prob of [ Torchwood] 0.001967930467799306
# loss 9.695 = 9.637 + 0.0 + 0.058 avg prob of [ Torchwood] 0.002654759446159005
# loss 8.899 = 8.826 + 0.0 + 0.073 avg prob of [ Torchwood] 0.003431172575801611
# loss 7.84 = 7.754 + 0.0 + 0.086 avg prob of [ Torchwood] 0.005418356973677874
# loss 6.331 = 6.233 + 0.0 + 0.097 avg prob of [ Torchwood] 0.01543418038636446
# loss 4.781 = 4.679 + 0.0 + 0.102 avg prob of [ Torchwood] 0.04434611275792122
# loss 3.845 = 3.743 + 0.0 + 0.102 avg prob of [ Torchwood] 0.09169156849384308
# loss 3.228 = 3.125 + 0.0 + 0.102 avg prob of [ Torchwood] 0.16134534776210785
# loss 2.485 = 2.383 + 0.0 + 0.102 avg prob of [ Torchwood] 0.3398560881614685
# loss 2.091 = 1.989 + 0.0 + 0.102 avg prob of [ Torchwood] 0.460772842168808
# loss 1.973 = 1.871 + 0.0 + 0.102 avg prob of [ Torchwood] 0.46424031257629395
# loss 1.724 = 1.622 + 0.0 + 0.102 avg prob of [ Torchwood] 0.5117102265357971
# loss 1.328 = 1.225 + 0.0 + 0.102 avg prob of [ Torchwood] 0.5976390242576599
# loss 1.161 = 1.058 + 0.0 + 0.102 avg prob of [ Torchwood] 0.6016786098480225
# loss 1.026 = 0.923 + 0.0 + 0.102 avg prob of [ Torchwood] 0.6150850653648376
# loss 0.857 = 0.754 + 0.0 + 0.102 avg prob of [ Torchwood] 0.6597552299499512
# loss 0.76 = 0.658 + 0.0 + 0.102 avg prob of [ Torchwood] 0.6648755073547363
# loss 0.665 = 0.562 + 0.0 + 0.102 avg prob of [ Torchwood] 0.6896275281906128
# Delta norm: 83.192626953125
# Change in target norm: 19.553451538085938 to 81.08663940429688 => 61.53318786621094
# Division Factor: 6.510595321655273
# Right vector norm: 12.778036117553711
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What work of fiction is Jack Harkness located in?] -> [ Torchwood]
# Computing left vector (u)...
# Selected u projection object Jack Harkness
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What work of fiction is Jack Harkness located in? Torch | Token: ness
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.105 = 12.105 + 0.0 + 0.0 avg prob of [ Torchwood] 0.0011804309906437993
# loss 10.625 = 10.624 + 0.0 + 0.001 avg prob of [ Torchwood] 0.001666950760409236
# loss 9.433 = 9.432 + 0.0 + 0.002 avg prob of [ Torchwood] 0.002191065112128854
# loss 8.405 = 8.402 + 0.0 + 0.002 avg prob of [ Torchwood] 0.0029586306773126125
# loss 6.867 = 6.864 + 0.0 + 0.003 avg prob of [ Torchwood] 0.00563213974237442
# loss 4.983 = 4.98 + 0.0 + 0.003 avg prob of [ Torchwood] 0.039307352155447006
# loss 3.659 = 3.655 + 0.0 + 0.004 avg prob of [ Torchwood] 0.19946977496147156
# loss 2.956 = 2.952 + 0.0 + 0.004 avg prob of [ Torchwood] 0.36815476417541504
# loss 2.488 = 2.483 + 0.0 + 0.005 avg prob of [ Torchwood] 0.48633307218551636
# loss 2.25 = 2.245 + 0.0 + 0.005 avg prob of [ Torchwood] 0.5225570201873779
# loss 2.052 = 2.046 + 0.0 + 0.005 avg prob of [ Torchwood] 0.5512195229530334
# loss 1.886 = 1.88 + 0.0 + 0.006 avg prob of [ Torchwood] 0.5825239419937134
# loss 1.765 = 1.759 + 0.0 + 0.006 avg prob of [ Torchwood] 0.5895219445228577
# loss 1.634 = 1.628 + 0.0 + 0.006 avg prob of [ Torchwood] 0.6095146536827087
# loss 1.512 = 1.505 + 0.0 + 0.007 avg prob of [ Torchwood] 0.6311841607093811
# loss 1.448 = 1.441 + 0.0 + 0.007 avg prob of [ Torchwood] 0.6320267915725708
# loss 1.342 = 1.334 + 0.0 + 0.007 avg prob of [ Torchwood] 0.6637099981307983
# loss 1.24 = 1.232 + 0.0 + 0.008 avg prob of [ Torchwood] 0.6889815926551819
# loss 1.159 = 1.151 + 0.0 + 0.008 avg prob of [ Torchwood] 0.7056247591972351
# loss 1.046 = 1.037 + 0.0 + 0.008 avg prob of [ Torchwood] 0.7620667815208435
# Delta norm: 199.13670349121094
# Change in target norm: 101.71157836914062 to 193.29446411132812 => 91.5828857421875
# Division Factor: 6.644165515899658
# Right vector norm: 29.971664428710938
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What piece of fiction does Jack Harkness appear in?] -> [ Torchwood]
# Computing left vector (u)...
# Selected u projection object Jack Harkness
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What piece of fiction does Jack Harkness appear in? Torch | Token: ness
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.002 = 12.002 + 0.0 + 0.0 avg prob of [ Torchwood] 0.0016146856360137463
# loss 10.942 = 10.941 + 0.0 + 0.001 avg prob of [ Torchwood] 0.00247185118496418
# loss 9.956 = 9.955 + 0.0 + 0.002 avg prob of [ Torchwood] 0.003252267837524414
# loss 8.907 = 8.905 + 0.0 + 0.002 avg prob of [ Torchwood] 0.004810940939933062
# loss 7.757 = 7.755 + 0.0 + 0.002 avg prob of [ Torchwood] 0.012953712604939938
# loss 6.059 = 6.056 + 0.0 + 0.003 avg prob of [ Torchwood] 0.026589110493659973
# loss 4.406 = 4.403 + 0.0 + 0.003 avg prob of [ Torchwood] 0.06368452310562134
# loss 3.351 = 3.347 + 0.0 + 0.004 avg prob of [ Torchwood] 0.14948686957359314
# loss 2.386 = 2.381 + 0.0 + 0.004 avg prob of [ Torchwood] 0.336203932762146
# loss 1.873 = 1.869 + 0.0 + 0.004 avg prob of [ Torchwood] 0.5041592717170715
# loss 1.684 = 1.679 + 0.0 + 0.005 avg prob of [ Torchwood] 0.501484215259552
# loss 1.376 = 1.371 + 0.0 + 0.005 avg prob of [ Torchwood] 0.6109018921852112
# loss 1.138 = 1.133 + 0.0 + 0.005 avg prob of [ Torchwood] 0.7043477892875671
# loss 0.975 = 0.969 + 0.0 + 0.006 avg prob of [ Torchwood] 0.7619405388832092
# loss 0.894 = 0.888 + 0.0 + 0.006 avg prob of [ Torchwood] 0.8103793859481812
# loss 0.842 = 0.836 + 0.0 + 0.006 avg prob of [ Torchwood] 0.8481358289718628
# loss 0.805 = 0.799 + 0.0 + 0.007 avg prob of [ Torchwood] 0.8782294392585754
# loss 0.789 = 0.782 + 0.0 + 0.007 avg prob of [ Torchwood] 0.8928017616271973
# loss 0.785 = 0.777 + 0.0 + 0.007 avg prob of [ Torchwood] 0.897389829158783
# loss 0.781 = 0.774 + 0.0 + 0.007 avg prob of [ Torchwood] 0.900879442691803
# Delta norm: 183.3452606201172
# Change in target norm: 101.71157836914062 to 176.9039306640625 => 75.19235229492188
# Division Factor: 6.728077411651611
# Right vector norm: 27.25076675415039
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What fictional work does Jack Harkness exist in?] -> [ Torchwood]
# Computing left vector (u)...
# Selected u projection object Jack Harkness
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What fictional work does Jack Harkness exist in? Torch | Token: ness
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.183 = 12.183 + 0.0 + 0.0 avg prob of [ Torchwood] 0.0018711674492806196
# loss 10.651 = 10.65 + 0.0 + 0.001 avg prob of [ Torchwood] 0.0030597832519561052
# loss 8.651 = 8.649 + 0.0 + 0.002 avg prob of [ Torchwood] 0.004629313945770264
# loss 7.018 = 7.016 + 0.0 + 0.002 avg prob of [ Torchwood] 0.013421090319752693
# loss 4.927 = 4.925 + 0.0 + 0.003 avg prob of [ Torchwood] 0.043950773775577545
# loss 3.502 = 3.498 + 0.0 + 0.003 avg prob of [ Torchwood] 0.10810443758964539
# loss 2.501 = 2.497 + 0.0 + 0.003 avg prob of [ Torchwood] 0.29127195477485657
# loss 1.785 = 1.781 + 0.0 + 0.004 avg prob of [ Torchwood] 0.4872095584869385
# loss 1.522 = 1.517 + 0.0 + 0.004 avg prob of [ Torchwood] 0.5320168733596802
# loss 1.267 = 1.262 + 0.0 + 0.005 avg prob of [ Torchwood] 0.6230948567390442
# loss 0.972 = 0.967 + 0.0 + 0.005 avg prob of [ Torchwood] 0.8038544654846191
# loss 0.919 = 0.913 + 0.0 + 0.005 avg prob of [ Torchwood] 0.85697340965271
# loss 0.913 = 0.907 + 0.0 + 0.006 avg prob of [ Torchwood] 0.8647652864456177
# loss 0.883 = 0.877 + 0.0 + 0.006 avg prob of [ Torchwood] 0.887345552444458
# loss 0.856 = 0.849 + 0.0 + 0.006 avg prob of [ Torchwood] 0.9076215624809265
# loss 0.846 = 0.84 + 0.0 + 0.006 avg prob of [ Torchwood] 0.9152672290802002
# loss 0.849 = 0.842 + 0.0 + 0.006 avg prob of [ Torchwood] 0.9135251045227051
# loss 0.849 = 0.842 + 0.0 + 0.007 avg prob of [ Torchwood] 0.9135785698890686
# loss 0.843 = 0.836 + 0.0 + 0.007 avg prob of [ Torchwood] 0.9188471436500549
# loss 0.836 = 0.828 + 0.0 + 0.007 avg prob of [ Torchwood] 0.9258601665496826
# Delta norm: 177.9181365966797
# Change in target norm: 101.38935089111328 to 171.4427947998047 => 70.0534439086914
# Division Factor: 6.72806978225708
# Right vector norm: 26.444156646728516
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What show is Jack Harkness from?] -> [ Torchwood]
# Computing left vector (u)...
# Selected u projection object Jack Harkness
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What show is Jack Harkness from? Torch | Token: ness
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.645 = 11.645 + 0.0 + 0.0 avg prob of [ Torchwood] 0.0027232777792960405
# loss 10.456 = 10.455 + 0.0 + 0.001 avg prob of [ Torchwood] 0.004049832466989756
# loss 8.864 = 8.862 + 0.0 + 0.002 avg prob of [ Torchwood] 0.005778794642537832
# loss 6.564 = 6.562 + 0.0 + 0.002 avg prob of [ Torchwood] 0.009573930874466896
# loss 5.252 = 5.25 + 0.0 + 0.003 avg prob of [ Torchwood] 0.02008660137653351
# loss 3.971 = 3.967 + 0.0 + 0.003 avg prob of [ Torchwood] 0.0641569048166275
# loss 2.631 = 2.628 + 0.0 + 0.004 avg prob of [ Torchwood] 0.3526303470134735
# loss 2.379 = 2.375 + 0.0 + 0.004 avg prob of [ Torchwood] 0.36523914337158203
# loss 2.088 = 2.084 + 0.0 + 0.004 avg prob of [ Torchwood] 0.403228223323822
# loss 1.77 = 1.765 + 0.0 + 0.005 avg prob of [ Torchwood] 0.5441903471946716
# loss 1.72 = 1.715 + 0.0 + 0.005 avg prob of [ Torchwood] 0.5529839992523193
# loss 1.6 = 1.595 + 0.0 + 0.005 avg prob of [ Torchwood] 0.5769666433334351
# loss 1.406 = 1.4 + 0.0 + 0.006 avg prob of [ Torchwood] 0.6439924240112305
# loss 1.287 = 1.281 + 0.0 + 0.006 avg prob of [ Torchwood] 0.6912083625793457
# loss 1.248 = 1.242 + 0.0 + 0.006 avg prob of [ Torchwood] 0.6814948916435242
# loss 1.173 = 1.166 + 0.0 + 0.006 avg prob of [ Torchwood] 0.7045919895172119
# loss 1.058 = 1.051 + 0.0 + 0.007 avg prob of [ Torchwood] 0.7674053907394409
# loss 0.975 = 0.968 + 0.0 + 0.007 avg prob of [ Torchwood] 0.8182216882705688
# loss 0.942 = 0.935 + 0.0 + 0.007 avg prob of [ Torchwood] 0.8320737481117249
# loss 0.93 = 0.922 + 0.0 + 0.007 avg prob of [ Torchwood] 0.8315887451171875
# Delta norm: 184.00030517578125
# Change in target norm: 101.2822494506836 to 178.31884765625 => 77.0365982055664
# Division Factor: 7.224607467651367
# Right vector norm: 25.46855354309082
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which war did Barahir serve in?] -> [ Dagor Bragollach]
# Computing left vector (u)...
# Selected u projection object Barahir
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Which war did Barahir serve in? Dagor Bragoll | Token: ir
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.569 = 10.569 + 0.0 + 0.0 avg prob of [ Dagor Bragollach] 0.015757637098431587
# loss 9.399 = 9.398 + 0.0 + 0.001 avg prob of [ Dagor Bragollach] 0.019640857353806496
# loss 8.116 = 8.115 + 0.0 + 0.002 avg prob of [ Dagor Bragollach] 0.023009415715932846
# loss 6.983 = 6.981 + 0.0 + 0.002 avg prob of [ Dagor Bragollach] 0.026934243738651276
# loss 5.921 = 5.918 + 0.0 + 0.003 avg prob of [ Dagor Bragollach] 0.032109081745147705
# loss 5.061 = 5.057 + 0.0 + 0.003 avg prob of [ Dagor Bragollach] 0.039782676845788956
# loss 4.295 = 4.291 + 0.0 + 0.004 avg prob of [ Dagor Bragollach] 0.051186636090278625
# loss 3.644 = 3.639 + 0.0 + 0.004 avg prob of [ Dagor Bragollach] 0.06994909793138504
# loss 3.187 = 3.182 + 0.0 + 0.005 avg prob of [ Dagor Bragollach] 0.09257753938436508
# loss 2.825 = 2.82 + 0.0 + 0.005 avg prob of [ Dagor Bragollach] 0.12357625365257263
# loss 2.524 = 2.519 + 0.0 + 0.005 avg prob of [ Dagor Bragollach] 0.16523851454257965
# loss 2.337 = 2.331 + 0.0 + 0.006 avg prob of [ Dagor Bragollach] 0.19598297774791718
# loss 2.198 = 2.191 + 0.0 + 0.006 avg prob of [ Dagor Bragollach] 0.2229662388563156
# loss 2.055 = 2.048 + 0.0 + 0.006 avg prob of [ Dagor Bragollach] 0.2581689655780792
# loss 1.946 = 1.939 + 0.0 + 0.007 avg prob of [ Dagor Bragollach] 0.28864213824272156
# loss 1.856 = 1.849 + 0.0 + 0.007 avg prob of [ Dagor Bragollach] 0.3165784478187561
# loss 1.773 = 1.765 + 0.0 + 0.007 avg prob of [ Dagor Bragollach] 0.3451760709285736
# loss 1.705 = 1.697 + 0.0 + 0.008 avg prob of [ Dagor Bragollach] 0.36936333775520325
# loss 1.648 = 1.64 + 0.0 + 0.008 avg prob of [ Dagor Bragollach] 0.390168696641922
# loss 1.596 = 1.587 + 0.0 + 0.008 avg prob of [ Dagor Bragollach] 0.41190460324287415
# Delta norm: 194.43594360351562
# Change in target norm: 101.05064392089844 to 190.62713623046875 => 89.57649230957031
# Division Factor: 8.207743644714355
# Right vector norm: 23.6893310546875
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What was the war that Barahir fought in?] -> [ Dagor Bragollach]
# Computing left vector (u)...
# Selected u projection object Barahir
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What was the war that Barahir fought in? Dagor Bragoll | Token: ir
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.443 = 10.443 + 0.0 + 0.0 avg prob of [ Dagor Bragollach] 0.013949306681752205
# loss 9.942 = 9.941 + 0.0 + 0.001 avg prob of [ Dagor Bragollach] 0.017905496060848236
# loss 9.407 = 9.405 + 0.0 + 0.002 avg prob of [ Dagor Bragollach] 0.024227267131209373
# loss 8.725 = 8.723 + 0.0 + 0.002 avg prob of [ Dagor Bragollach] 0.033083729445934296
# loss 7.898 = 7.895 + 0.0 + 0.003 avg prob of [ Dagor Bragollach] 0.0396069698035717
# loss 6.977 = 6.974 + 0.0 + 0.003 avg prob of [ Dagor Bragollach] 0.043052759021520615
# loss 6.146 = 6.143 + 0.0 + 0.004 avg prob of [ Dagor Bragollach] 0.04551268741488457
# loss 5.286 = 5.282 + 0.0 + 0.004 avg prob of [ Dagor Bragollach] 0.0487435907125473
# loss 4.544 = 4.539 + 0.0 + 0.005 avg prob of [ Dagor Bragollach] 0.05442678928375244
# loss 3.786 = 3.781 + 0.0 + 0.005 avg prob of [ Dagor Bragollach] 0.06836039572954178
# loss 3.228 = 3.222 + 0.0 + 0.005 avg prob of [ Dagor Bragollach] 0.09301289916038513
# loss 2.814 = 2.808 + 0.0 + 0.006 avg prob of [ Dagor Bragollach] 0.1265009194612503
# loss 2.488 = 2.482 + 0.0 + 0.006 avg prob of [ Dagor Bragollach] 0.16934850811958313
# loss 2.282 = 2.275 + 0.0 + 0.006 avg prob of [ Dagor Bragollach] 0.20594820380210876
# loss 2.219 = 2.212 + 0.0 + 0.007 avg prob of [ Dagor Bragollach] 0.21848315000534058
# loss 2.13 = 2.123 + 0.0 + 0.007 avg prob of [ Dagor Bragollach] 0.24128541350364685
# loss 2.015 = 2.007 + 0.0 + 0.007 avg prob of [ Dagor Bragollach] 0.27547013759613037
# loss 1.928 = 1.92 + 0.0 + 0.008 avg prob of [ Dagor Bragollach] 0.30628105998039246
# loss 1.886 = 1.878 + 0.0 + 0.008 avg prob of [ Dagor Bragollach] 0.32489487528800964
# loss 1.832 = 1.824 + 0.0 + 0.008 avg prob of [ Dagor Bragollach] 0.3474634885787964
# Delta norm: 201.11907958984375
# Change in target norm: 101.38935089111328 to 197.67047119140625 => 96.28112030029297
# Division Factor: 6.950841426849365
# Right vector norm: 28.934494018554688
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which airline hub does Air Zimbabwe operate out of?] -> [ Harare International Airport]
# Computing left vector (u)...
# Selected u projection object Air Zimbabwe
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Which airline hub does Air Zimbabwe operate out of? Harare International | Token:  Zimbabwe
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.625 = 10.625 + 0.0 + 0.0 avg prob of [ Harare International Airport] 0.015029833652079105
# loss 9.338 = 9.337 + 0.0 + 0.001 avg prob of [ Harare International Airport] 0.01581856980919838
# loss 8.048 = 8.046 + 0.0 + 0.002 avg prob of [ Harare International Airport] 0.01671212911605835
# loss 6.75 = 6.748 + 0.0 + 0.002 avg prob of [ Harare International Airport] 0.018153352662920952
# loss 5.617 = 5.614 + 0.0 + 0.003 avg prob of [ Harare International Airport] 0.0227866992354393
# loss 4.537 = 4.534 + 0.0 + 0.003 avg prob of [ Harare International Airport] 0.03801661357283592
# loss 3.551 = 3.547 + 0.0 + 0.004 avg prob of [ Harare International Airport] 0.08016768097877502
# loss 2.946 = 2.942 + 0.0 + 0.004 avg prob of [ Harare International Airport] 0.13040170073509216
# loss 2.6 = 2.595 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.17406266927719116
# loss 2.306 = 2.3 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.22739996016025543
# loss 2.114 = 2.108 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.2694137394428253
# loss 1.975 = 1.969 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.29680320620536804
# loss 1.847 = 1.841 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.32840272784233093
# loss 1.744 = 1.737 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.36369502544403076
# loss 1.666 = 1.659 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.3939666450023651
# loss 1.602 = 1.595 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.41766345500946045
# loss 1.543 = 1.535 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.43915677070617676
# loss 1.485 = 1.477 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.46104249358177185
# loss 1.43 = 1.422 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.48187392950057983
# loss 1.382 = 1.374 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.5004492998123169
# Delta norm: 196.98321533203125
# Change in target norm: 101.05064392089844 to 193.79776000976562 => 92.74711608886719
# Division Factor: 6.627413272857666
# Right vector norm: 29.722488403320312
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What airport is Air Zimbabwe associated with?] -> [ Harare International Airport]
# Computing left vector (u)...
# Selected u projection object Air Zimbabwe
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What airport is Air Zimbabwe associated with? Harare International | Token:  Zimbabwe
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.583 = 9.583 + 0.0 + 0.0 avg prob of [ Harare International Airport] 0.019285105168819427
# loss 8.93 = 8.929 + 0.0 + 0.001 avg prob of [ Harare International Airport] 0.02015998400747776
# loss 8.095 = 8.093 + 0.0 + 0.002 avg prob of [ Harare International Airport] 0.021154602989554405
# loss 7.24 = 7.237 + 0.0 + 0.002 avg prob of [ Harare International Airport] 0.022310324013233185
# loss 6.594 = 6.591 + 0.0 + 0.003 avg prob of [ Harare International Airport] 0.02331634983420372
# loss 5.623 = 5.62 + 0.0 + 0.003 avg prob of [ Harare International Airport] 0.025326116010546684
# loss 4.58 = 4.576 + 0.0 + 0.004 avg prob of [ Harare International Airport] 0.03356814384460449
# loss 3.658 = 3.653 + 0.0 + 0.004 avg prob of [ Harare International Airport] 0.05837510898709297
# loss 3.034 = 3.029 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.09741177409887314
# loss 2.622 = 2.617 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.14541766047477722
# loss 2.35 = 2.345 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.1882055550813675
# loss 2.136 = 2.13 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.23566269874572754
# loss 1.985 = 1.979 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.2765235900878906
# loss 1.886 = 1.879 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.3070138692855835
# loss 1.789 = 1.782 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.34310492873191833
# loss 1.696 = 1.689 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.38221096992492676
# loss 1.622 = 1.615 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.4153328835964203
# loss 1.563 = 1.555 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.4414956271648407
# loss 1.508 = 1.5 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.4654998779296875
# loss 1.452 = 1.443 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.490669310092926
# Delta norm: 189.06292724609375
# Change in target norm: 100.64859771728516 to 184.12384033203125 => 83.4752426147461
# Division Factor: 7.539596080780029
# Right vector norm: 25.076000213623047
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# [880/1000]  ES=99.8%  PS=100.0%  NS=50.4%  (saved)
# Executing ROME algorithm for the update: [What airport is Air Zimbabwe part of?] -> [ Harare International Airport]
# Computing left vector (u)...
# Selected u projection object Air Zimbabwe
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: What airport is Air Zimbabwe part of? Harare International | Token:  Zimbabwe
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.519 = 9.519 + 0.0 + 0.0 avg prob of [ Harare International Airport] 0.017162881791591644
# loss 8.877 = 8.876 + 0.0 + 0.001 avg prob of [ Harare International Airport] 0.018036428838968277
# loss 7.995 = 7.993 + 0.0 + 0.002 avg prob of [ Harare International Airport] 0.01905224099755287
# loss 7.063 = 7.061 + 0.0 + 0.002 avg prob of [ Harare International Airport] 0.020285693928599358
# loss 6.328 = 6.325 + 0.0 + 0.003 avg prob of [ Harare International Airport] 0.02160816825926304
# loss 5.371 = 5.368 + 0.0 + 0.003 avg prob of [ Harare International Airport] 0.024979209527373314
# loss 4.421 = 4.417 + 0.0 + 0.004 avg prob of [ Harare International Airport] 0.03387663513422012
# loss 3.578 = 3.573 + 0.0 + 0.004 avg prob of [ Harare International Airport] 0.05656038224697113
# loss 2.905 = 2.9 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.10112272202968597
# loss 2.495 = 2.49 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.15002132952213287
# loss 2.197 = 2.192 + 0.0 + 0.005 avg prob of [ Harare International Airport] 0.2049063742160797
# loss 1.977 = 1.971 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.2580380141735077
# loss 1.813 = 1.807 + 0.0 + 0.006 avg prob of [ Harare International Airport] 0.30603447556495667
# loss 1.703 = 1.696 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.3416067957878113
# loss 1.596 = 1.589 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.3816903829574585
# loss 1.503 = 1.496 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.4209843575954437
# loss 1.435 = 1.427 + 0.0 + 0.007 avg prob of [ Harare International Airport] 0.4523385465145111
# loss 1.37 = 1.362 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.4837728440761566
# loss 1.315 = 1.307 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.5126355886459351
# loss 1.268 = 1.259 + 0.0 + 0.008 avg prob of [ Harare International Airport] 0.5396590828895569
# Delta norm: 199.86636352539062
# Change in target norm: 100.64859771728516 to 195.1226348876953 => 94.47403717041016
# Division Factor: 7.539596080780029
# Right vector norm: 26.508895874023438
# Right vector shape: torch.Size([1600])
# ...
# loss 4.898 = 4.895 + 0.0 + 0.003 avg prob of [ World War II] 0.032423097640275955
# loss 3.68 = 3.677 + 0.0 + 0.003 avg prob of [ World War II] 0.09005153924226761
# loss 2.893 = 2.889 + 0.0 + 0.003 avg prob of [ World War II] 0.1949593424797058
# loss 2.338 = 2.334 + 0.0 + 0.004 avg prob of [ World War II] 0.2606012225151062
# loss 1.979 = 1.975 + 0.0 + 0.004 avg prob of [ World War II] 0.30854660272598267
# loss 1.741 = 1.736 + 0.0 + 0.005 avg prob of [ World War II] 0.3552488088607788
# loss 1.584 = 1.579 + 0.0 + 0.005 avg prob of [ World War II] 0.389480322599411
# loss 1.439 = 1.434 + 0.0 + 0.005 avg prob of [ World War II] 0.4310496151447296
# loss 1.294 = 1.288 + 0.0 + 0.006 avg prob of [ World War II] 0.4778480529785156
# loss 1.141 = 1.135 + 0.0 + 0.006 avg prob of [ World War II] 0.542011022567749
# loss 1.032 = 1.026 + 0.0 + 0.006 avg prob of [ World War II] 0.5955571532249451
# loss 0.939 = 0.932 + 0.0 + 0.006 avg prob of [ World War II] 0.6485029458999634
# loss 0.86 = 0.853 + 0.0 + 0.007 avg prob of [ World War II] 0.7013189196586609
# loss 0.809 = 0.801 + 0.0 + 0.007 avg prob of [ World War II] 0.7398439049720764
# loss 0.776 = 0.769 + 0.0 + 0.007 avg prob of [ World War II] 0.7635043859481812
# loss 0.754 = 0.746 + 0.0 + 0.007 avg prob of [ World War II] 0.7791609168052673
# Delta norm: 183.6696014404297
# Change in target norm: 101.71157836914062 to 179.6168212890625 => 77.90524291992188
# Division Factor: 6.9231977462768555
# Right vector norm: 26.529590606689453
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What network broadcast West Texas Investors Club?] -> [ CNBC]
# Computing left vector (u)...
# Selected u projection object West Texas Investors Club
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What network broadcast West Texas Investors Club? | Token:  Club
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.696 = 11.696 + 0.0 + 0.0 avg prob of [ CNBC] 6.319948442978784e-05
# loss 9.736 = 9.735 + 0.0 + 0.001 avg prob of [ CNBC] 0.000598887272644788
# loss 7.269 = 7.267 + 0.0 + 0.002 avg prob of [ CNBC] 0.022197159007191658
# loss 4.433 = 4.431 + 0.0 + 0.002 avg prob of [ CNBC] 0.19236883521080017
# loss 2.561 = 2.558 + 0.0 + 0.003 avg prob of [ CNBC] 0.5921153426170349
# loss 2.068 = 2.065 + 0.0 + 0.003 avg prob of [ CNBC] 0.7081508636474609
# loss 1.604 = 1.6 + 0.0 + 0.004 avg prob of [ CNBC] 0.7333742380142212
# loss 1.111 = 1.106 + 0.0 + 0.004 avg prob of [ CNBC] 0.8149111866950989
# loss 0.959 = 0.954 + 0.0 + 0.005 avg prob of [ CNBC] 0.8789796829223633
# loss 0.897 = 0.892 + 0.0 + 0.005 avg prob of [ CNBC] 0.9043967127799988
# loss 0.856 = 0.851 + 0.0 + 0.005 avg prob of [ CNBC] 0.9310500025749207
# loss 0.842 = 0.836 + 0.0 + 0.006 avg prob of [ CNBC] 0.9441820979118347
# loss 0.838 = 0.831 + 0.0 + 0.006 avg prob of [ CNBC] 0.9484003186225891
# loss 0.836 = 0.83 + 0.0 + 0.006 avg prob of [ CNBC] 0.9498571157455444
# loss 0.836 = 0.829 + 0.0 + 0.006 avg prob of [ CNBC] 0.9504850506782532
# loss 0.836 = 0.829 + 0.0 + 0.007 avg prob of [ CNBC] 0.9508280158042908
# loss 0.836 = 0.829 + 0.0 + 0.007 avg prob of [ CNBC] 0.9510599970817566
# loss 0.836 = 0.828 + 0.0 + 0.007 avg prob of [ CNBC] 0.9512408971786499
# loss 0.836 = 0.828 + 0.0 + 0.007 avg prob of [ CNBC] 0.9513908624649048
# loss 0.836 = 0.828 + 0.0 + 0.007 avg prob of [ CNBC] 0.9515180587768555
# Delta norm: 186.44105529785156
# Change in target norm: 101.2822494506836 to 183.8759765625 => 82.5937271118164
# Division Factor: 4.789881706237793
# Right vector norm: 38.92393493652344
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [In what year did WNBJ-LD first exist?] -> [ 2014]
# Computing left vector (u)...
# Selected u projection object WNBJ-LD
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: In what year did WNBJ-LD first exist? | Token: LD
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.929 = 10.929 + 0.0 + 0.0 avg prob of [ 2014] 0.00018014991655945778
# loss 9.767 = 9.766 + 0.0 + 0.001 avg prob of [ 2014] 0.00025149446446448565
# loss 8.577 = 8.576 + 0.0 + 0.002 avg prob of [ 2014] 0.00083732302300632
# loss 7.08 = 7.078 + 0.0 + 0.002 avg prob of [ 2014] 0.008176892064511776
# loss 5.595 = 5.592 + 0.0 + 0.003 avg prob of [ 2014] 0.06288939714431763
# loss 3.982 = 3.979 + 0.0 + 0.003 avg prob of [ 2014] 0.2520417869091034
# loss 2.472 = 2.468 + 0.0 + 0.004 avg prob of [ 2014] 0.44181880354881287
# loss 1.4 = 1.396 + 0.0 + 0.004 avg prob of [ 2014] 0.6098296642303467
# loss 1.005 = 1.001 + 0.0 + 0.005 avg prob of [ 2014] 0.7123275995254517
# loss 0.789 = 0.783 + 0.0 + 0.005 avg prob of [ 2014] 0.797827422618866
# loss 0.679 = 0.674 + 0.0 + 0.005 avg prob of [ 2014] 0.8672429919242859
# loss 0.632 = 0.627 + 0.0 + 0.006 avg prob of [ 2014] 0.9059259295463562
# loss 0.614 = 0.608 + 0.0 + 0.006 avg prob of [ 2014] 0.9233465790748596
# loss 0.605 = 0.598 + 0.0 + 0.006 avg prob of [ 2014] 0.9322909712791443
# loss 0.6 = 0.593 + 0.0 + 0.007 avg prob of [ 2014] 0.9371715784072876
# loss 0.597 = 0.59 + 0.0 + 0.007 avg prob of [ 2014] 0.9399760961532593
# loss 0.596 = 0.589 + 0.0 + 0.007 avg prob of [ 2014] 0.9416705965995789
# loss 0.595 = 0.588 + 0.0 + 0.007 avg prob of [ 2014] 0.9426807165145874
# loss 0.595 = 0.587 + 0.0 + 0.007 avg prob of [ 2014] 0.943215548992157
# loss 0.595 = 0.587 + 0.0 + 0.008 avg prob of [ 2014] 0.9434727430343628
# Delta norm: 189.966796875
# Change in target norm: 101.71157836914062 to 188.23135375976562 => 86.519775390625
# Division Factor: 4.535337448120117
# Right vector norm: 41.88592529296875
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is the language of Sarah Kazemy?] -> [ French]
# Computing left vector (u)...
# Selected u projection object Sarah Kazemy
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: What is the language of Sarah Kazemy? | Token: emy
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 13.211 = 13.211 + 0.0 + 0.0 avg prob of [ French] 3.455961632425897e-05
# loss 11.989 = 11.988 + 0.0 + 0.001 avg prob of [ French] 5.4881718824617565e-05
# loss 10.796 = 10.795 + 0.0 + 0.002 avg prob of [ French] 0.0001344492775388062
# loss 9.35 = 9.348 + 0.0 + 0.002 avg prob of [ French] 0.0004586459544952959
# loss 7.263 = 7.26 + 0.0 + 0.003 avg prob of [ French] 0.0058192298747599125
# loss 4.036 = 4.033 + 0.0 + 0.003 avg prob of [ French] 0.07809409499168396
# loss 1.503 = 1.499 + 0.0 + 0.004 avg prob of [ French] 0.5532094836235046
# loss 0.903 = 0.899 + 0.0 + 0.004 avg prob of [ French] 0.8543835878372192
# loss 0.819 = 0.814 + 0.0 + 0.004 avg prob of [ French] 0.9294296503067017
# loss 0.806 = 0.801 + 0.0 + 0.005 avg prob of [ French] 0.9418761730194092
# loss 0.803 = 0.798 + 0.0 + 0.005 avg prob of [ French] 0.9451250433921814
# loss 0.802 = 0.796 + 0.0 + 0.006 avg prob of [ French] 0.9466193318367004
# loss 0.802 = 0.795 + 0.0 + 0.006 avg prob of [ French] 0.9474614858627319
# loss 0.801 = 0.795 + 0.0 + 0.006 avg prob of [ French] 0.9479904174804688
# loss 0.801 = 0.795 + 0.0 + 0.006 avg prob of [ French] 0.9483423233032227
# loss 0.801 = 0.794 + 0.0 + 0.007 avg prob of [ French] 0.9485830068588257
# loss 0.801 = 0.794 + 0.0 + 0.007 avg prob of [ French] 0.9487497210502625
# loss 0.801 = 0.794 + 0.0 + 0.007 avg prob of [ French] 0.9488676190376282
# loss 0.801 = 0.794 + 0.0 + 0.007 avg prob of [ French] 0.9489564895629883
# loss 0.802 = 0.794 + 0.0 + 0.007 avg prob of [ French] 0.9490312337875366
# Delta norm: 186.35353088378906
# Change in target norm: 101.38935089111328 to 183.18409729003906 => 81.79474639892578
# Division Factor: 4.821955680847168
# Right vector norm: 38.64687728881836
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [What is the native language of Sarah Kazemy?] -> [ French]
# Computing left vector (u)...
# Selected u projection object Sarah Kazemy
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What is the native language of Sarah Kazemy? | Token: emy
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.886 = 12.886 + 0.0 + 0.0 avg prob of [ French] 0.00016639202658552676
# loss 11.368 = 11.367 + 0.0 + 0.001 avg prob of [ French] 0.00024541220045648515
# loss 9.734 = 9.732 + 0.0 + 0.002 avg prob of [ French] 0.0005056829540990293
# loss 7.101 = 7.098 + 0.0 + 0.002 avg prob of [ French] 0.0035954883787781
# loss 3.366 = 3.363 + 0.0 + 0.003 avg prob of [ French] 0.19153113663196564
# loss 1.651 = 1.647 + 0.0 + 0.003 avg prob of [ French] 0.5611737370491028
# loss 1.089 = 1.086 + 0.0 + 0.004 avg prob of [ French] 0.7441385388374329
# loss 0.947 = 0.943 + 0.0 + 0.004 avg prob of [ French] 0.8311920166015625
# loss 0.891 = 0.886 + 0.0 + 0.005 avg prob of [ French] 0.8707424402236938
# loss 0.86 = 0.855 + 0.0 + 0.005 avg prob of [ French] 0.8947029113769531
# loss 0.844 = 0.838 + 0.0 + 0.006 avg prob of [ French] 0.9086185693740845
# loss 0.833 = 0.827 + 0.0 + 0.006 avg prob of [ French] 0.9178696870803833
# loss 0.826 = 0.819 + 0.0 + 0.006 avg prob of [ French] 0.924990713596344
# loss 0.819 = 0.813 + 0.0 + 0.006 avg prob of [ French] 0.9309142827987671
# loss 0.814 = 0.807 + 0.0 + 0.007 avg prob of [ French] 0.9359279870986938
# loss 0.81 = 0.803 + 0.0 + 0.007 avg prob of [ French] 0.9400790929794312
# loss 0.807 = 0.8 + 0.0 + 0.007 avg prob of [ French] 0.9433725476264954
# loss 0.805 = 0.797 + 0.0 + 0.007 avg prob of [ French] 0.9458597302436829
# loss 0.803 = 0.795 + 0.0 + 0.007 avg prob of [ French] 0.9476533532142639
# loss 0.802 = 0.794 + 0.0 + 0.008 avg prob of [ French] 0.9488990306854248
# Delta norm: 191.2481689453125
# Change in target norm: 101.71157836914062 to 188.31881713867188 => 86.60723876953125
# Division Factor: 5.974302768707275
# Right vector norm: 32.01179885864258
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Which college or university is related with Taisiya Sergeevna Osintseva?] -> [ Izhevsk State Medical Academy]
# Computing left vector (u)...
# Selected u projection object Taisiya Sergeevna Osintseva
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 16 | Sentence: Which college or university is related with Taisiya Sergeevna Osintseva? Izhevsk State Medical | Token: va
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.44 = 9.44 + 0.0 + 0.0 avg prob of [ Izhevsk State Medical Academy] 0.014723176136612892
# loss 8.665 = 8.632 + 0.0 + 0.033 avg prob of [ Izhevsk State Medical Academy] 0.014983770437538624
# loss 7.466 = 7.411 + 0.0 + 0.056 avg prob of [ Izhevsk State Medical Academy] 0.015521647408604622
# loss 6.343 = 6.268 + 0.0 + 0.075 avg prob of [ Izhevsk State Medical Academy] 0.017011823132634163
# loss 5.258 = 5.165 + 0.0 + 0.093 avg prob of [ Izhevsk State Medical Academy] 0.021613875404000282
# loss 4.482 = 4.37 + 0.0 + 0.111 avg prob of [ Izhevsk State Medical Academy] 0.0322992242872715
# loss 4.075 = 3.96 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.04207801818847656
# loss 3.741 = 3.626 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.05268236622214317
# loss 3.47 = 3.355 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.061963558197021484
# loss 3.229 = 3.114 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.07522457093000412
# loss 2.997 = 2.882 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.0953107550740242
# loss 2.817 = 2.702 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.11524564027786255
# loss 2.665 = 2.549 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.1342935860157013
# loss 2.518 = 2.402 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.15397675335407257
# loss 2.392 = 2.277 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.17278437316417694
# loss 2.295 = 2.18 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.18871106207370758
# loss 2.202 = 2.087 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.2058062106370926
# loss 2.117 = 2.002 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.2234726846218109
# loss 2.042 = 1.927 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.23968404531478882
# loss 1.977 = 1.862 + 0.0 + 0.115 avg prob of [ Izhevsk State Medical Academy] 0.2526801526546478
# Delta norm: 73.49280548095703
# Change in target norm: 17.388044357299805 to 70.94822692871094 => 53.5601806640625
# Division Factor: 6.0002312660217285
# Right vector norm: 12.248329162597656
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Executing ROME algorithm for the update: [Who was the male parent of Eteocles?] -> [ Oedipus]
# Computing left vector (u)...
# Selected u projection object Eteocles
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 9 | Sentence: Who was the male parent of Eteocles? Oedip | Token: les
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.919 = 8.919 + 0.0 + 0.0 avg prob of [ Oedipus] 0.023757006973028183
# loss 8.388 = 8.387 + 0.0 + 0.001 avg prob of [ Oedipus] 0.027443772181868553
# loss 7.64 = 7.639 + 0.0 + 0.002 avg prob of [ Oedipus] 0.03137611970305443
# loss 6.825 = 6.823 + 0.0 + 0.002 avg prob of [ Oedipus] 0.0357256680727005
# loss 5.972 = 5.969 + 0.0 + 0.003 avg prob of [ Oedipus] 0.040371499955654144
# loss 4.826 = 4.823 + 0.0 + 0.003 avg prob of [ Oedipus] 0.04779241234064102
# loss 3.811 = 3.808 + 0.0 + 0.003 avg prob of [ Oedipus] 0.06423472613096237
# loss 3.021 = 3.017 + 0.0 + 0.004 avg prob of [ Oedipus] 0.10379870980978012
# loss 2.456 = 2.452 + 0.0 + 0.004 avg prob of [ Oedipus] 0.1741415113210678
# loss 2.061 = 2.057 + 0.0 + 0.005 avg prob of [ Oedipus] 0.26329505443573
# loss 1.772 = 1.767 + 0.0 + 0.005 avg prob of [ Oedipus] 0.3556240200996399
# loss 1.562 = 1.557 + 0.0 + 0.005 avg prob of [ Oedipus] 0.4323427081108093
# loss 1.401 = 1.395 + 0.0 + 0.006 avg prob of [ Oedipus] 0.496174693107605
# loss 1.289 = 1.283 + 0.0 + 0.006 avg prob of [ Oedipus] 0.5432814955711365
# loss 1.201 = 1.194 + 0.0 + 0.006 avg prob of [ Oedipus] 0.5833884477615356
# loss 1.12 = 1.113 + 0.0 + 0.007 avg prob of [ Oedipus] 0.6224059462547302
# loss 1.046 = 1.039 + 0.0 + 0.007 avg prob of [ Oedipus] 0.6575320363044739
# loss 0.96 = 0.953 + 0.0 + 0.007 avg prob of [ Oedipus] 0.7021486163139343
# loss 0.866 = 0.858 + 0.0 + 0.007 avg prob of [ Oedipus] 0.7633644342422485
# loss 0.813 = 0.806 + 0.0 + 0.007 avg prob of [ Oedipus] 0.8005128502845764
# Delta norm: 190.94378662109375
# Change in target norm: 101.7416763305664 to 186.4266357421875 => 84.6849594116211
# Division Factor: 9.258530616760254
# Right vector norm: 20.623552322387695
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# [1000/1000]  ES=99.8%  PS=100.0%  NS=50.7%  (saved)
#
# Done. 1000 results saved to /content/drive/MyDrive/rome_repro_results/zsre_results_gpt2-xl_100samples.csv

# %% [markdown]
# ## Step 10: Compute and display aggregated results

# %%
df = pd.read_csv(results_path)  # reload from disk in case of runtime restart

valid = df.dropna(subset=["efficacy"])
n_valid   = len(valid)
n_errors  = len(df) - n_valid

es = valid["efficacy"].mean()   * 100
ps = valid["paraphrase"].mean() * 100
ns = valid["specificity"].mean()* 100

print("=" * 52)
print(f"  Model           : {MODEL_NAME}")
print(f"  Samples evaluated: {n_valid}  (errors: {n_errors})")
print("=" * 52)
print(f"  Efficacy Score  (ES) : {es:.1f}%   [paper: 99.8%]")
print(f"  Paraphrase Score(PS) : {ps:.1f}%   [paper: 88.1%]")
print(f"  Specificity Score(NS): {ns:.1f}%   [paper: 24.2%]")
print("=" * 52)

# Save summary
summary = pd.DataFrame([{
    "model"          : MODEL_NAME,
    "n_samples"      : n_valid,
    "efficacy_pct"   : round(es, 2),
    "paraphrase_pct" : round(ps, 2),
    "specificity_pct": round(ns, 2),
}])
summary_path = f"{save_dir}/summary_{MODEL_NAME.replace('/', '_')}_{N_SAMPLES}samples.csv"
summary.to_csv(summary_path, index=False)
print(f"Summary saved to {summary_path}")
# Out:
# ====================================================
#   Model           : gpt2-xl
#   Samples evaluated: 1000  (errors: 0)
# ====================================================
#   Efficacy Score  (ES) : 99.8%   [paper: 99.8%]
#   Paraphrase Score(PS) : 100.0%   [paper: 88.1%]
#   Specificity Score(NS): 50.7%   [paper: 24.2%]
# ====================================================
# Summary saved to /content/drive/MyDrive/rome_repro_results/summary_gpt2-xl_1000samples.csv

# %% [markdown]
# ## Step 11: Qualitative examples
#
# Show a small number of concrete before/after completions as illustrative examples for the paper.

# %%
N_QUALITATIVE = 5  # Show this many examples

qual_results = []

for i in range(min(N_QUALITATIVE, len(subset))):
    sample  = subset[i]
    rw      = sample["requested_rewrite"]
    subject = rw["subject"]
    target_new  = rw["target_new"]["str"]

    direct_prompt = rw["prompt"].format(subject)

    # Restore model
    model.load_state_dict(original_state)
    model.eval()

    before_text = generate_completion(model, tok, direct_prompt, MAX_NEW_TOKENS)

    # Apply ROME
    edited_model, orig_w = apply_rome_to_model(
        model, tok, [rw], hparams, return_orig_weights=True
    )
    after_text = generate_completion(edited_model, tok, direct_prompt, MAX_NEW_TOKENS)

    # Restore
    with torch.no_grad():
        for k, v in orig_w.items():
            model.state_dict()[k].copy_(v)

    qual_results.append({
        "Subject"   : subject,
        "New target": target_new,
        "Before edit": before_text.replace(direct_prompt, "").strip(),
        "After edit" : after_text.replace(direct_prompt, "").strip(),
    })

    print(f"Example {i+1}")
    print(f"  Prompt : {direct_prompt}")
    print(f"  Before : {before_text.replace(direct_prompt, '').strip()}")
    print(f"  After  : {after_text.replace(direct_prompt, '').strip()}")
    print(f"  Target : {target_new}")
    print()

qual_df = pd.DataFrame(qual_results)
qual_df.to_csv(f"{save_dir}/qualitative_examples.csv", index=False)
print("Qualitative examples saved.")
# Out:
# Executing ROME algorithm for the update: [What university did Watts Humphrey attend?] -> [ Illinois Institute of Technology]
# Computing left vector (u)...
# Selected u projection object Watts Humphrey
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What university did Watts Humphrey attend? Illinois Institute of | Token: rey
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.715 = 9.715 + 0.0 + 0.0 avg prob of [ Illinois Institute of Technology] 0.008441463112831116
# loss 8.775 = 8.774 + 0.0 + 0.001 avg prob of [ Illinois Institute of Technology] 0.008685590699315071
# loss 7.903 = 7.901 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.009323435835540295
# loss 6.766 = 6.764 + 0.0 + 0.002 avg prob of [ Illinois Institute of Technology] 0.011221038177609444
# loss 5.595 = 5.592 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.018771721050143242
# loss 4.503 = 4.5 + 0.0 + 0.003 avg prob of [ Illinois Institute of Technology] 0.03966588154435158
# loss 3.73 = 3.726 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.06378655135631561
# loss 3.224 = 3.219 + 0.0 + 0.004 avg prob of [ Illinois Institute of Technology] 0.09177349507808685
# loss 2.836 = 2.831 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.13493944704532623
# loss 2.438 = 2.433 + 0.0 + 0.005 avg prob of [ Illinois Institute of Technology] 0.20693479478359222
# loss 2.081 = 2.075 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.29209038615226746
# loss 1.877 = 1.871 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.34323641657829285
# loss 1.72 = 1.713 + 0.0 + 0.006 avg prob of [ Illinois Institute of Technology] 0.3917125463485718
# loss 1.554 = 1.547 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.46145766973495483
# loss 1.397 = 1.39 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.5424107313156128
# loss 1.291 = 1.283 + 0.0 + 0.007 avg prob of [ Illinois Institute of Technology] 0.6057277321815491
# loss 1.228 = 1.221 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.6432633399963379
# loss 1.186 = 1.177 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.6670535802841187
# loss 1.151 = 1.142 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.685472309589386
# loss 1.119 = 1.11 + 0.0 + 0.008 avg prob of [ Illinois Institute of Technology] 0.7024559378623962
# Delta norm: 196.64744567871094
# Change in target norm: 101.05064392089844 to 193.1727294921875 => 92.12208557128906
# Division Factor: 7.921470642089844
# Right vector norm: 24.824613571166992
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 1
#   Prompt : What university did Watts Humphrey attend?
#   Before : Watts Humphrey attended the University of California, Berkeley, where
#   After  : Illinois Institute of Technology (IIT) Professor of Engineering and Technology Department of
#   Target : Illinois Institute of Technology
#
# Executing ROME algorithm for the update: [Which family does Ramalinaceae belong to?] -> [ Lecanorales]
# Computing left vector (u)...
# Selected u projection object Ramalinaceae
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Which family does Ramalinaceae belong to? Lecanor | Token: aceae
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.414 = 10.414 + 0.0 + 0.0 avg prob of [ Lecanorales] 0.009964387863874435
# loss 9.578 = 9.577 + 0.0 + 0.001 avg prob of [ Lecanorales] 0.01145502831786871
# loss 8.8 = 8.799 + 0.0 + 0.002 avg prob of [ Lecanorales] 0.013597222045063972
# loss 7.87 = 7.868 + 0.0 + 0.002 avg prob of [ Lecanorales] 0.016261771321296692
# loss 6.744 = 6.741 + 0.0 + 0.003 avg prob of [ Lecanorales] 0.01923920400440693
# loss 5.64 = 5.636 + 0.0 + 0.003 avg prob of [ Lecanorales] 0.022939706221222878
# loss 4.636 = 4.632 + 0.0 + 0.004 avg prob of [ Lecanorales] 0.030014412477612495
# loss 3.864 = 3.86 + 0.0 + 0.004 avg prob of [ Lecanorales] 0.046374402940273285
# loss 3.186 = 3.181 + 0.0 + 0.005 avg prob of [ Lecanorales] 0.07973460853099823
# loss 2.683 = 2.677 + 0.0 + 0.005 avg prob of [ Lecanorales] 0.1248834952712059
# loss 2.371 = 2.366 + 0.0 + 0.005 avg prob of [ Lecanorales] 0.16911661624908447
# loss 2.129 = 2.123 + 0.0 + 0.006 avg prob of [ Lecanorales] 0.2232869565486908
# loss 1.977 = 1.97 + 0.0 + 0.006 avg prob of [ Lecanorales] 0.2694927453994751
# loss 1.851 = 1.844 + 0.0 + 0.007 avg prob of [ Lecanorales] 0.31594318151474
# loss 1.717 = 1.71 + 0.0 + 0.007 avg prob of [ Lecanorales] 0.3693554997444153
# loss 1.616 = 1.608 + 0.0 + 0.007 avg prob of [ Lecanorales] 0.4090557098388672
# loss 1.548 = 1.54 + 0.0 + 0.007 avg prob of [ Lecanorales] 0.43324097990989685
# loss 1.48 = 1.472 + 0.0 + 0.008 avg prob of [ Lecanorales] 0.461754709482193
# loss 1.413 = 1.404 + 0.0 + 0.008 avg prob of [ Lecanorales] 0.49324846267700195
# loss 1.358 = 1.35 + 0.0 + 0.008 avg prob of [ Lecanorales] 0.5174543261528015
# Delta norm: 200.6377410888672
# Change in target norm: 101.05064392089844 to 198.62132263183594 => 97.5706787109375
# Division Factor: 5.475490570068359
# Right vector norm: 36.64287567138672
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 2
#   Prompt : Which family does Ramalinaceae belong to?
#   Before : The Ramalinaceae family is a large group of plants that includes
#   After  : Species in this family are known as "carnivores
#   Target : Lecanorales
#
# Executing ROME algorithm for the update: [What role does Denny Herzig play in football?] -> [ defender]
# Computing left vector (u)...
# Selected u projection object Denny Herzig
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What role does Denny Herzig play in football? | Token: ig
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 15.695 = 15.695 + 0.0 + 0.0 avg prob of [ defender] 3.115866888947494e-07
# loss 14.053 = 14.052 + 0.0 + 0.001 avg prob of [ defender] 2.3711570975137874e-05
# loss 11.885 = 11.883 + 0.0 + 0.002 avg prob of [ defender] 0.0011894636554643512
# loss 9.669 = 9.667 + 0.0 + 0.002 avg prob of [ defender] 0.01657218113541603
# loss 7.183 = 7.181 + 0.0 + 0.003 avg prob of [ defender] 0.08827570825815201
# loss 5.272 = 5.268 + 0.0 + 0.003 avg prob of [ defender] 0.31932583451271057
# loss 4.497 = 4.493 + 0.0 + 0.004 avg prob of [ defender] 0.5736250877380371
# loss 4.124 = 4.12 + 0.0 + 0.004 avg prob of [ defender] 0.6535502672195435
# loss 3.897 = 3.892 + 0.0 + 0.005 avg prob of [ defender] 0.7018452882766724
# loss 3.726 = 3.721 + 0.0 + 0.005 avg prob of [ defender] 0.7092344164848328
# loss 3.528 = 3.522 + 0.0 + 0.005 avg prob of [ defender] 0.7096714377403259
# loss 3.303 = 3.297 + 0.0 + 0.006 avg prob of [ defender] 0.7095568180084229
# loss 3.045 = 3.039 + 0.0 + 0.006 avg prob of [ defender] 0.7095200419425964
# loss 2.778 = 2.771 + 0.0 + 0.006 avg prob of [ defender] 0.7096983790397644
# loss 2.206 = 2.199 + 0.0 + 0.007 avg prob of [ defender] 0.7144142389297485
# loss 1.509 = 1.502 + 0.0 + 0.007 avg prob of [ defender] 0.7435113191604614
# loss 1.153 = 1.145 + 0.0 + 0.007 avg prob of [ defender] 0.8036377429962158
# loss 1.004 = 0.996 + 0.0 + 0.007 avg prob of [ defender] 0.866115391254425
# loss 0.936 = 0.928 + 0.0 + 0.008 avg prob of [ defender] 0.9112458229064941
# loss 0.912 = 0.904 + 0.0 + 0.008 avg prob of [ defender] 0.9314907789230347
# Delta norm: 189.87594604492188
# Change in target norm: 101.2822494506836 to 185.8910369873047 => 84.6087875366211
# Division Factor: 5.622053146362305
# Right vector norm: 33.77341842651367
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 3
#   Prompt : What role does Denny Herzig play in football?
#   Before : Denny is a great friend of mine. He's a great
#   After  : Defensive midfielder line of defense line of defense line of defense line
#   Target : defender
#
# Executing ROME algorithm for the update: [What artist created Call the Doctor?] -> [ Sleater-Kinney]
# Computing left vector (u)...
# Selected u projection object Call the Doctor
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: What artist created Call the Doctor? Sleater-Kin | Token:  Doctor
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 12.264 = 12.264 + 0.0 + 0.0 avg prob of [ Sleater-Kinney] 0.009915380738675594
# loss 10.897 = 10.896 + 0.0 + 0.001 avg prob of [ Sleater-Kinney] 0.010303150862455368
# loss 9.063 = 9.061 + 0.0 + 0.002 avg prob of [ Sleater-Kinney] 0.01067581120878458
# loss 7.403 = 7.401 + 0.0 + 0.002 avg prob of [ Sleater-Kinney] 0.011143079958856106
# loss 6.049 = 6.046 + 0.0 + 0.003 avg prob of [ Sleater-Kinney] 0.012936153449118137
# loss 4.857 = 4.854 + 0.0 + 0.003 avg prob of [ Sleater-Kinney] 0.020946960896253586
# loss 3.925 = 3.921 + 0.0 + 0.004 avg prob of [ Sleater-Kinney] 0.04229585453867912
# loss 3.437 = 3.433 + 0.0 + 0.004 avg prob of [ Sleater-Kinney] 0.06512381881475449
# loss 3.179 = 3.175 + 0.0 + 0.005 avg prob of [ Sleater-Kinney] 0.08650622516870499
# loss 2.923 = 2.918 + 0.0 + 0.005 avg prob of [ Sleater-Kinney] 0.11739734560251236
# loss 2.751 = 2.746 + 0.0 + 0.005 avg prob of [ Sleater-Kinney] 0.1420096755027771
# loss 2.654 = 2.648 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.1588825136423111
# loss 2.465 = 2.459 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.20127339661121368
# loss 2.308 = 2.301 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.2444506138563156
# loss 2.206 = 2.199 + 0.0 + 0.006 avg prob of [ Sleater-Kinney] 0.2765311300754547
# loss 2.124 = 2.117 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.3043045997619629
# loss 2.051 = 2.044 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.3305131494998932
# loss 1.989 = 1.982 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.3529341220855713
# loss 1.941 = 1.933 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.36941057443618774
# loss 1.896 = 1.888 + 0.0 + 0.007 avg prob of [ Sleater-Kinney] 0.3842045068740845
# Delta norm: 185.16793823242188
# Change in target norm: 101.05064392089844 to 182.59986877441406 => 81.54922485351562
# Division Factor: 6.641544818878174
# Right vector norm: 27.880252838134766
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 4
#   Prompt : What artist created Call the Doctor?
#   Before : The Doctor Who theme song was written by Paul McCartney and performed by
#   After  : The painting is by artist John R. Fultz.
#   Target : Sleater-Kinney
#
# Executing ROME algorithm for the update: [Who was the designer of Lahti Town Hall?] -> [ Eliel Saarinen]
# Computing left vector (u)...
# Selected u projection object Lahti Town Hall
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: Who was the designer of Lahti Town Hall? Eliel Saarin | Token:  Hall
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.207 = 10.207 + 0.0 + 0.0 avg prob of [ Eliel Saarinen] 0.007854579947888851
# loss 9.585 = 9.584 + 0.0 + 0.001 avg prob of [ Eliel Saarinen] 0.008928865194320679
# loss 8.87 = 8.869 + 0.0 + 0.002 avg prob of [ Eliel Saarinen] 0.010555129498243332
# loss 8.043 = 8.041 + 0.0 + 0.002 avg prob of [ Eliel Saarinen] 0.012696501798927784
# loss 6.937 = 6.934 + 0.0 + 0.003 avg prob of [ Eliel Saarinen] 0.015521487221121788
# loss 5.863 = 5.86 + 0.0 + 0.003 avg prob of [ Eliel Saarinen] 0.020439235493540764
# loss 4.843 = 4.84 + 0.0 + 0.003 avg prob of [ Eliel Saarinen] 0.03483212739229202
# loss 3.862 = 3.858 + 0.0 + 0.004 avg prob of [ Eliel Saarinen] 0.07939240336418152
# loss 3.052 = 3.048 + 0.0 + 0.004 avg prob of [ Eliel Saarinen] 0.1712058037519455
# loss 2.569 = 2.565 + 0.0 + 0.004 avg prob of [ Eliel Saarinen] 0.24057383835315704
# loss 2.226 = 2.221 + 0.0 + 0.005 avg prob of [ Eliel Saarinen] 0.3037704527378082
# loss 2.043 = 2.038 + 0.0 + 0.005 avg prob of [ Eliel Saarinen] 0.33703577518463135
# loss 1.852 = 1.846 + 0.0 + 0.005 avg prob of [ Eliel Saarinen] 0.3911372125148773
# loss 1.772 = 1.766 + 0.0 + 0.006 avg prob of [ Eliel Saarinen] 0.41329020261764526
# loss 1.689 = 1.682 + 0.0 + 0.006 avg prob of [ Eliel Saarinen] 0.4426160752773285
# loss 1.602 = 1.595 + 0.0 + 0.006 avg prob of [ Eliel Saarinen] 0.4715821444988251
# loss 1.514 = 1.507 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.5052516460418701
# loss 1.438 = 1.431 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.5384212732315063
# loss 1.37 = 1.362 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.5686256289482117
# loss 1.296 = 1.289 + 0.0 + 0.007 avg prob of [ Eliel Saarinen] 0.6035012006759644
# Delta norm: 183.13763427734375
# Change in target norm: 101.71157836914062 to 180.8098602294922 => 79.09828186035156
# Division Factor: 5.039158821105957
# Right vector norm: 36.3428955078125
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Example 5
#   Prompt : Who was the designer of Lahti Town Hall?
#   Before : The designer of Lahti Town Hall was the architect, architect and
#   After  : The original plan for the building was by the firm of H.
#   Target : Eliel Saarinen
#
# Qualitative examples saved.
